# %%
import numpy as np

# %%
np.cos(x)
# Out:
# 0.9800665778412416

# %%
x=np.linspace(-np.pi,np.pi,100)

# %%
y=np.cos(x)

# %%
import matplotlib.pyplot as plt

# %%
fig,ax=plt.subplots(1,1)
ax.plot(x,y)

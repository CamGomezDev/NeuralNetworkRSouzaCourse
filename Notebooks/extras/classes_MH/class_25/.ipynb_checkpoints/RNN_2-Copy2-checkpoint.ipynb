# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#import dataset from data.csv file
dataset = pd.read_csv('data.csv',sep='\t')
dataset = dataset.dropna(subset=["Temperature"])
df=dataset.reset_index(drop=True)

# %%
train_size = int(len(df) * 0.8)
test_size = len(df) - train_size
training_set, testing_set = df.iloc[0:train_size], df.iloc[train_size:len(df)]
print(len(training_set), len(testing_set))
# Out:
# 2456 615

# %%
fig,ax=plt.subplots(1,1)
ax.plot(training_set['Temperature'],c='b',marker='o',ms=10)
ax.plot(testing_set['Temperature'],c='r',marker='o',ms=10)

ax.grid(True)

# %%
training_set=training_set.iloc[:,1:2].values
testing_set=testing_set.iloc[:,1:2].values

# %%
fig,ax=plt.subplots(1,1)
ax.plot(training_set,c='b',marker='o',ms=10)
ax.plot(testing_set,c='r',marker='o',ms=10)

ax.grid(True)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc

# %%
#Feature Scaling 
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
X_train = []
y_train = []
n_future = 4 # next 4 days temperature forecast
n_past = 30 # Past 30 days 
for i in range(0,len(training_set_scaled)-n_past-n_future+1):
    X_train.append(training_set_scaled[i : i + n_past , 0])     
    y_train.append(training_set_scaled[i + n_past : i + n_past + n_future , 0 ])
X_train , y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0] , X_train.shape[1], 1) )

# %%
X_train.shape
# Out:
# (2423, 30, 1)

# %%
fig,ax=plt.subplots(1,1)
ax.plot(np.arange(0,len(X_train[0])),X_train[0],c='b',marker='o',ms=10)
ax.scatter([30,31,32,33],y_train[0],c='r',s=200)
ax.grid(True)

# %%
from keras.models import Sequential
from keras.layers import LSTM,Dense ,Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping

# %%
model = keras.Sequential([Bidirectional(LSTM(units=30, return_sequences=True, input_shape = (X_train.shape[1], X_train.shape[2]) )) ,
                          Dropout(0.2),
                          LSTM(units= 30 , return_sequences=True),
                          Dropout(0.2),
                          LSTM(units= 30 , return_sequences=True),
                          Dropout(0.2),
                          LSTM(units= 30),
                          Dropout(0.2),
                          Dense(units = n_future,    activation='linear')])

# %%
model.compile(loss='mean_squared_error',optimizer=keras.optimizers.Adam(0.01),metrics=['acc'])

# %%
history=model.fit(X_train, y_train, epochs=200,batch_size=128, callbacks=[EarlyStopping(monitor='loss',patience=20)] )
# Out:
# Epoch 1/200
# 19/19 [==============================] - 9s 59ms/step - loss: 0.0513 - acc: 0.2670
# Epoch 2/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0142 - acc: 0.2546
# Epoch 3/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0113 - acc: 0.2509
# Epoch 4/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0100 - acc: 0.2513
# Epoch 5/200
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0092 - acc: 0.2567
# Epoch 6/200
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0087 - acc: 0.2456
# Epoch 7/200
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0084 - acc: 0.2678
# Epoch 8/200
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0080 - acc: 0.2501
# Epoch 9/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0078 - acc: 0.2497
# Epoch 10/200
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0075 - acc: 0.2666
# Epoch 11/200
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0075 - acc: 0.2509
# Epoch 12/200
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0073 - acc: 0.2497
# Epoch 13/200
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0071 - acc: 0.2352
# Epoch 14/200
# 19/19 [==============================] - 1s 73ms/step - loss: 0.0071 - acc: 0.2559
# Epoch 15/200
# 19/19 [==============================] - 1s 68ms/step - loss: 0.0068 - acc: 0.2757
# Epoch 16/200
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0071 - acc: 0.2394
# Epoch 17/200
# 19/19 [==============================] - 2s 84ms/step - loss: 0.0072 - acc: 0.2575
# Epoch 18/200
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0072 - acc: 0.2505
# Epoch 19/200
# 19/19 [==============================] - 2s 84ms/step - loss: 0.0069 - acc: 0.2546
# Epoch 20/200
# 19/19 [==============================] - 2s 84ms/step - loss: 0.0069 - acc: 0.2555
# Epoch 21/200
# 19/19 [==============================] - 2s 84ms/step - loss: 0.0070 - acc: 0.2811
# Epoch 22/200
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0070 - acc: 0.2674
# Epoch 23/200
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0066 - acc: 0.2650
# Epoch 24/200
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0065 - acc: 0.2654
# Epoch 25/200
# 19/19 [==============================] - 2s 82ms/step - loss: 0.0065 - acc: 0.2658
# Epoch 26/200
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0064 - acc: 0.2802
# Epoch 27/200
# 19/19 [==============================] - 1s 79ms/step - loss: 0.0064 - acc: 0.2621
# Epoch 28/200
# 19/19 [==============================] - 2s 81ms/step - loss: 0.
# 19/19 [==============================] - 2s 86ms/step - loss: 0.0050 - acc: 0.3359
# Epoch 166/200
# 19/19 [==============================] - 2s 89ms/step - loss: 0.0051 - acc: 0.3322
# Epoch 167/200
# 19/19 [==============================] - 2s 91ms/step - loss: 0.0052 - acc: 0.3322
# Epoch 168/200
# 19/19 [==============================] - 2s 92ms/step - loss: 0.0050 - acc: 0.3351
# Epoch 169/200
# 19/19 [==============================] - 2s 90ms/step - loss: 0.0050 - acc: 0.3454
# Epoch 170/200
# 19/19 [==============================] - 2s 86ms/step - loss: 0.0049 - acc: 0.3475
# Epoch 171/200
# 19/19 [==============================] - 2s 86ms/step - loss: 0.0049 - acc: 0.3500
# Epoch 172/200
# 19/19 [==============================] - 2s 86ms/step - loss: 0.0048 - acc: 0.3392
# Epoch 173/200
# 19/19 [==============================] - 2s 86ms/step - loss: 0.0049 - acc: 0.3471
# Epoch 174/200
# 19/19 [==============================] - 2s 90ms/step - loss: 0.0048 - acc: 0.3401
# Epoch 175/200
# 19/19 [==============================] - 2s 98ms/step - loss: 0.0048 - acc: 0.3496
# Epoch 176/200
# 19/19 [==============================] - 2s 95ms/step - loss: 0.0049 - acc: 0.3496
# Epoch 177/200
# 19/19 [==============================] - 2s 94ms/step - loss: 0.0048 - acc: 0.3537
# Epoch 178/200
# 19/19 [==============================] - 2s 90ms/step - loss: 0.0049 - acc: 0.3244
# Epoch 179/200
# 19/19 [==============================] - 2s 98ms/step - loss: 0.0049 - acc: 0.3467
# Epoch 180/200
# 19/19 [==============================] - 2s 97ms/step - loss: 0.0048 - acc: 0.3483
# Epoch 181/200
# 19/19 [==============================] - 2s 93ms/step - loss: 0.0051 - acc: 0.3434
# Epoch 182/200
# 19/19 [==============================] - 2s 87ms/step - loss: 0.0049 - acc: 0.3417
# Epoch 183/200
# 19/19 [==============================] - 2s 90ms/step - loss: 0.0047 - acc: 0.3541
# Epoch 184/200
# 19/19 [==============================] - 2s 87ms/step - loss: 0.0046 - acc: 0.3520
# Epoch 185/200
# 19/19 [==============================] - 2s 90ms/step - loss: 0.0048 - acc: 0.3417
# Epoch 186/200
# 19/19 [==============================] - 2s 88ms/step - loss: 0.0047 - acc: 0.3558
# Epoch 187/200
# 19/19 [==============================] - 2s 86ms/step - loss: 0.0050 - acc: 0.3343
# Epoch 188/200
# 19/19 [==============================] - 2s 87ms/step - loss: 0.0049 - acc: 0.3426
# Epoch 189/200
# 19/19 [==============================] - 2s 105ms/step - loss: 0.0047 - acc: 0.3467
# Epoch 190/200
# 19/19 [==============================] - 2s 89ms/step - loss: 0.0047 - acc: 0.3430
# Epoch 191/200
# 19/19 [==============================] - 2s 88ms/step - loss: 0.0047 - acc: 0.3558
# Epoch 192/200
# 19/19 [==============================] - 2s 90ms/step - loss: 0.0047 - acc: 0.3500
# Epoch 193/200
# 19/19 [==============================] - 2s 85ms/step - loss: 0.0048 - acc: 0.3446
# Epoch 194/200
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0047 - acc: 0.3483
# Epoch 195/200
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0047 - acc: 0.3483
# Epoch 196/200
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0046 - acc: 0.3558
# Epoch 197/200
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0044 - acc: 0.3558
# Epoch 198/200
# 19/19 [==============================] - 1s 69ms/step - loss: 0.0045 - acc: 0.3442
# Epoch 199/200
# 19/19 [==============================] - 1s 69ms/step - loss: 0.0043 - acc: 0.3570
# Epoch 200/200
#  1/19 [>.............................] - ETA: 1s - loss: 0.0039 - acc: 0.3594

# %%
fig,ax=plt.subplots(1,1,figsize=(10,8))
ax.plot(history.history['acc'])
#ax.plot(history.history['val_loss'])
ax.grid(True)

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# # Testing

# %%
#Feature Scaling 
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
testing_set_scaled = sc.fit_transform(testing_set)

# %%
X_test = []
y_test = []
n_future = 4 # next 4 days temperature forecast
n_past = 30 # Past 30 days 
for i in range(0,len(testing_set_scaled)-n_past-n_future+1):
    X_test.append(testing_set_scaled[i : i + n_past , 0])     
    y_test.append(testing_set_scaled[i + n_past : i + n_past + n_future , 0 ])
X_test , y_test = np.array(X_test), np.array(y_test)
X_test = np.reshape(X_test, (X_test.shape[0] , X_test.shape[1], 1) )

# %%
fig,ax=plt.subplots(1,1)
ax.plot(np.arange(0,len(X_test[0])),X_test[0],c='b',marker='o',ms=10)
ax.scatter([30,31,32,33],y_test[0],c='r',s=200)
ax.grid(True)

# %%
fig,ax=plt.subplots(1,1,figsize=(10,8))
ax.plot(np.arange(0, len(y_train)), y_train, 'b', label="train")
ax.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test, c='y',marker='.', label="true")
ax.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_pred, 'k', label="prediction")
ax.set_ylabel('Value')
ax.set_xlabel('Time Step')
ax.legend()
ax.grid(True)

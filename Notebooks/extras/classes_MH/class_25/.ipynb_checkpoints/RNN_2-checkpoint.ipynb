# %% [markdown]
# # Recurrent Neural Network II

# %% [markdown]
# ### 4 days weather prediction

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#import dataset from data.csv file
dataset = pd.read_csv('data.csv',sep='\t')
dataset = dataset.dropna(subset=["Temperature"])
df=dataset.reset_index(drop=True)

# %%
train_size = int(len(df) * 0.8)
test_size = len(df) - train_size
training_set, testing_set = df.iloc[0:train_size], df.iloc[train_size:len(df)]
print(len(training_set), len(testing_set))

# %%
fig,ax=plt.subplots(1,1)
ax.plot(training_set['Temperature'])
ax.plot(testing_set['Temperature'])
ax.grid(True)

# %%
training_set=training_set.iloc[:,1:2].values
testing_set=testing_set.iloc[:,1:2].values

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc

# %%
#Feature Scaling 
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
X_train = []
y_train = []
n_future = 4 # next 4 days temperature forecast
n_past = 30 # Past 30 days 
for i in range(0,len(training_set_scaled)-n_past-n_future+1):
    X_train.append(training_set_scaled[i : i + n_past , 0])     
    y_train.append(training_set_scaled[i + n_past : i + n_past + n_future , 0 ])
X_train , y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0] , X_train.shape[1], 1) )

# %%
X_train.shape

# %%
fig,ax=plt.subplots(1,1)
ax.plot(np.arange(0,len(X_train[0])),X_train[0],c='b',marker='o',ms=10)
ax.scatter([30,31,32,33],y_train[0],c='r',s=200)
ax.grid(True)

# %%
from keras.models import Sequential
from keras.layers import LSTM,Dense ,Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping

# %%
model = keras.Sequential([(LSTM(units=32, return_sequences=True, input_shape = (X_train.shape[1], X_train.shape[2]) )) ,
                          Dropout(0.5),
                          LSTM(units= 32 , return_sequences=True),
                          Dropout(0.5),
                          LSTM(units= 32 , return_sequences=True),
                          Dropout(0.5),
                          LSTM(units= 32),
                          Dropout(0.5),
                          Dense(units = n_future,    activation='linear')])

# %%
model.compile(loss='mean_squared_error',optimizer=keras.optimizers.Adam(0.001),metrics=['acc'])

# %%
history=model.fit(X_train, y_train, validation_split=0.1, epochs=500,batch_size=32, callbacks=[EarlyStopping(monitor='val_loss',patience=10)] )
# Out:
# Epoch 1/500
# 69/69 [==============================] - 11s 60ms/step - loss: 0.1336 - acc: 0.2628 - val_loss: 0.0700 - val_acc: 0.3045
# Epoch 2/500
# 69/69 [==============================] - 2s 36ms/step - loss: 0.0489 - acc: 0.2794 - val_loss: 0.0306 - val_acc: 0.3045
# Epoch 3/500
# 69/69 [==============================] - 3s 38ms/step - loss: 0.0416 - acc: 0.2734 - val_loss: 0.0217 - val_acc: 0.3045
# Epoch 4/500
# 69/69 [==============================] - 3s 39ms/step - loss: 0.0377 - acc: 0.2661 - val_loss: 0.0220 - val_acc: 0.2757
# Epoch 5/500
# 69/69 [==============================] - 3s 39ms/step - loss: 0.0365 - acc: 0.2560 - val_loss: 0.0207 - val_acc: 0.3045
# Epoch 6/500
# 69/69 [==============================] - 3s 39ms/step - loss: 0.0335 - acc: 0.2642 - val_loss: 0.0172 - val_acc: 0.3045
# Epoch 7/500
# 69/69 [==============================] - 3s 38ms/step - loss: 0.0313 - acc: 0.2592 - val_loss: 0.0220 - val_acc: 0.3045
# Epoch 8/500
# 69/69 [==============================] - 3s 38ms/step - loss: 0.0318 - acc: 0.2596 - val_loss: 0.0188 - val_acc: 0.3045
# Epoch 9/500
# 69/69 [==============================] - 3s 39ms/step - loss: 0.0291 - acc: 0.2757 - val_loss: 0.0159 - val_acc: 0.3045
# Epoch 10/500
# 69/69 [==============================] - 3s 39ms/step - loss: 0.0287 - acc: 0.2518 - val_loss: 0.0163 - val_acc: 0.3045
# Epoch 11/500
# 69/69 [==============================] - 3s 39ms/step - loss: 0.0277 - acc: 0.2720 - val_loss: 0.0148 - val_acc: 0.3045
# Epoch 12/500
# 69/69 [==============================] - 3s 39ms/step - loss: 0.0268 - acc: 0.2514 - val_loss: 0.0152 - val_acc: 0.3045
# Epoch 13/500
# 69/69 [==============================] - 3s 39ms/step - loss: 0.0265 - acc: 0.2509 - val_loss: 0.0152 - val_acc: 0.3045
# Epoch 14/500
# 69/69 [==============================] - 3s 39ms/step - loss: 0.0253 - acc: 0.2394 - val_loss: 0.0182 - val_acc: 0.3045
# Epoch 15/500
# 69/69 [==============================] - 3s 41ms/step - loss: 0.0255 - acc: 0.2546 - val_loss: 0.0134 - val_acc: 0.3045
# Epoch 16/500
# 69/69 [==============================] - 3s 41ms/step - loss: 0.0248 - acc: 0.2518 - val_loss: 0.0141 - val_acc: 0.3045
# Epoch 17/500
# 69/69 [==============================] - 4s 55ms/step - loss: 0.0242 - acc: 0.2569 - val_loss: 0.0164 - val_acc: 0.3045
# Epoch 18/500
# 69/69 [==============================] - 5s 77ms/step - loss: 0.0239 - acc: 0.2619 - val_loss: 0.0160 - val_acc: 0.3045
# Epoch 19/500
# 69/69 [==============================] - 6s 81ms/step - loss: 0.0230 - acc: 0.2528 - val_loss: 0.0171 - val_acc: 0.3045
# Epoch 20/500
# 69/69 [==============================] - 6s 88ms/step - loss: 0.0216 - acc: 0.2642 - val_loss: 0.0139 - val_acc: 0.3045
# Epoch 21/500
# 69/69 [==============================] - 6s 89ms/step - loss: 0.0223 - acc: 0.2495 - val_loss: 0.0151 - val_acc: 0.3045
# Epoch 22/500
# 69/69 [==============================] - 6s 81ms/step - loss: 0.0213 - acc: 0.2500 - val_loss: 0.0113 - val_acc: 0.3045
# Epoch 23/500
# 69/69 [==============================] - 6s 86ms/step - loss: 0.0204 - acc: 0.2683 - val_loss: 0.0129 - val_acc: 0.3045
# Epoch 24/500
# 69/69 [==============================] - 6s 87ms/step - loss: 0.0209 - acc: 0.2628 - val_loss: 0.0127 - val_acc: 0.3169
# Epoch 25/500
# 69/69 [==============================] - 6s 83ms/step - loss: 0.0196 - acc: 0.2619 - val_loss: 0.0131 - val_acc: 0.3045
# Epoch 26/500
# 69/69 [==============================] - 4s 59ms/step - loss: 0.0195 - acc: 0.2477 - val_loss: 0.0128 - val_acc: 0.3045
# Epoch 27/500
# 69/69 [==============================] - 4s 59ms/step - loss: 0.0193 - acc: 0.2587 - val_loss: 0.0132 - val_acc: 0.3045
# Epoch 28/500
# 69/69 [==============================] - 4s 60ms/step - loss: 0.0182 - acc: 0.2468 - val_loss: 0.0117 - val_acc: 0.3045
# Epoch 29/500
# 69/69 [==============================] - 4s 59ms/step - loss: 0.0188 - acc: 0.2647 - val_loss: 0.0147 - val_acc: 0.3045
# Epoch 30/500
# 69/69 [==============================] - 4s 61ms/step - loss: 0.0184 - acc: 0.2638 - val_loss: 0.0142 - val_acc: 0.3045
# Epoch 31/500
# 69/69 [==============================] - 4s 61ms/step - loss: 0.0183 - acc: 0.2514 - val_loss: 0.0120 - val_acc: 0.3045
# Epoch 32/500
# 69/69 [==============================] - 4s 60ms/step - loss: 0.0182 - acc: 0.2495 - val_loss: 0.0131 - val_acc: 0.3045

# %%
fig,ax=plt.subplots(1,1,figsize=(10,8))
ax.plot(history.history['acc'],label='acc')
ax.plot(history.history['val_acc'],label='val acc')
ax.legend()
ax.grid(True)

# %%
fig,ax=plt.subplots(1,1,figsize=(10,8))
ax.plot(history.history['loss'],label='loss')
ax.plot(history.history['val_loss'],label='val loss')
ax.legend()
ax.grid(True)

# %% [markdown]
# # Testing

# %%
#Feature Scaling 
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
testing_set_scaled = sc.fit_transform(testing_set)

# %%
X_test = []
y_test = []
n_future = 4 # next 4 days temperature forecast
n_past = 30 # Past 30 days 
for i in range(0,len(testing_set_scaled)-n_past-n_future+1):
    X_test.append(testing_set_scaled[i : i + n_past , 0])     
    y_test.append(testing_set_scaled[i + n_past : i + n_past + n_future , 0 ])
X_test , y_test = np.array(X_test), np.array(y_test)
X_test = np.reshape(X_test, (X_test.shape[0] , X_test.shape[1], 1) )

# %%
fig,ax=plt.subplots(1,1)
ax.plot(np.arange(0,len(X_test[0])),X_test[0],c='b',marker='o',ms=10)
ax.scatter([30,31,32,33],y_test[0],c='r',s=200)
ax.grid(True)

# %%
y_pred = model.predict(X_test)

# %%
fig,ax=plt.subplots(1,1,figsize=(10,8))
ax.plot(np.arange(0, len(y_train)), y_train, 'b', label="train")
ax.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test, c='y',marker='.', label="true")
ax.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_pred, 'k', label="prediction")
ax.set_ylabel('Value')
ax.set_xlabel('Time Step')
ax.legend()
ax.grid(True)

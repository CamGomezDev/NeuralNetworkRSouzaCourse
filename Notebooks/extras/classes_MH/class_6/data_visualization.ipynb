# %%
import os, fnmatch
for filename in os.listdir('flowers/'):
    if fnmatch.fnmatch(filename,'*.jpg'):
        print(filename)
# Out:
# 10994032453_ac7f8d9e2e.jpg
# 10555749515_13a12a026e.jpg
# 10466290366_cc72e33532.jpg
# 100080576_f52e8ee070_n.jpg
# 107592979_aaa9cdfe78_m.jpg
# 1031799732_e7f4008c03.jpg
# 10712722853_5632165b04.jpg
# 10993818044_4c19b86c82.jpg
# 10437929963_bc13eebe0c.jpg
# 10993710036_2033222c91.jpg
# 10437770546_8bb6f7bdd3_m.jpg
# 105806915_a9c13e2106_n.jpg
# 102841525_bd6628ae3c.jpg
# 10172567486_2748826a8b.jpg
# 10437754174_22ec990b77_m.jpg
# 10555826524_423eb8bf71_n.jpg
# 10140303196_b88d3d6cec.jpg
# 10172636503_21bededa75_n.jpg
# 10466558316_a7198b87e2.jpg
# 10770585085_4742b9dac3_n.jpg
# 11023214096_b5b39fab08.jpg
# 11023272144_fce94401f2_m.jpg
# 10559679065_50d2b16f6d.jpg
# 10172379554_b296050f82_n.jpg
# 10841136265_af473efc60.jpg
# 10391248763_1d16681106_n.jpg
# 10555815624_dc211569b0.jpg

# %%
for dirName, dirList, fileList in os.walk('FFT'):
    print(dirName,fileList)
#dirpath is a string, the path to the directory.  
#dirnames is a list of the names of the subdirectories in dirpath (excluding '.' and '..').
#filenames is a list of the names of the non-directory files in dirpath.
# Out:
# FFT ['20171025_161021.jpg', '20171025_160954.jpg', 'Dados 0811.ods']
# FFT/GO ['Green_Orange.ods']
# FFT/GO/ALL0002 ['F0002TEK.SET', 'F0002MTH.CSV', 'F0002TEK.JPG']
# FFT/GO/ALL0000 ['F0000TEK.JPG', 'F0000MTH.CSV', 'F0000TEK.SET']
# FFT/GO/ALL0001 ['F0001TEK.SET', 'F0001TEK.JPG', 'F0001MTH.CSV']
# FFT/ORANGE ['Orange.ods']
# FFT/ORANGE/ALL0004 ['F0004TEK.SET', 'F0004TEK.JPG', 'F0004MTH.CSV']
# FFT/ORANGE/ALL0002 ['F0002TEK.SET', 'F0002MTH.CSV', 'F0002TEK.JPG']
# FFT/ORANGE/ALL0000 ['F0000TEK.JPG', 'F0000MTH.CSV', 'F0000TEK.SET']
# FFT/ORANGE/ALL0001 ['F0001TEK.SET', 'F0001TEK.JPG', 'F0001MTH.CSV']
# FFT/ORANGE/ALL0003 ['F0003TEK.JPG', 'F0003MTH.CSV', 'F0003TEK.SET']
# FFT/RO ['Red_Orange.ods']
# FFT/RO/ALL0002 ['F0002TEK.SET', 'F0002MTH.CSV', 'F0002TEK.JPG']
# FFT/RO/ALL0000 ['F0000TEK.JPG', 'F0000MTH.CSV', 'F0000TEK.SET']
# FFT/RO/ALL0001 ['F0001TEK.SET', 'F0001TEK.JPG', 'F0001MTH.CSV']
# FFT/GREEN ['Green.ods']
# FFT/GREEN/ALL0006 ['F0006TEK.SET', 'F0006TEK.JPG', 'F0006MTH.CSV']
# FFT/GREEN/ALL0002 ['F0002TEK.SET', 'F0002MTH.CSV', 'F0002TEK.JPG']
# FFT/GREEN/ALL0000 ['F0000TEK.JPG', 'F0000MTH.CSV', 'F0000TEK.SET']
# FFT/GREEN/ALL0005 ['F0005TEK.JPG', 'F0005TEK.SET', 'F0005MTH.CSV']
# FFT/GREEN/ALL0001 ['F0001TEK.SET', 'F0001TEK.JPG', 'F0001MTH.CSV']
# FFT/ROG ['Red_Orange_Green.ods']
# FFT/ROG/ALL0002 ['F0002TEK.SET', 'F0002MTH.CSV', 'F0002TEK.JPG']
# FFT/ROG/ALL0000 ['F0000TEK.JPG', 'F0000MTH.CSV', 'F0000TEK.SET']
# FFT/ROG/ALL0001 ['F0001TEK.SET', 'F0001TEK.JPG', 'F0001MTH.CSV']
# FFT/RED ['Red.ods']
# FFT/RED/ALL0002 ['F0002TEK.SET', 'F0002MTH.CSV', 'F0002TEK.JPG']
# FFT/RED/ALL0000 ['F0000TEK.JPG', 'F0000MTH.CSV', 'F0000TEK.SET']
# FFT/RED/HeNe632d8nm ['F0000TEK.JPG', 'F0000MTH.CSV', 'F0000TEK.SET']
# FFT/RED/ALL0001 ['F0001TEK.SET', 'F0001TEK.JPG', 'F0001MTH.CSV']
# FFT/RED/ALL0003 ['F0003TEK.JPG', 'F0003MTH.CSV', 'F0003TEK.SET']
# FFT/RG ['Red_Green.ods']
# FFT/RG/ALL0002 ['F0002TEK.SET', 'F0002MTH.CSV', 'F0002TEK.JPG']
# FFT/RG/ALL0000 ['F0000TEK.JPG', 'F0000MTH.CSV', 'F0000TEK.SET']
# FFT/RG/ALL0001 ['F0001TEK.SET', 'F0001TEK.JPG', 'F0001MTH.CSV']

# %%
import shutil
import pandas as pd
df_all=pd.DataFrame()
for dirName, dirList, fileList in os.walk('FFT'):
    for fname in fileList:
        if fnmatch.fnmatch(fname,'*.CSV'):
            fullFilename = os.path.join(dirName,fname)
            shutil.copy(fullFilename, '/home/michal/TMP')

# %%
import pandas as pd
df_all=pd.DataFrame()
for dirName, dirList, fileList in os.walk('FFT'):
    for fname in fileList:
        if fnmatch.fnmatch(fname,'*.CSV'):
            fullFilename = os.path.join(dirName,fname)
            df = pd.read_csv(fullFilename,skiprows=18)
            cols = [0,1,2,3,5]
            df.drop(df.columns[cols], axis=1, inplace=True)
            df_all=pd.concat([df_all,df],axis=1)

# %%
df_all.shape
# Out:
# (1005, 27)

# %%
df_all.columns = [str(i) for i in range(len(df_all.columns))]

# %%
df_all.head()
# Out:
#          0        1        2        3        4        5        6        7  \
# 0 -94.9485 -86.1485 -84.9485 -92.9691 -58.9691 -62.5691 -55.7691 -90.9691
# 1 -88.9485 -84.9485 -85.7485 -91.7691 -67.7691 -66.9691 -60.5691 -89.7691
# 2 -85.3485 -85.7485 -79.7485 -89.3691 -71.3691 -66.9691 -57.7691 -97.7691
# 3 -88.9485 -90.9485 -81.7485 -88.9691 -62.1691 -59.7691 -57.3691 -92.1691
# 4 -87.7485 -93.7485 -86.9485 -92.9691 -63.7691 -57.7691 -65.3691 -89.7691
#
#          8        9  ...       17       18       19       20       21  \
# 0 -86.1485 -90.9485  ... -94.9485 -81.7485 -57.3897 -54.9897 -54.5897
# 1 -83.7485 -87.7485  ... -89.7485 -86.9485 -55.7897 -60.9897 -52.9897
# 2 -86.9485 -90.9485  ... -83.7485 -91.7485 -54.9897 -52.9897 -54.9897
# 3 -86.9485 -88.5485  ... -86.9485 -90.9485 -55.7897 -58.9897 -46.9897
# 4 -83.7485 -91.3485  ... -91.7485 -81.7485 -58.9897 -49.7897 -50.9897
#
#         22       23       24       25       26
# 0 -53.3897 -58.1897 -82.9485 -86.9485 -83.3485
# 1 -57.7897 -58.1897 -83.7485 -86.9485 -80.5485
# 2 -57.3897 -62.9897 -84.9485 -89.7485 -93.7485
# 3 -63.7897 -53.7897 -90.9485 -86.9485 -91.7485
# 4 -56.1897 -51.3897 -83.7485 -88.5485 -82.9485
#
# [5 rows x 27 columns]

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Cust_Segmentation.csv")
print(df.shape)
df.head()
# Out:
# (850, 10)
#    Customer Id  Age  Edu  Years Employed  Income  Card Debt  Other Debt  \
# 0            1   41    2               6      19      0.124       1.073
# 1            2   47    1              26     100      4.582       8.218
# 2            3   33    2              10      57      6.111       5.802
# 3            4   29    2               4      19      0.681       0.516
# 4            5   47    1              31     253      9.308       8.908
#
#    Defaulted Address  DebtIncomeRatio
# 0        0.0  NBA001              6.3
# 1        0.0  NBA021             12.8
# 2        1.0  NBA013             20.9
# 3        0.0  NBA009              6.3
# 4        0.0  NBA008              7.2

# %%
#df = df.drop('Address', axis=1)

# %%
X = df.values[:,1:5]

# %%
type(X)
# Out:
# numpy.ndarray

# %%
X=X.astype('float')

# %%
# %matplotlib notebook
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
 
fig = plt.figure(figsize=(6,4))
ax = plt.axes(projection ='3d')
 
x = X[:, 0]
y = X[:, 1]
z = X[:, 2]
ax.scatter(x, y, z) # must be floats
#ax.plot3D(x, y, z, 'green')

ax.set_xlabel('Age')
ax.set_ylabel('Educacion')
ax.set_zlabel('Income') 
ax.set_title('3d Scatter plot geeks for geeks')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="599.5333333333333">

# %%
from sklearn.preprocessing import StandardScaler
X = df.values[:,1:5]
X = np.nan_to_num(X)
Clus_dataSet = StandardScaler().fit_transform(X)
Clus_dataSet
# Out:
# array([[ 0.74291541,  0.31212243, -0.37878978, -0.71845859],
#        [ 1.48949049, -0.76634938,  2.5737211 ,  1.38432469],
#        [-0.25251804,  0.31212243,  0.2117124 ,  0.26803233],
#        ...,
#        [-1.24795149,  2.46906604, -1.26454304, -0.74441888],
#        [-0.37694723, -0.76634938,  0.50696349, -0.484816  ],
#        [ 2.1116364 , -0.76634938,  1.09746566,  0.44975434]])

# %%
import pandas as pd
cust_df = pd.read_csv("Cust_Segmentation.csv")
print(cust_df.shape)
cust_df.head()
# Out:
# (850, 10)
#    Customer Id  Age  Edu  Years Employed  Income  Card Debt  Other Debt  \
# 0            1   41    2               6      19      0.124       1.073
# 1            2   47    1              26     100      4.582       8.218
# 2            3   33    2              10      57      6.111       5.802
# 3            4   29    2               4      19      0.681       0.516
# 4            5   47    1              31     253      9.308       8.908
#
#    Defaulted Address  DebtIncomeRatio
# 0        0.0  NBA001              6.3
# 1        0.0  NBA021             12.8
# 2        1.0  NBA013             20.9
# 3        0.0  NBA009              6.3
# 4        0.0  NBA008              7.2

# %%
df = cust_df.drop('Address', axis=1)

# %% [markdown]
# * loading data from CSV, TXT, DICTIONARY (like in homework)
# * data visulatization 2D, 3D
# * simple example of fnmatch

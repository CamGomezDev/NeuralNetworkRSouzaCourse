# %% [markdown]
# ## Convolutional Neural Networks - introduction

# %% [markdown]
# # CNN with Tensorflow

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.5.0

# %% [markdown]
# #### Load and inspect CIFAR-10 dataset
# The CIFAR-10 dataset consists of, in total, 60000 color images, each with one of 10 labels: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck. For an introduction and a download, see [this link](https://www.cs.toronto.edu/~kriz/cifar.html).

# %%
# Import the CIFAR-10 dataset and rescale the pixel values

(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
X_train = X_train / 255.0
X_test = X_test / 255.0
# Use smaller subset -- speeds things up
X_train = X_train[:2000]
y_train = y_train[:2000]
X_test = X_test[:1000]
y_test = y_test[:1000]

# %%
X_train.shape
# Out:
# (2000, 32, 32, 3)

# %%
# Plot the first 10 CIFAR-10 images

import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 10, figsize=(10, 1))
for i in range(10):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])

# %%
X_train.shape
# Out:
# (2000, 32, 32, 3)

# %%
X_train[0].shape
# Out:
# (32, 32, 3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, Flatten, Conv2D, MaxPooling2D

# %%
def get_model(input_shape):
    model = Sequential([InputLayer(input_shape=input_shape),
                        Conv2D(filters=32,  kernel_size=(3, 3), activation='relu', name='conv_1'),
                        MaxPooling2D(pool_size=(2, 2), name='pool_1'),
                        Conv2D(filters=64, kernel_size=(3, 3), activation='relu', name='conv_2'),
                        MaxPooling2D(pool_size=(2, 2), name='pool_2'),
                        Flatten(name='flatten'),
                        Dense(units=64, activation='relu', name='dense_1'),
                        Dense(units=10, activation='softmax', name='dense_2')])
    
    return model

# %%
def compile_model(model):
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Introduce function to test model accuracy

def get_test_accuracy(model, x_test, y_test):
    test_loss, test_acc = model.evaluate(x=x_test, y=y_test, verbose=0)
    print('accuracy: {acc:0.3f}'.format(acc=test_acc))

# %%
# Create an instance of the model and show model summary
model=get_model(X_train[0].shape)
compile_model(model)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_1 (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# pool_1 (MaxPooling2D)        (None, 15, 15, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 13, 13, 64)        18496
# _________________________________________________________________
# pool_2 (MaxPooling2D)        (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                147520
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 167,562
# Trainable params: 167,562
# Non-trainable params: 0
# _________________________________________________________________

# %%
get_test_accuracy(model,X_test,y_test)
# Out:
# accuracy: 0.101

# %%
# Fit model, with simple checkpoint which saves (and overwrites) model weights every epoch
epochs=30
history=model.fit(X_train,y_train,epochs=epochs,validation_split=0.1,verbose=1)
# Out:
# Epoch 1/30
# 57/57 [==============================] - 2s 24ms/step - loss: 2.2279 - accuracy: 0.1633 - val_loss: 2.2070 - val_accuracy: 0.2100
# Epoch 2/30
# 57/57 [==============================] - 1s 22ms/step - loss: 1.9603 - accuracy: 0.3028 - val_loss: 1.9229 - val_accuracy: 0.3650
# Epoch 3/30
# 57/57 [==============================] - 1s 21ms/step - loss: 1.7231 - accuracy: 0.3883 - val_loss: 1.8274 - val_accuracy: 0.3400
# Epoch 4/30
# 57/57 [==============================] - 1s 21ms/step - loss: 1.5939 - accuracy: 0.4356 - val_loss: 1.6073 - val_accuracy: 0.4150
# Epoch 5/30
# 57/57 [==============================] - 1s 21ms/step - loss: 1.4993 - accuracy: 0.4661 - val_loss: 1.5919 - val_accuracy: 0.4200
# Epoch 6/30
# 57/57 [==============================] - 1s 21ms/step - loss: 1.4053 - accuracy: 0.4967 - val_loss: 1.6487 - val_accuracy: 0.4300
# Epoch 7/30
# 57/57 [==============================] - 1s 22ms/step - loss: 1.3116 - accuracy: 0.5322 - val_loss: 1.5708 - val_accuracy: 0.4150
# Epoch 8/30
# 57/57 [==============================] - 1s 20ms/step - loss: 1.2580 - accuracy: 0.5478 - val_loss: 1.5079 - val_accuracy: 0.4200
# Epoch 9/30
# 57/57 [==============================] - 1s 22ms/step - loss: 1.1813 - accuracy: 0.5822 - val_loss: 1.4355 - val_accuracy: 0.4550
# Epoch 10/30
# 57/57 [==============================] - 1s 21ms/step - loss: 1.0895 - accuracy: 0.6283 - val_loss: 1.4515 - val_accuracy: 0.5100
# Epoch 11/30
# 57/57 [==============================] - 1s 21ms/step - loss: 1.0258 - accuracy: 0.6522 - val_loss: 1.5294 - val_accuracy: 0.4500
# Epoch 12/30
# 57/57 [==============================] - 1s 21ms/step - loss: 0.9447 - accuracy: 0.6744 - val_loss: 1.4273 - val_accuracy: 0.4600
# Epoch 13/30
# 57/57 [==============================] - 1s 21ms/step - loss: 0.8631 - accuracy: 0.7156 - val_loss: 1.4322 - val_accuracy: 0.4900
# Epoch 14/30
# 57/57 [==============================] - 1s 21ms/step - loss: 0.8161 - accuracy: 0.7300 - val_loss: 1.4570 - val_accuracy: 0.5100
# Epoch 15/30
# 57/57 [==============================] - 1s 22ms/step - loss: 0.7407 - accuracy: 0.7628 - val_loss: 1.5235 - val_accuracy: 0.4400
# Epoch 16/30
# 57/57 [==============================] - 1s 22ms/step - loss: 0.6773 - accuracy: 0.7928 - val_loss: 1.4869 - val_accuracy: 0.4900
# Epoch 17/30
# 57/57 [==============================] - 1s 22ms/step - loss: 0.5856 - accuracy: 0.8061 - val_loss: 1.5025 - val_accuracy: 0.4750
# Epoch 18/30
# 57/57 [==============================] - 1s 21ms/step - loss: 0.5524 - accuracy: 0.8211 - val_loss: 1.5417 - val_accuracy: 0.5150
# Epoch 19/30
# 57/57 [==============================] - 1s 21ms/step - loss: 0.4692 - accuracy: 0.8661 - val_loss: 1.6954 - val_accuracy: 0.4650
# Epoch 20/30
# 57/57 [==============================] - 1s 21ms/step - loss: 0.4002 - accuracy: 0.8856 - val_loss: 1.7708 - val_accuracy: 0.4750
# Epoch 21/30
# 57/57 [==============================] - 1s 21ms/step - loss: 0.3830 - accuracy: 0.8889 - val_loss: 1.8088 - val_accuracy: 0.4900
# Epoch 22/30
# 57/57 [==============================] - 1s 21ms/step - loss: 0.3299 - accuracy: 0.9139 - val_loss: 1.7022 - val_accuracy: 0.4850
# Epoch 23/30
# 57/57 [==============================] - 1s 21ms/step - loss: 0.2522 - accuracy: 0.9439 - val_loss: 1.7563 - val_accuracy: 0.5100
# Epoch 24/30
# 57/57 [==============================] - 1s 21ms/step - loss: 0.2213 - accuracy: 0.9517 - val_loss: 1.9532 - val_accuracy: 0.4550
# Epoch 25/30
# 57/57 [==============================] - 1s 22ms/step - loss: 0.1969 - accuracy: 0.9572 - val_loss: 1.9741 - val_accuracy: 0.4750
# Epoch 26/30
# 57/57 [==============================] - 1s 24ms/step - loss: 0.1971 - accuracy: 0.9511 - val_loss: 1.9478 - val_accuracy: 0.5100
# Epoch 27/30
# 57/57 [==============================] - 1s 24ms/step - loss: 0.1542 - accuracy: 0.9750 - val_loss: 2.0974 - val_accuracy: 0.4950
# Epoch 28/30
# 57/57 [==============================] - 1s 24ms/step - loss: 0.1087 - accuracy: 0.9878 - val_loss: 2.0955 - val_accuracy: 0.4850
# Epoch 29/30
# 57/57 [==============================] - 1s 24ms/step - loss: 0.0865 - accuracy: 0.9889 - val_loss: 2.1997 - val_accuracy: 0.4750
# Epoch 30/30
# 57/57 [==============================] - 1s 24ms/step - loss: 0.0746 - accuracy: 0.9911 - val_loss: 2.1821 - val_accuracy: 0.5000

# %%
get_test_accuracy(model,X_test,y_test)
# Out:
# accuracy: 0.496

# %%
import matplotlib.pyplot as plt
xvals=range(epochs)
fig,ax=plt.subplots(1,1)
ax.plot(xvals, history.history['val_accuracy'],label='validation set accuracy')
ax.plot(xvals, history.history['accuracy'],label='train set accuracy')
ax.set_xlabel('epochs')
ax.set_ylabel('accuracy')
ax.legend()

# %% [markdown]
# ## from_digits=True
# * loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True) - is another way to say normalize the output in terms of probabitlity

# %%
def compile_model2(model):
    model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])
# Softmax function is called when logit=True (normalized output)

# %%
def get_model2(input_shape):
    model = Sequential([InputLayer(input_shape=input_shape),
                        Conv2D(filters=32,  kernel_size=(3, 3), activation='relu', name='conv_1'),
                        MaxPooling2D(pool_size=(2, 2), name='pool_1'),
                        Conv2D(filters=64, kernel_size=(3, 3), activation='relu', name='conv_2'),
                        MaxPooling2D(pool_size=(2, 2), name='pool_2'),
                        Flatten(name='flatten'),
                        Dense(units=64, activation='relu', name='dense_1'),
                        Dense(units=10, name='dense_2')])
    
    return model

# %%
model=get_model2(X_train[0].shape)
compile_model2(model)

# %% [markdown]
# # Dataset augmentaton using TensorFlow data generator:
# (https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator)

# %% [markdown]
# Overfitting occurs when you have too few records relative to other parameters (e.g., predictors or features). I'm not familiar with your data, but it sounds like the subsetting is creating additional records.
#
# Data augmentation artificially increases the size of the training set by generating many realistic variants of each training instance. Data augmentation is a technique used for introducing variety in training data thereby helping to mitigate overfitting.
#
# Data augmentation makes a sample data look slightly different every time it is processed by the model. The process makes each data set appear unique to the model and prevents the model from learning the characteristics of the data sets.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    validation_split=0.1,
    zoom_range=0.5,
    fill_mode='nearest')
# compute quantities required for featurewise normalization
# (std, mean, and principal components if ZCA whitening is applied)

# %%
datagen.fit(X_train)

# %%
train_aug=datagen.flow(X_train, y_train, batch_size=32,
         subset='training',shuffle=True)

valid_aug=datagen.flow(X_train, y_train, batch_size=32,
         subset='training',shuffle=True)

# %% [markdown]
# #### `train_aug` is a package of X_train and y_train

# %%
X_gen,y_gen = train_aug.next()
fig, ax = plt.subplots(1, 10, figsize=(10, 1))
for i in range(10):
    ax[i].imshow(X_gen[i])

# %%
model=get_model(X_gen[0].shape)
compile_model(model)

# %%
get_test_accuracy(model,X_test,y_test)
# Out:
# accuracy: 0.125

# %%
epochs=100
history=model.fit(train_aug,
         validation_data=valid_aug,epochs=epochs)
# Out:
# Epoch 1/100
# 57/57 [==============================] - 4s 56ms/step - loss: 2.2247 - accuracy: 0.1822 - val_loss: 2.0677 - val_accuracy: 0.2200
# Epoch 2/100
# 57/57 [==============================] - 3s 56ms/step - loss: 2.0134 - accuracy: 0.2561 - val_loss: 1.9842 - val_accuracy: 0.2628
# Epoch 3/100
# 57/57 [==============================] - 3s 49ms/step - loss: 1.8971 - accuracy: 0.2950 - val_loss: 1.8530 - val_accuracy: 0.3222
# Epoch 4/100
# 57/57 [==============================] - 3s 48ms/step - loss: 1.8245 - accuracy: 0.3322 - val_loss: 1.8114 - val_accuracy: 0.3411
# Epoch 5/100
# 57/57 [==============================] - 3s 52ms/step - loss: 1.7848 - accuracy: 0.3583 - val_loss: 1.7354 - val_accuracy: 0.3756
# Epoch 6/100
# 57/57 [==============================] - 3s 53ms/step - loss: 1.7591 - accuracy: 0.3678 - val_loss: 1.7256 - val_accuracy: 0.3789
# Epoch 7/100
# 57/57 [==============================] - 3s 52ms/step - loss: 1.7037 - accuracy: 0.3994 - val_loss: 1.6725 - val_accuracy: 0.3911
# Epoch 8/100
# 57/57 [==============================] - 3s 54ms/step - loss: 1.6848 - accuracy: 0.3883 - val_loss: 1.6833 - val_accuracy: 0.3817
# Epoch 9/100
# 57/57 [==============================] - 3s 51ms/step - loss: 1.6239 - accuracy: 0.4144 - val_loss: 1.6588 - val_accuracy: 0.3917
# Epoch 10/100
# 57/57 [==============================] - 3s 50ms/step - loss: 1.6300 - accuracy: 0.4083 - val_loss: 1.6011 - val_accuracy: 0.4056
# Epoch 11/100
# 57/57 [==============================] - 3s 52ms/step - loss: 1.6232 - accuracy: 0.4139 - val_loss: 1.5856 - val_accuracy: 0.4394
# Epoch 12/100
# 57/57 [==============================] - 3s 55ms/step - loss: 1.5941 - accuracy: 0.4339 - val_loss: 1.5949 - val_accuracy: 0.4344
# Epoch 13/100
# 57/57 [==============================] - 4s 68ms/step - loss: 1.5932 - accuracy: 0.4289 - val_loss: 1.5221 - val_accuracy: 0.4561
# Epoch 14/100
# 57/57 [==============================] - 4s 63ms/step - loss: 1.5415 - accuracy: 0.4556 - val_loss: 1.4965 - val_accuracy: 0.4761
# Epoch 15/100
# 57/57 [==============================] - 3s 54ms/step - loss: 1.5576 - accuracy: 0.4428 - val_loss: 1.5354 - val_accuracy: 0.4656
# Epoch 16/100
# 57/57 [==============================] - 3s 55ms/step - loss: 1.5269 - accuracy: 0.4661 - val_loss: 1.5487 - val_accuracy: 0.4494
# Epoch 17/100
# 57/57 [==============================] - 3s 53ms/step - loss: 1.5265 - accuracy: 0.4594 - val_loss: 1.5449 - val_accuracy: 0.4739
# Epoch 18/100
# 57/57 [==============================] - 3s 53ms/step - loss: 1.4926 - accuracy: 0.4644 - val_loss: 1.4719 - val_accuracy: 0.4911
# Epoch 19/100
# 57/57 [==============================] - 3s 52ms/step - loss: 1.5008 - accuracy: 0.4722 - val_loss: 1.4627 - val_accuracy: 0.4678
# Epoch 20/100
# 57/57 [==============================] - 3s 54ms/step - loss: 1.4817 - accuracy: 0.4783 - val_loss: 1.5004 - val_accuracy: 0.4544
# Epoch 21/100
# 57/57 [==============================] - 4s 63ms/step - loss: 1.4703 - accuracy: 0.4733 - val_loss: 1.4614 - val_accuracy: 0.5011
# Epoch 22/100
# 57/57 [==============================] - 4s 64ms/step - loss: 1.4682 - accuracy: 0.4789 - val_loss: 1.4116 - val_accuracy: 0.4856
# Epoch 23/100
# 57/57 [==============================] - 3s 60ms/step - loss: 1.4438 - accuracy: 0.5006 - val_loss: 1.3891 - val_accuracy: 0.5139
# Epoch 24/100
# 57/57 [==============================] - 3s 57ms/step - loss: 1.4630 - accuracy: 0.4639 - val_loss: 1.4134 - val_accuracy: 0.5006
# Epoch 25/100
# 57/57 [==============================] - 3s 56ms/step - loss: 1.4040 - accuracy: 0.5083 - val_loss: 1.3653 - val_accuracy: 0.5194
# Epoch 26/100
# 57/57 [==============================] - 3s 55ms/step - loss: 1.4364 - accuracy: 0.4928 - val_loss: 1.3465 - val_accuracy: 0.5217
# Epoch 27/100
# 57/57 [==============================] - 3s 56ms/step - loss: 1.3984 - accuracy: 0.5094 - val_loss: 1.3556 - val_accuracy: 0.5344
# Epoch 28/100
# 57/57 [==============================] - 3s 55ms/step - loss: 1.4004 - accuracy: 0.4939 - val_loss: 1.3219 - val_accuracy: 0.5422
# Epoch 29/100
# 57/57 [==============================] - 3s 56ms/step - loss: 1.3428 - accuracy: 0.5128 - val_loss: 1.3227 - val_accuracy: 0.5383
# Epoch 30/100
# 57/57 [==============================] - 3s 55ms/step - loss: 1.3346 - accuracy: 0.5344 - val_loss: 1.3263 - val_accuracy: 0.5261
# Epoch 31/100
# 57/57 [==============================] - 3s 55ms/step - loss: 1.3808 - accuracy: 0.5100 - val_loss: 1.3435 - val_accuracy: 0.5189
# Epoch 32/100
# 57/57 [==============================] - 3s 55ms/step - loss: 1.3653 - accuracy: 0.5150 - val_loss: 1.2696 - val_accuracy: 0.5417
# Epoch 33/100
# 57/57 [==============================] - 3s 55ms/step - loss: 1.3472 - accuracy: 0.5194 - val_loss: 1.2810 - val_accuracy: 0.5483
# Epoch 34/100
# 57/57 [==============================] - 3s 54ms/step - loss: 1.3468 - accuracy: 0.5300 - val_loss: 1.3410 - val_accuracy: 0.5344
# Epoch 35/100
# 57/57 [==============================] - 3s 60ms/step - loss: 1.2967 - accuracy: 0.5378 - val_loss: 1.2678 - val_accuracy: 0.5556
# Epoch 36/100
# 57/57 [==============================] - 3s 54ms/step - loss: 1.2852 - accuracy: 0.5500 - val_loss: 1.2639 - val_accuracy: 0.5600
# Epoch 37/100
# 57/57 [==============================] - 3s 55ms/step - loss: 1.3126 - accuracy: 0.5361 - val_loss: 1.2781 - val_accuracy: 0.5494
# Epoch 38/100
# 57/57 [==============================] - 3s 57ms/step - loss: 1.2607 - accuracy: 0.5456 - val_loss: 1.2750 - val_accuracy: 0.5517
# Epoch 39/100
# 57/57 [==============================] - 3s 53ms/step - loss: 1.2802 - accuracy: 0.5572 - val_loss: 1.2401 - val_accuracy: 0.5667
# Epoch 40/100
# 57/57 [==============================] - 3s 51ms/step - loss: 1.2627 - accuracy: 0.5461 - val_loss: 1.2552 - val_accuracy: 0.5506
# Epoch 41/100
# 57/57 [==============================] - 3s 51ms/step - loss: 1.2899 - accuracy: 0.5539 - val_loss: 1.2633 - val_accuracy: 0.5489
# Epoch 42/100
# 57/57 [==============================] - 3s 53ms/step - loss: 1.2596 - accuracy: 0.5556 - val_loss: 1.2199 - val_accuracy: 0.5594
# Epoch 43/100
# 57/57 [==============================] - 3s 53ms/step - loss: 1.2348 - accuracy: 0.5572 - val_loss: 1.2363 - val_accuracy: 0.5506
# Epoch 44/100
# 57/57 [==============================] - 3s 51ms/step - loss: 1.2473 - accuracy: 0.5611 - val_loss: 1.2378 - val_accuracy: 0.5722
# Epoch 45/100
# 57/57 [==============================] - 3s 54ms/step - loss: 1.2321 - accuracy: 0.5683 - val_loss: 1.2416 - val_accuracy: 0.5606
# Epoch 46/100
# 57/57 [==============================] - 3s 57ms/step - loss: 1.2450 - accuracy: 0.5561 - val_loss: 1.1777 - val_accuracy: 0.5783
# Epoch 47/100
# 57/57 [==============================] - 3s 55ms/step - loss: 1.1887 - accuracy: 0.5767 - val_loss: 1.1907 - val_accuracy: 0.5750
# Epoch 48/100
# 57/57 [==============================] - 3s 54ms/step - loss: 1.2158 - accuracy: 0.5767 - val_loss: 1.1897 - val_accuracy: 0.5961
# Epoch 49/100
# 57/57 [==============================] - 3s 54ms/step - loss: 1.1873 - accuracy: 0.5856 - val_loss: 1.1931 - val_accuracy: 0.5800
# Epoch 50/100
# 57/57 [==============================] - 5s 88ms/step - loss: 1.1938 - accuracy: 0.5817 - val_loss: 1.1614 - val_accuracy: 0.5872
# Epoch 51/100
# 57/57 [==============================] - 3s 60ms/step - loss: 1.1860 - accuracy: 0.5761 - val_loss: 1.1494 - val_accuracy: 0.5989
# Epoch 52/100
# 57/57 [==============================] - 3s 57ms/step - loss: 1.1931 - accuracy: 0.5650 - val_loss: 1.1546 - val_accuracy: 0.6011
# Epoch 53/100
# 57/57 [==============================] - 4s 63ms/step - loss: 1.1747 - accuracy: 0.5961 - val_loss: 1.1721 - val_accuracy: 0.5806
# Epoch 54/100
# 57/57 [==============================] - 4s 78ms/step - loss: 1.1598 - accuracy: 0.5906 - val_loss: 1.1357 - val_accuracy: 0.6033
# Epoch 55/100
# 57/57 [==============================] - 4s 61ms/step - loss: 1.1717 - accuracy: 0.5944 - val_loss: 1.1407 - val_accuracy: 0.6044
# Epoch 56/100
# 57/57 [==============================] - 3s 55ms/step - loss: 1.1896 - accuracy: 0.5772 - val_loss: 1.1406 - val_accuracy: 0.5883
# Epoch 57/100
# 57/57 [==============================] - 3s 53ms/step - loss: 1.1217 - accuracy: 0.6022 - val_loss: 1.1374 - val_accuracy: 0.5956
# Epoch 58/100
# 57/57 [==============================] - 3s 55ms/step - loss: 1.1468 - accuracy: 0.5811 - val_loss: 1.1300 - val_accuracy: 0.6033
# Epoch 59/100
# 57/57 [==============================] - 3s 61ms/step - loss: 1.1813 - accuracy: 0.5822 - val_loss: 1.1249 - val_accuracy: 0.6094
# Epoch 60/100
# 57/57 [==============================] - 4s 70ms/step - loss: 1.1307 - accuracy: 0.5950 - val_loss: 1.1274 - val_accuracy: 0.5961
# Epoch 61/100
# 57/57 [==============================] - 7s 117ms/step - loss: 1.1285 - accuracy: 0.6028 - val_loss: 1.0509 - val_accuracy: 0.6322
# Epoch 62/100
# 57/57 [==============================] - 4s 66ms/step - loss: 1.1174 - accuracy: 0.6089 - val_loss: 1.0760 - val_accuracy: 0.6267
# Epoch 63/100
# 57/57 [==============================] - 3s 56ms/step - loss: 1.1056 - accuracy: 0.6078 - val_loss: 1.1372 - val_accuracy: 0.5978
# Epoch 64/100
# 57/57 [==============================] - 3s 58ms/step - loss: 1.1109 - accuracy: 0.6144 - val_loss: 1.0752 - val_accuracy: 0.6222
# Epoch 65/100
# 57/57 [==============================] - 3s 55ms/step - loss: 1.0657 - accuracy: 0.6439 - val_loss: 1.0652 - val_accuracy: 0.6178
# Epoch 66/100
# 57/57 [==============================] - 3s 54ms/step - loss: 1.1046 - accuracy: 0.6167 - val_loss: 1.0985 - val_accuracy: 0.6217
# Epoch 67/100
# 57/57 [==============================] - 3s 60ms/step - loss: 1.0880 - accuracy: 0.6228 - val_loss: 1.0644 - val_accuracy: 0.6061
# Epoch 68/100
# 57/57 [==============================] - 3s 60ms/step - loss: 1.1242 - accuracy: 0.6050 - val_loss: 1.0649 - val_accuracy: 0.6239
# Epoch 69/100
# 57/57 [==============================] - 3s 52ms/step - loss: 1.0839 - accuracy: 0.6272 - val_loss: 1.0987 - val_accuracy: 0.6150
# Epoch 70/100
# 57/57 [==============================] - 3s 56ms/step - loss: 1.1275 - accuracy: 0.5983 - val_loss: 1.0602 - val_accuracy: 0.6378
# Epoch 71/100
# 57/57 [==============================] - 3s 53ms/step - loss: 1.0774 - accuracy: 0.6333 - val_loss: 1.0970 - val_accuracy: 0.6111
# Epoch 72/100
# 57/57 [==============================] - 3s 54ms/step - loss: 1.0958 - accuracy: 0.6133 - val_loss: 1.0279 - val_accuracy: 0.6383
# Epoch 73/100
# 57/57 [==============================] - 3s 54ms/step - loss: 1.0367 - accuracy: 0.6344 - val_loss: 1.0301 - val_accuracy: 0.6406
# Epoch 74/100
# 57/57 [==============================] - 3s 53ms/step - loss: 1.0471 - accuracy: 0.6272 - val_loss: 1.0457 - val_accuracy: 0.6350
# Epoch 75/100
# 57/57 [==============================] - 3s 52ms/step - loss: 1.0640 - accuracy: 0.6356 - val_loss: 1.0182 - val_accuracy: 0.6400
# Epoch 76/100
# 57/57 [==============================] - 3s 57ms/step - loss: 1.0700 - accuracy: 0.6222 - val_loss: 1.0246 - val_accuracy: 0.6389
# Epoch 77/100
# 57/57 [==============================] - 4s 73ms/step - loss: 0.9934 - accuracy: 0.6500 - val_loss: 0.9843 - val_accuracy: 0.6511
# Epoch 78/100
# 57/57 [==============================] - 3s 55ms/step - loss: 1.0162 - accuracy: 0.6278 - val_loss: 1.0165 - val_accuracy: 0.6400
# Epoch 79/100
# 57/57 [==============================] - 4s 75ms/step - loss: 1.0549 - accuracy: 0.6172 - val_loss: 1.0498 - val_accuracy: 0.6328
# Epoch 80/100
# 57/57 [==============================] - 4s 63ms/step - loss: 1.0477 - accuracy: 0.6294 - val_loss: 1.0332 - val_accuracy: 0.6372
# Epoch 81/100
# 57/57 [==============================] - 4s 61ms/step - loss: 1.0334 - accuracy: 0.6383 - val_loss: 0.9864 - val_accuracy: 0.6583
# Epoch 82/100
# 57/57 [==============================] - 3s 53ms/step - loss: 1.0145 - accuracy: 0.6394 - val_loss: 0.9838 - val_accuracy: 0.6589
# Epoch 83/100
# 57/57 [==============================] - 3s 54ms/step - loss: 1.0095 - accuracy: 0.6467 - val_loss: 0.9856 - val_accuracy: 0.6567
# Epoch 84/100
# 57/57 [==============================] - 3s 55ms/step - loss: 0.9973 - accuracy: 0.6583 - val_loss: 0.9529 - val_accuracy: 0.6650
# Epoch 85/100
# 57/57 [==============================] - 3s 59ms/step - loss: 0.9747 - accuracy: 0.6550 - val_loss: 0.9611 - val_accuracy: 0.6650
# Epoch 86/100
# 57/57 [==============================] - 3s 57ms/step - loss: 0.9944 - accuracy: 0.6383 - val_loss: 0.9844 - val_accuracy: 0.6572
# Epoch 87/100
# 57/57 [==============================] - 3s 57ms/step - loss: 1.0269 - accuracy: 0.6278 - val_loss: 1.0269 - val_accuracy: 0.6450
# Epoch 88/100
# 57/57 [==============================] - 3s 56ms/step - loss: 0.9980 - accuracy: 0.6478 - val_loss: 0.9571 - val_accuracy: 0.6628
# Epoch 89/100
# 57/57 [==============================] - 3s 56ms/step - loss: 0.9753 - accuracy: 0.6533 - val_loss: 0.9402 - val_accuracy: 0.6672
# Epoch 90/100
# 57/57 [==============================] - 3s 58ms/step - loss: 1.0021 - accuracy: 0.6383 - val_loss: 0.9604 - val_accuracy: 0.6622
# Epoch 91/100
# 57/57 [==============================] - 3s 55ms/step - loss: 0.9507 - accuracy: 0.6667 - val_loss: 0.9241 - val_accuracy: 0.6806
# Epoch 92/100
# 57/57 [==============================] - 3s 56ms/step - loss: 0.9634 - accuracy: 0.6611 - val_loss: 0.9671 - val_accuracy: 0.6578
# Epoch 93/100
# 57/57 [==============================] - 3s 56ms/step - loss: 0.9850 - accuracy: 0.6356 - val_loss: 1.0313 - val_accuracy: 0.6400
# Epoch 94/100
# 57/57 [==============================] - 3s 59ms/step - loss: 0.9710 - accuracy: 0.6683 - val_loss: 0.9640 - val_accuracy: 0.6522
# Epoch 95/100
# 57/57 [==============================] - 3s 59ms/step - loss: 0.9592 - accuracy: 0.6533 - val_loss: 0.8810 - val_accuracy: 0.6906
# Epoch 96/100
# 57/57 [==============================] - 3s 56ms/step - loss: 0.9381 - accuracy: 0.6800 - val_loss: 0.9337 - val_accuracy: 0.6694
# Epoch 97/100
# 57/57 [==============================] - 3s 60ms/step - loss: 0.9846 - accuracy: 0.6533 - val_loss: 0.9478 - val_accuracy: 0.6617
# Epoch 98/100
# 57/57 [==============================] - 3s 59ms/step - loss: 0.9336 - accuracy: 0.6767 - val_loss: 0.9172 - val_accuracy: 0.6728
# Epoch 99/100
# 57/57 [==============================] - 3s 56ms/step - loss: 0.9562 - accuracy: 0.6622 - val_loss: 0.9182 - val_accuracy: 0.6672
# Epoch 100/100
# 57/57 [==============================] - 3s 58ms/step - loss: 0.9566 - accuracy: 0.6578 - val_loss: 0.9436 - val_accuracy: 0.6733

# %%
import matplotlib.pyplot as plt
xvals=range(epochs)
fig,ax=plt.subplots(1,1)
ax.plot(xvals, history.history['val_accuracy'],label='validation set accuracy')
ax.plot(xvals, history.history['accuracy'],label='train set accuracy')
ax.set_xlabel('epochs')
ax.set_ylabel('accuracy')
ax.legend()

# %%
get_test_accuracy(model,X_test,y_test)
# Out:
# accuracy: 0.542

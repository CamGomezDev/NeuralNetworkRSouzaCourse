# %% [markdown]
# ## Convolutional Neural Networks - introduction

# %% [markdown]
# # CNN with Tensorflow

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.5.0

# %% [markdown]
# #### Load and inspect CIFAR-10 dataset
# The CIFAR-10 dataset consists of, in total, 60000 color images, each with one of 10 labels: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck. For an introduction and a download, see [this link](https://www.cs.toronto.edu/~kriz/cifar.html).

# %%
# Import the CIFAR-10 dataset and rescale the pixel values

(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
X_train = X_train / 255.0
X_test = X_test / 255.0
# Use smaller subset -- speeds things up
X_train = X_train[:2000]
y_train = y_train[:2000]
X_test = X_test[:1000]
y_test = y_test[:1000]

# %%
X_train.shape
# Out:
# (2000, 32, 32, 3)

# %%
# Plot the first 10 CIFAR-10 images

import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 10, figsize=(10, 1))
for i in range(10):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])

# %%
X_train.shape
# Out:
# (2000, 32, 32, 3)

# %%
X_train[0].shape
# Out:
# (32, 32, 3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, Flatten, Conv2D, MaxPooling2D

# %%
def get_model(input_shape):
    model = Sequential([InputLayer(input_shape=input_shape),
                        Conv2D(filters=32,  kernel_size=(3, 3), activation='relu', name='conv_1'),
                        MaxPooling2D(pool_size=(2, 2), name='pool_1'),
                        Conv2D(filters=64, kernel_size=(3, 3), activation='relu', name='conv_2'),
                        MaxPooling2D(pool_size=(2, 2), name='pool_2'),
                        Flatten(name='flatten'),
                        Dense(units=64, activation='relu', name='dense_1'),
                        Dense(units=10, activation='softmax', name='dense_2')])
    
    return model

# %%
def compile_model(model):
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Introduce function to test model accuracy

def get_test_accuracy(model, x_test, y_test):
    test_loss, test_acc = model.evaluate(x=x_test, y=y_test, verbose=0)
    print('accuracy: {acc:0.3f}'.format(acc=test_acc))

# %%
# Create an instance of the model and show model summary
model=get_model(X_train[0].shape)
compile_model(model)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_1 (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# pool_1 (MaxPooling2D)        (None, 15, 15, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 13, 13, 64)        18496
# _________________________________________________________________
# pool_2 (MaxPooling2D)        (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                147520
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 167,562
# Trainable params: 167,562
# Non-trainable params: 0
# _________________________________________________________________

# %%
get_test_accuracy(model,X_test,y_test)
# Out:
# accuracy: 0.069

# %%
# Fit model, with simple checkpoint which saves (and overwrites) model weights every epoch
epochs=30
history=model.fit(X_train,y_train,epochs=epochs,validation_split=0.1,verbose=1)
# Out:
# Epoch 1/30
# 57/57 [==============================] - 2s 22ms/step - loss: 2.1519 - accuracy: 0.2011 - val_loss: 2.1214 - val_accuracy: 0.2100
# Epoch 2/30
# 57/57 [==============================] - 1s 20ms/step - loss: 1.8142 - accuracy: 0.3317 - val_loss: 1.9279 - val_accuracy: 0.3500
# Epoch 3/30
# 57/57 [==============================] - 1s 20ms/step - loss: 1.6832 - accuracy: 0.3972 - val_loss: 1.7561 - val_accuracy: 0.3250
# Epoch 4/30
# 57/57 [==============================] - 1s 19ms/step - loss: 1.5626 - accuracy: 0.4439 - val_loss: 1.6954 - val_accuracy: 0.3800
# Epoch 5/30
# 57/57 [==============================] - 1s 20ms/step - loss: 1.4665 - accuracy: 0.4739 - val_loss: 1.6236 - val_accuracy: 0.4050
# Epoch 6/30
# 57/57 [==============================] - 1s 20ms/step - loss: 1.3762 - accuracy: 0.5100 - val_loss: 1.5187 - val_accuracy: 0.4450
# Epoch 7/30
# 57/57 [==============================] - 1s 20ms/step - loss: 1.2734 - accuracy: 0.5450 - val_loss: 1.5936 - val_accuracy: 0.4600
# Epoch 8/30
# 57/57 [==============================] - 1s 19ms/step - loss: 1.1901 - accuracy: 0.5761 - val_loss: 1.5639 - val_accuracy: 0.4800
# Epoch 9/30
# 57/57 [==============================] - 1s 20ms/step - loss: 1.1137 - accuracy: 0.6172 - val_loss: 1.4435 - val_accuracy: 0.5200
# Epoch 10/30
# 57/57 [==============================] - 1s 19ms/step - loss: 1.0197 - accuracy: 0.6389 - val_loss: 1.4295 - val_accuracy: 0.4900
# Epoch 11/30
# 57/57 [==============================] - 1s 20ms/step - loss: 0.9619 - accuracy: 0.6683 - val_loss: 1.4462 - val_accuracy: 0.5150
# Epoch 12/30
# 57/57 [==============================] - 1s 20ms/step - loss: 0.8616 - accuracy: 0.7061 - val_loss: 1.5104 - val_accuracy: 0.4950
# Epoch 13/30
# 57/57 [==============================] - 1s 19ms/step - loss: 0.8038 - accuracy: 0.7222 - val_loss: 1.4319 - val_accuracy: 0.5150
# Epoch 14/30
# 57/57 [==============================] - 1s 20ms/step - loss: 0.7047 - accuracy: 0.7728 - val_loss: 1.4031 - val_accuracy: 0.5100
# Epoch 15/30
# 57/57 [==============================] - 1s 20ms/step - loss: 0.6287 - accuracy: 0.7967 - val_loss: 1.5324 - val_accuracy: 0.5100
# Epoch 16/30
# 57/57 [==============================] - 1s 20ms/step - loss: 0.5783 - accuracy: 0.8111 - val_loss: 1.5772 - val_accuracy: 0.4800
# Epoch 17/30
# 57/57 [==============================] - 1s 20ms/step - loss: 0.5202 - accuracy: 0.8367 - val_loss: 1.5064 - val_accuracy: 0.5150
# Epoch 18/30
# 57/57 [==============================] - 1s 20ms/step - loss: 0.5044 - accuracy: 0.8372 - val_loss: 1.6818 - val_accuracy: 0.4900
# Epoch 19/30
# 57/57 [==============================] - 1s 19ms/step - loss: 0.3915 - accuracy: 0.8922 - val_loss: 1.7799 - val_accuracy: 0.4650
# Epoch 20/30
# 57/57 [==============================] - 1s 19ms/step - loss: 0.3566 - accuracy: 0.9000 - val_loss: 1.6916 - val_accuracy: 0.4900
# Epoch 21/30
# 57/57 [==============================] - 1s 20ms/step - loss: 0.3089 - accuracy: 0.9144 - val_loss: 1.7707 - val_accuracy: 0.4950
# Epoch 22/30
# 57/57 [==============================] - 1s 19ms/step - loss: 0.2513 - accuracy: 0.9389 - val_loss: 2.0796 - val_accuracy: 0.4800
# Epoch 23/30
# 57/57 [==============================] - 1s 21ms/step - loss: 0.2304 - accuracy: 0.9417 - val_loss: 2.0546 - val_accuracy: 0.4600
# Epoch 24/30
# 57/57 [==============================] - 1s 22ms/step - loss: 0.1854 - accuracy: 0.9561 - val_loss: 2.0482 - val_accuracy: 0.4750
# Epoch 25/30
# 57/57 [==============================] - 1s 24ms/step - loss: 0.1566 - accuracy: 0.9711 - val_loss: 2.0740 - val_accuracy: 0.4750
# Epoch 26/30
# 57/57 [==============================] - 1s 22ms/step - loss: 0.1316 - accuracy: 0.9778 - val_loss: 2.0951 - val_accuracy: 0.4900
# Epoch 27/30
# 57/57 [==============================] - 1s 23ms/step - loss: 0.1122 - accuracy: 0.9800 - val_loss: 2.1698 - val_accuracy: 0.4800
# Epoch 28/30
# 57/57 [==============================] - 1s 22ms/step - loss: 0.0859 - accuracy: 0.9900 - val_loss: 2.2098 - val_accuracy: 0.4500
# Epoch 29/30
# 57/57 [==============================] - 1s 22ms/step - loss: 0.0671 - accuracy: 0.9928 - val_loss: 2.1899 - val_accuracy: 0.5100
# Epoch 30/30
# 57/57 [==============================] - 1s 24ms/step - loss: 0.0538 - accuracy: 0.9972 - val_loss: 2.2821 - val_accuracy: 0.4750

# %%
get_test_accuracy(model,X_test,y_test)
# Out:
# accuracy: 0.485

# %%
import matplotlib.pyplot as plt
xvals=range(epochs)
fig,ax=plt.subplots(1,1)
ax.plot(xvals, history.history['val_accuracy'],label='validation set accuracy')
ax.plot(xvals, history.history['accuracy'],label='train set accuracy')
ax.set_xlabel('epochs')
ax.set_ylabel('accuracy')
ax.legend()

# %% [markdown]
# # Dataset augmentaton using TensorFlow data generator:
# (https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator)

# %% [markdown]
# Overfitting occurs when you have too few records relative to other parameters (e.g., predictors or features). I'm not familiar with your data, but it sounds like the subsetting is creating additional records.
#
# Data augmentation artificially increases the size of the training set by generating many realistic variants of each training instance. Data augmentation is a technique used for introducing variety in training data thereby helping to mitigate overfitting.
#
# Data augmentation makes a sample data look slightly different every time it is processed by the model. The process makes each data set appear unique to the model and prevents the model from learning the characteristics of the data sets.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    validation_split=0.1,
    zoom_range=0.5,
    fill_mode='nearest')
# compute quantities required for featurewise normalization
# (std, mean, and principal components if ZCA whitening is applied)

# %%
datagen.fit(X_train)

# %%
train_aug=datagen.flow(X_train, y_train, batch_size=32,
         subset='training',shuffle=True)

valid_aug=datagen.flow(X_train, y_train, batch_size=32,
         subset='training',shuffle=True)

# %%
def plot_images(rows,cols,sample_img_array):
    fig,axes=plt.subplots(rows,
                          cols,
                          figsize=(10,10))
    for img,ax in zip(sample_img_array,axes):
        ax.imshow(img)
    plt.show()

augmented_images = [train_aug[0][0][3] for i in range(5)]
plot_images(1,5,augmented_images)

# %% [markdown]
# #### `train_aug` is a package of X_train and y_train

# %%
X_gen,y_gen = train_aug.next()
fig, ax = plt.subplots(1, 10, figsize=(10, 1))
for i in range(10):
    ax[i].imshow(X_gen[i])

# %% [markdown]
# or ...

# %%
sample_img_array,_ = train_aug.next()
print(len(sample_img_array))
plot_images(1,5,sample_img_array[0:5])

# %%
model=get_model(X_gen[0].shape)
compile_model(model)

# %%
get_test_accuracy(model,X_test,y_test)
# Out:
# accuracy: 0.091

# %%
epochs=100
history=model.fit(train_aug,
         validation_data=valid_aug,epochs=epochs)
# Out:
# Epoch 1/100
# 57/57 [==============================] - 4s 68ms/step - loss: 2.2078 - accuracy: 0.1733 - val_loss: 2.0584 - val_accuracy: 0.2828
# Epoch 2/100
# 57/57 [==============================] - 4s 68ms/step - loss: 1.9832 - accuracy: 0.2606 - val_loss: 1.9235 - val_accuracy: 0.2972
# Epoch 3/100
# 57/57 [==============================] - 4s 71ms/step - loss: 1.8579 - accuracy: 0.3217 - val_loss: 1.7991 - val_accuracy: 0.3467
# Epoch 4/100
# 57/57 [==============================] - 4s 72ms/step - loss: 1.7872 - accuracy: 0.3406 - val_loss: 1.7778 - val_accuracy: 0.3561
# Epoch 5/100
# 57/57 [==============================] - 4s 69ms/step - loss: 1.7954 - accuracy: 0.3411 - val_loss: 1.7352 - val_accuracy: 0.3778
# Epoch 6/100
# 57/57 [==============================] - 4s 71ms/step - loss: 1.7408 - accuracy: 0.3606 - val_loss: 1.7563 - val_accuracy: 0.3672
# Epoch 7/100
# 57/57 [==============================] - 4s 67ms/step - loss: 1.7271 - accuracy: 0.3644 - val_loss: 1.7299 - val_accuracy: 0.3744
# Epoch 8/100
# 57/57 [==============================] - 4s 65ms/step - loss: 1.6676 - accuracy: 0.4111 - val_loss: 1.6563 - val_accuracy: 0.4122
# Epoch 9/100
# 57/57 [==============================] - 4s 66ms/step - loss: 1.6668 - accuracy: 0.3950 - val_loss: 1.6371 - val_accuracy: 0.4133
# Epoch 10/100
# 57/57 [==============================] - 4s 71ms/step - loss: 1.6570 - accuracy: 0.4172 - val_loss: 1.6272 - val_accuracy: 0.4056
# Epoch 11/100
# 57/57 [==============================] - 4s 69ms/step - loss: 1.6100 - accuracy: 0.4244 - val_loss: 1.5816 - val_accuracy: 0.4372
# Epoch 12/100
# 57/57 [==============================] - 4s 68ms/step - loss: 1.5966 - accuracy: 0.4278 - val_loss: 1.5789 - val_accuracy: 0.4239
# Epoch 13/100
# 57/57 [==============================] - 4s 70ms/step - loss: 1.5995 - accuracy: 0.4378 - val_loss: 1.6403 - val_accuracy: 0.4028
# Epoch 14/100
# 57/57 [==============================] - 4s 71ms/step - loss: 1.5794 - accuracy: 0.4422 - val_loss: 1.5374 - val_accuracy: 0.4550
# Epoch 15/100
# 57/57 [==============================] - 4s 72ms/step - loss: 1.5641 - accuracy: 0.4256 - val_loss: 1.4998 - val_accuracy: 0.4511
# Epoch 16/100
# 57/57 [==============================] - 4s 71ms/step - loss: 1.5397 - accuracy: 0.4467 - val_loss: 1.5115 - val_accuracy: 0.4517
# Epoch 17/100
# 57/57 [==============================] - 4s 73ms/step - loss: 1.5359 - accuracy: 0.4539 - val_loss: 1.4632 - val_accuracy: 0.4994
# Epoch 18/100
# 57/57 [==============================] - 4s 67ms/step - loss: 1.5193 - accuracy: 0.4628 - val_loss: 1.4761 - val_accuracy: 0.4828
# Epoch 19/100
# 57/57 [==============================] - 4s 66ms/step - loss: 1.4765 - accuracy: 0.4772 - val_loss: 1.4511 - val_accuracy: 0.4872
# Epoch 20/100
# 57/57 [==============================] - 4s 67ms/step - loss: 1.5071 - accuracy: 0.4672 - val_loss: 1.4596 - val_accuracy: 0.4850
# Epoch 21/100
# 57/57 [==============================] - 4s 64ms/step - loss: 1.4829 - accuracy: 0.4878 - val_loss: 1.4692 - val_accuracy: 0.4733
# Epoch 22/100
# 57/57 [==============================] - 4s 64ms/step - loss: 1.4848 - accuracy: 0.4856 - val_loss: 1.3830 - val_accuracy: 0.5061
# Epoch 23/100
# 57/57 [==============================] - 4s 66ms/step - loss: 1.4541 - accuracy: 0.4750 - val_loss: 1.5053 - val_accuracy: 0.4717
# Epoch 24/100
# 57/57 [==============================] - 4s 66ms/step - loss: 1.4600 - accuracy: 0.4700 - val_loss: 1.4460 - val_accuracy: 0.5000
# Epoch 25/100
# 57/57 [==============================] - 4s 63ms/step - loss: 1.4458 - accuracy: 0.4856 - val_loss: 1.3837 - val_accuracy: 0.5206
# Epoch 26/100
# 57/57 [==============================] - 4s 67ms/step - loss: 1.4095 - accuracy: 0.4850 - val_loss: 1.3699 - val_accuracy: 0.5128
# Epoch 27/100
# 57/57 [==============================] - 4s 66ms/step - loss: 1.3894 - accuracy: 0.5128 - val_loss: 1.3774 - val_accuracy: 0.5106
# Epoch 28/100
# 57/57 [==============================] - 4s 70ms/step - loss: 1.4060 - accuracy: 0.4972 - val_loss: 1.3411 - val_accuracy: 0.5317
# Epoch 29/100
# 57/57 [==============================] - 4s 74ms/step - loss: 1.3777 - accuracy: 0.5022 - val_loss: 1.4097 - val_accuracy: 0.5094
# Epoch 30/100
# 57/57 [==============================] - 5s 86ms/step - loss: 1.3923 - accuracy: 0.5150 - val_loss: 1.4303 - val_accuracy: 0.4917
# Epoch 31/100
# 57/57 [==============================] - 5s 79ms/step - loss: 1.4108 - accuracy: 0.5033 - val_loss: 1.3625 - val_accuracy: 0.5272
# Epoch 32/100
# 57/57 [==============================] - 5s 82ms/step - loss: 1.3264 - accuracy: 0.5228 - val_loss: 1.3213 - val_accuracy: 0.5383
# Epoch 33/100
# 57/57 [==============================] - 4s 79ms/step - loss: 1.3567 - accuracy: 0.5139 - val_loss: 1.3472 - val_accuracy: 0.5367
# Epoch 34/100
# 57/57 [==============================] - 4s 72ms/step - loss: 1.3564 - accuracy: 0.5250 - val_loss: 1.3231 - val_accuracy: 0.5167
# Epoch 35/100
# 57/57 [==============================] - 4s 71ms/step - loss: 1.3380 - accuracy: 0.5311 - val_loss: 1.2942 - val_accuracy: 0.5489
# Epoch 36/100
# 57/57 [==============================] - 4s 69ms/step - loss: 1.3408 - accuracy: 0.5256 - val_loss: 1.3201 - val_accuracy: 0.5383
# Epoch 37/100
# 57/57 [==============================] - 4s 68ms/step - loss: 1.2891 - accuracy: 0.5517 - val_loss: 1.2700 - val_accuracy: 0.5583
# Epoch 38/100
# 57/57 [==============================] - 4s 71ms/step - loss: 1.3457 - accuracy: 0.5211 - val_loss: 1.2757 - val_accuracy: 0.5472
# Epoch 39/100
# 57/57 [==============================] - 4s 73ms/step - loss: 1.3298 - accuracy: 0.5350 - val_loss: 1.2898 - val_accuracy: 0.5433
# Epoch 40/100
# 57/57 [==============================] - 4s 68ms/step - loss: 1.2976 - accuracy: 0.5367 - val_loss: 1.2299 - val_accuracy: 0.5639
# Epoch 41/100
# 57/57 [==============================] - 4s 68ms/step - loss: 1.2940 - accuracy: 0.5361 - val_loss: 1.2679 - val_accuracy: 0.5594
# Epoch 42/100
# 57/57 [==============================] - 4s 69ms/step - loss: 1.2789 - accuracy: 0.5550 - val_loss: 1.2420 - val_accuracy: 0.5550
# Epoch 43/100
# 57/57 [==============================] - 4s 68ms/step - loss: 1.2644 - accuracy: 0.5544 - val_loss: 1.2787 - val_accuracy: 0.5656
# Epoch 44/100
# 57/57 [==============================] - 4s 68ms/step - loss: 1.2893 - accuracy: 0.5333 - val_loss: 1.2166 - val_accuracy: 0.5772
# Epoch 45/100
# 57/57 [==============================] - 4s 71ms/step - loss: 1.2577 - accuracy: 0.5556 - val_loss: 1.2236 - val_accuracy: 0.5722
# Epoch 46/100
# 57/57 [==============================] - 4s 67ms/step - loss: 1.2217 - accuracy: 0.5622 - val_loss: 1.2573 - val_accuracy: 0.5494
# Epoch 47/100
# 57/57 [==============================] - 4s 67ms/step - loss: 1.2556 - accuracy: 0.5633 - val_loss: 1.1893 - val_accuracy: 0.5844
# Epoch 48/100
# 57/57 [==============================] - 4s 67ms/step - loss: 1.2488 - accuracy: 0.5561 - val_loss: 1.1911 - val_accuracy: 0.5833
# Epoch 49/100
# 57/57 [==============================] - 4s 66ms/step - loss: 1.1997 - accuracy: 0.5728 - val_loss: 1.1600 - val_accuracy: 0.6017
# Epoch 50/100
# 57/57 [==============================] - 4s 67ms/step - loss: 1.2195 - accuracy: 0.5694 - val_loss: 1.1762 - val_accuracy: 0.5933
# Epoch 51/100
# 57/57 [==============================] - 4s 67ms/step - loss: 1.2289 - accuracy: 0.5811 - val_loss: 1.1923 - val_accuracy: 0.5739
# Epoch 52/100
# 57/57 [==============================] - 4s 66ms/step - loss: 1.2289 - accuracy: 0.5711 - val_loss: 1.2400 - val_accuracy: 0.5633
# Epoch 53/100
# 57/57 [==============================] - 4s 66ms/step - loss: 1.2121 - accuracy: 0.5628 - val_loss: 1.1632 - val_accuracy: 0.5894
# Epoch 54/100
# 57/57 [==============================] - 4s 66ms/step - loss: 1.1900 - accuracy: 0.5922 - val_loss: 1.1669 - val_accuracy: 0.6000
# Epoch 55/100
# 57/57 [==============================] - 4s 66ms/step - loss: 1.2015 - accuracy: 0.5794 - val_loss: 1.1853 - val_accuracy: 0.5794
# Epoch 56/100
# 57/57 [==============================] - 4s 77ms/step - loss: 1.2094 - accuracy: 0.5894 - val_loss: 1.1722 - val_accuracy: 0.5844
# Epoch 57/100
# 57/57 [==============================] - 5s 79ms/step - loss: 1.1941 - accuracy: 0.5672 - val_loss: 1.0982 - val_accuracy: 0.6178
# Epoch 58/100
# 57/57 [==============================] - 6s 98ms/step - loss: 1.1611 - accuracy: 0.5922 - val_loss: 1.1546 - val_accuracy: 0.5894
# Epoch 59/100
# 57/57 [==============================] - 7s 127ms/step - loss: 1.1489 - accuracy: 0.6050 - val_loss: 1.1515 - val_accuracy: 0.6017
# Epoch 60/100
# 57/57 [==============================] - 4s 68ms/step - loss: 1.1819 - accuracy: 0.5800 - val_loss: 1.1410 - val_accuracy: 0.6050
# Epoch 61/100
# 57/57 [==============================] - 5s 83ms/step - loss: 1.1684 - accuracy: 0.5928 - val_loss: 1.1280 - val_accuracy: 0.5978
# Epoch 62/100
# 57/57 [==============================] - 4s 70ms/step - loss: 1.1699 - accuracy: 0.5889 - val_loss: 1.0996 - val_accuracy: 0.6100
# Epoch 63/100
# 57/57 [==============================] - 4s 66ms/step - loss: 1.1186 - accuracy: 0.6094 - val_loss: 1.0800 - val_accuracy: 0.6400
# Epoch 64/100
# 57/57 [==============================] - 4s 66ms/step - loss: 1.1504 - accuracy: 0.5867 - val_loss: 1.1272 - val_accuracy: 0.5983
# Epoch 65/100
# 57/57 [==============================] - 4s 66ms/step - loss: 1.1286 - accuracy: 0.6139 - val_loss: 1.1083 - val_accuracy: 0.6089
# Epoch 66/100
# 57/57 [==============================] - 4s 67ms/step - loss: 1.1278 - accuracy: 0.5983 - val_loss: 1.0992 - val_accuracy: 0.6100
# Epoch 67/100
# 57/57 [==============================] - 4s 71ms/step - loss: 1.1519 - accuracy: 0.6078 - val_loss: 1.0646 - val_accuracy: 0.6361
# Epoch 68/100
# 57/57 [==============================] - 4s 73ms/step - loss: 1.0941 - accuracy: 0.6094 - val_loss: 1.1071 - val_accuracy: 0.6089
# Epoch 69/100
# 57/57 [==============================] - 4s 70ms/step - loss: 1.0566 - accuracy: 0.6111 - val_loss: 1.0089 - val_accuracy: 0.6489
# Epoch 70/100
# 57/57 [==============================] - 4s 68ms/step - loss: 1.1067 - accuracy: 0.5983 - val_loss: 1.0646 - val_accuracy: 0.6250
# Epoch 71/100
# 57/57 [==============================] - 4s 71ms/step - loss: 1.0985 - accuracy: 0.6122 - val_loss: 1.0368 - val_accuracy: 0.6378
# Epoch 72/100
# 57/57 [==============================] - 4s 67ms/step - loss: 1.0958 - accuracy: 0.6122 - val_loss: 1.1202 - val_accuracy: 0.5944
# Epoch 73/100
# 57/57 [==============================] - 4s 69ms/step - loss: 1.1135 - accuracy: 0.6217 - val_loss: 1.0417 - val_accuracy: 0.6389
# Epoch 74/100
# 57/57 [==============================] - 4s 70ms/step - loss: 1.0918 - accuracy: 0.6189 - val_loss: 1.0826 - val_accuracy: 0.6194
# Epoch 75/100
# 57/57 [==============================] - 4s 70ms/step - loss: 1.0930 - accuracy: 0.6228 - val_loss: 1.0572 - val_accuracy: 0.6228
# Epoch 76/100
# 57/57 [==============================] - 4s 74ms/step - loss: 1.1050 - accuracy: 0.6100 - val_loss: 1.0099 - val_accuracy: 0.6544
# Epoch 77/100
# 57/57 [==============================] - 4s 67ms/step - loss: 1.0692 - accuracy: 0.6089 - val_loss: 1.0185 - val_accuracy: 0.6478
# Epoch 78/100
# 57/57 [==============================] - 4s 68ms/step - loss: 1.1088 - accuracy: 0.5933 - val_loss: 1.0236 - val_accuracy: 0.6422
# Epoch 79/100
# 57/57 [==============================] - 4s 69ms/step - loss: 1.0788 - accuracy: 0.6217 - val_loss: 1.0151 - val_accuracy: 0.6522
# Epoch 80/100
# 57/57 [==============================] - 4s 75ms/step - loss: 1.0414 - accuracy: 0.6261 - val_loss: 1.0037 - val_accuracy: 0.6506
# Epoch 81/100
# 57/57 [==============================] - 4s 67ms/step - loss: 1.0529 - accuracy: 0.6361 - val_loss: 0.9899 - val_accuracy: 0.6517
# Epoch 82/100
# 57/57 [==============================] - 4s 72ms/step - loss: 1.0540 - accuracy: 0.6272 - val_loss: 1.0136 - val_accuracy: 0.6456
# Epoch 83/100
# 57/57 [==============================] - 4s 69ms/step - loss: 1.0578 - accuracy: 0.6267 - val_loss: 1.0061 - val_accuracy: 0.6400
# Epoch 84/100
# 57/57 [==============================] - 4s 65ms/step - loss: 1.0555 - accuracy: 0.6261 - val_loss: 1.0417 - val_accuracy: 0.6267
# Epoch 85/100
# 57/57 [==============================] - 4s 68ms/step - loss: 1.0658 - accuracy: 0.6322 - val_loss: 0.9969 - val_accuracy: 0.6383
# Epoch 86/100
# 57/57 [==============================] - 4s 72ms/step - loss: 1.0264 - accuracy: 0.6483 - val_loss: 1.0066 - val_accuracy: 0.6406
# Epoch 87/100
# 57/57 [==============================] - 4s 69ms/step - loss: 1.0290 - accuracy: 0.6283 - val_loss: 1.0043 - val_accuracy: 0.6528
# Epoch 88/100
# 57/57 [==============================] - 4s 67ms/step - loss: 1.0046 - accuracy: 0.6350 - val_loss: 1.0243 - val_accuracy: 0.6467
# Epoch 89/100
# 57/57 [==============================] - 4s 69ms/step - loss: 1.0239 - accuracy: 0.6389 - val_loss: 1.0306 - val_accuracy: 0.6422
# Epoch 90/100
# 57/57 [==============================] - 4s 68ms/step - loss: 1.0728 - accuracy: 0.6161 - val_loss: 0.9703 - val_accuracy: 0.6628
# Epoch 91/100
# 57/57 [==============================] - 4s 67ms/step - loss: 1.0260 - accuracy: 0.6239 - val_loss: 0.9773 - val_accuracy: 0.6611
# Epoch 92/100
# 57/57 [==============================] - 4s 67ms/step - loss: 1.0023 - accuracy: 0.6333 - val_loss: 0.9600 - val_accuracy: 0.6700
# Epoch 93/100
# 57/57 [==============================] - 4s 67ms/step - loss: 0.9623 - accuracy: 0.6506 - val_loss: 0.9827 - val_accuracy: 0.6400
# Epoch 94/100
# 57/57 [==============================] - 4s 71ms/step - loss: 0.9912 - accuracy: 0.6494 - val_loss: 1.0019 - val_accuracy: 0.6372
# Epoch 95/100
# 57/57 [==============================] - 4s 66ms/step - loss: 1.0009 - accuracy: 0.6494 - val_loss: 0.9572 - val_accuracy: 0.6650
# Epoch 96/100
# 57/57 [==============================] - 4s 67ms/step - loss: 1.0091 - accuracy: 0.6539 - val_loss: 0.9096 - val_accuracy: 0.6828
# Epoch 97/100
# 57/57 [==============================] - 4s 65ms/step - loss: 0.9824 - accuracy: 0.6589 - val_loss: 0.9257 - val_accuracy: 0.6706
# Epoch 98/100
# 57/57 [==============================] - 4s 66ms/step - loss: 0.9812 - accuracy: 0.6606 - val_loss: 0.9005 - val_accuracy: 0.6933
# Epoch 99/100
# 57/57 [==============================] - 4s 66ms/step - loss: 0.9837 - accuracy: 0.6672 - val_loss: 0.9341 - val_accuracy: 0.6717
# Epoch 100/100
# 57/57 [==============================] - 4s 67ms/step - loss: 0.9696 - accuracy: 0.6622 - val_loss: 0.9450 - val_accuracy: 0.6672

# %%
import matplotlib.pyplot as plt
xvals=range(epochs)
fig,ax=plt.subplots(1,1)
ax.plot(xvals, history.history['val_accuracy'],label='validation set accuracy')
ax.plot(xvals, history.history['accuracy'],label='train set accuracy')
ax.set_xlabel('epochs')
ax.set_ylabel('accuracy')
ax.legend()

# %%
get_test_accuracy(model,X_test,y_test)
# Out:
# accuracy: 0.545

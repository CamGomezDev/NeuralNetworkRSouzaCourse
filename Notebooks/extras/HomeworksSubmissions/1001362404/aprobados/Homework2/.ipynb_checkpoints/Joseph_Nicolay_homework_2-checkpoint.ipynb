# %% [markdown]
# # To do the following exercises you need to know how to use:
# * pandas dataframes
# * dictionaries
# * plotting array of images
# * convert data to .to_numpy()
# * assign inputs (features) to **X_data**
# * assign outputs (labels/targets) to **y_data**
# * understand the output of attribute .shape (dimensions of the data)
# * generate random integers np.random.randint()
# * convert color image to grayscale

# %% [markdown]
# # Exercise 1
# * the file 'mnist_test.csv' contains 10000 images of digits in grayscale saved as a rows in the csv file
# * first column contains value of the digits then 784 columns correspond to pixels
# * make an array of plots of 25 randomly chosen images (5x5)
# * each plot has to have a title corresponding to a digit

# %%
#This command allow us to see what file we have in folder
# !ls
# Out:
# Joseph_Nicolay_homework_2.ipynb  mnist_test.csv

# %% [markdown]
# ## Solution E1

# %%
#Import libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Read image file using pandas

mnist_test = pd.read_csv("mnist_test.csv")
#mnist_test

# %%
#Convert pandas dataframe to numpy array

X_data = mnist_test.loc[:,'1x1':'28x28'].to_numpy().reshape((10000, 28, 28))
y_data = mnist_test.loc[:,'label'].to_numpy()

#Choose n_rows and n_columns as you prefer
n_rows = 5
n_columns = 5

#Random selection of a sample of size 25
random_sample = np.random.randint(0, X_data.shape[0], size=(n_rows*n_columns)).reshape(n_rows,n_columns)

#Plotting digits in a figure n_rows x n_columns

fig, ax = plt.subplots(n_rows, n_columns, figsize=(8,8))

for i in range(n_rows):
    for j in range(n_columns):
        
        ax[i][j].set_title("Digit " + str(y_data[random_sample[i][j]]))
        ax[i][j].imshow(X_data[random_sample[i][j]], cmap="gray")
        ax[i][j].axis('off')

fig.tight_layout(pad=1.0)

# %% [markdown]
# # Exercise 2
#
# * Sklearn digits dataset (https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_digits.html) contains 1797 images of digits in grayscale
# * download the dataset (command is below) and:
# * make an array of plots of 25 randomly chosen images (5 images x 5 images)
# * each plot has to have a title corresponding to a digit

# %% [markdown]
# ## Solution E2

# %%
#Charging library of datasets dictionaries
from sklearn import datasets
#Choose 'load_digits'
digits = datasets.load_digits() # digits is a dictionary

# %%
#Convert dataset dictionary to numpy array

X_data = digits['data'].reshape((digits['data'].shape[0], 8, 8))
y_data = digits['target']

#Choose n_rows and n_columns as you prefer
n_rows = 5
n_columns = 5

#Random selection of a sample of size 25
random_sample = np.random.randint(0, X_data.shape[0], size=(n_rows*n_columns)).reshape(n_rows,n_columns)

#Plotting digits in a figure n_rows x n_columns

fig, ax = plt.subplots(n_rows, n_columns, figsize=(8,8))

for i in range(n_rows):
    for j in range(n_columns):
        
        ax[i][j].set_title("Digit " + str(y_data[random_sample[i][j]]))
        ax[i][j].imshow(X_data[random_sample[i][j]], cmap="gray")
        ax[i][j].axis('off')

fig.tight_layout(pad=1.0)

# %% [markdown]
# # Exercise 3
# The CIFAR-10 dataset consists of, in total, 60000 **color** (three channels) images, each with one of 10 labels: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck. For an introduction and a download.
#
# http://www.cs.toronto.edu/~kriz/cifar.html
#
# * make an array of plots of 25 randomly chosen images (5 images x 5 images)
# * each plot has to have a title with a corresponding label
#
#
#
# * convert the color images to grayscale by averaging one of the dimensions and again display the images
#
#
# * make an array of plots of 25 randomly chosen images (5 images x 5 images)
# * each plot has to have a title with a corresponding label

# %%
import tensorflow as tf
(X_data, y_data), (_, _) = tf.keras.datasets.cifar10.load_data()

# %%
X_data.shape
# Out:
# (50000, 32, 32, 3)

# %%
labels = {
    0: "airplane",
    1: "automobile",
    2: "bird",
    3: "cat",
    4: "deer",
    5: "dog",
    6: "frog",
    7: "horse",
    8: "ship",
    9: "truck"
}

# %%
#Choose n_rows and n_columns as you prefer
n_rows = 5
n_columns = 5

#Random selection of a sample of size 25
random_sample = np.random.randint(0, X_data.shape[0], size=(n_rows*n_columns)).reshape(n_rows,n_columns)

#Plotting digits in a figure n_rows x n_columns

fig, ax = plt.subplots(n_rows, n_columns, figsize=(8,8))

for i in range(n_rows):
    for j in range(n_columns):
        
        ax[i][j].set_title("Name: " + labels[int(y_data[random_sample[i][j]])])
        ax[i][j].imshow(X_data[random_sample[i][j]])
        ax[i][j].axis('off')

fig.tight_layout(pad=1.0)

# %%
X_data_g = np.average(X_data, axis=3)

#Choose n_rows and n_columns as you prefer
n_rows = 5
n_columns = 5

#Random selection of a sample of size 25
random_sample = np.random.randint(0, X_data.shape[0], size=(n_rows*n_columns)).reshape(n_rows,n_columns)

#Plotting digits in a figure n_rows x n_columns

fig, ax = plt.subplots(n_rows, n_columns, figsize=(8,8))

for i in range(n_rows):
    for j in range(n_columns):
        
        ax[i][j].set_title("Name: " + labels[int(y_data[random_sample[i][j]])])
        ax[i][j].imshow(X_data_g[random_sample[i][j]], cmap='gray')
        ax[i][j].axis('off')

fig.tight_layout(pad=1.0)

# %%
# excelent work!

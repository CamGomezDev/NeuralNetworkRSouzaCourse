# %% [markdown]
# # Homework 7
# ### MODELADO DE DATOS CON REDES NEURONALES
# *Professor:* Michal Hemmerling \
# *e-mail:* michal.hemmerling@udea.edu.co
#
# *Student:* Camilo José Torres Castaño \
# *e-mail:* cjose.torres@udea.edu.co \
# *C.c.* 1036401258

# %% [markdown]
# Teach a NN model to predict the prices of the houses from the `kc_house_data.csv'` dataset.

# %% [markdown]
# * clean the data (NaN, repeated values, correlation...)
# ***I forgot to mention that the target (here `price`) should not be taken into account when making the correlation matrix***!!
# * remove outliers (very large, very small values)
# * split into train and test
# * use functions:
#   * `get_model(input_shape)`
#   * `get_regularized_model(input_shape,weight_decay,drop_ate)`
#   * `compile_model()`
# * use `metrics=['mape']` when compiling model
# * `scores=model.evaluate(X_test,y_test)` should return mean absolute percentage error
# * use ModelCheckpoint() callback to save the entire model into `.h5` file
# * (you can possibly normalize the data before training the algorithm) check this out

# %% [markdown]
#     * "id": Numero de identificacion de la vivienda
#     * "Date": Fecha en que se vendió la casa
#     * "Price": el precio es el objetivo de predicción
#     * "Bedrooms": Número de Dormitorios/Casa
#     * "Bathrooms": Número de baños/Casa
#     * "Sqft_Living": pies cuadrados de la casa
#     * "Sqft_Lot": pies cuadrados del lote
#     * "Floors": Total de pisos oniveles) en casa
#     * "Waterfront": Casa que tiene vista a la costanera
#     * "View": Ha sido visto
#     * "Condition": Qué tan buena es la condición ogeneral)
#     * "Grade": calificación de vivienda, según el sistema del condado de King
#     * "Sqft_above": pies cuadrados de la casa aparte del sótano
#     * "Sqft_Basement": pies cuadrados del sótano
#     * "Yr_Built": año de construcción
#     * "Yr_Renovated": año en que se renovó la casa
#     * "Zipcode": código postal
#     * "Lat": Coordenada de latitud
#     * "Long": Coordenada de longitud
#     * "Sqft_Living15": Área de la sala de estar en 2015 oimplica algunas renovaciones)
#     * "Sqft_Lot15": área del tamaño del lote en 2015 oimplica algunas renovaciones)

# %% [markdown]
# 1. Importar, leer e inspeccionar los datos
#   * `df.head()`
#   * `df.tail()`
#   * `df.columns()`
#   * `df.describe()`
#   * `df.info()`
#   * `df.loc[mascara]` - selecione filas usando "mascara" (ejemplo de mascara (condicion logica): `df['id']>100`)
# 2. Completar los datos y organizar las columnas
#   * `df.merge()`
#   * `df[df.duplicated()] ` - visualiza filas con valores duplicadas atraves todas columnas
#   * `df.drop_duplicates(subset=['nombre_columna'])` - eliminar valor duplicadas en la columna
#   * `df.drop(['nombre_columna'], axis=1)`           - eliminar columnas innecesarias o repetidas usando funcion
#   * `df['nueva_columna']=df['nueva_columna']/10.764` añadir otros nuevos (utilizando cálculos)
#   * `df.rename(columns={'nombre_columna_vieja': 'nombre_columna_nueva'})` cambiar el nombre de las columna
#   * `df['nombre_columna'] = df['nombre_columna'].astype(str)` cambiar tipo de valores de la columna
# 3. Comprobar de los tipos de datos y eliminar de los valores repetidos, y `Nan`
#   * `df.info()`
#   * `df.isnull().sum()` - soma de todas valores vacios en cada columna
#   * `df.isna().sum()`  - soma de todas valores NaN en cada columna
#   * `df['sqft_lot'].isnull()` - mascara logica de todos valores null util combinando con `df[mascara]`
#   * `df.dropna()` - elimina valores Nan, parametro `axis=0` significa eliminar todas filas con valor NaN
# 4. Revisar y comprender los datos
#   * `df['nombre_columna'].unique()`      - visualizar valores uniqas de la columna
#   * `df['nombre_columna'].value_counts()` - sumar frequencia de valores de la columna (se usa para columnas con valores discretos)
#   * `df.groupby(['nombre_columna_1','nombre_columna_1']).mean()`
#   * `df['nombre_columna'].nlargest(10)` - visualiza 10 mas grandes valore numericas de la columna
#   * `df.info()`
#   * `df.describe()`
# 5. Compruebar la correlación entre variables y eliminar las que tengan una correlación superior a 0,8
#   * `corr()`
# 6. Buscar y eliminar valores atípicos
#   * mirar las estadísticas de `df.describe()` max() min()
#   * `df.groupby`
#   * histogramas
#   * IQR y boxplot `seaborn.boxplot()`
# 7. Comprobar la normalidad de la distribución de continua variable
#   * `distplot()`
# 8. Búscar de linealidad y relación general entre variables
#   * `pairplot()`
# 9. Identificar de variables categóricas
#   * `matplotlib.scatter_plot()`
#   * `seaborn.scatter_plot()`
# 10. Extraer otras informaciónes válida, por ejemplo usando series de tiempo (time series )
#   * `pandas.to_datetime()`
#   * `pandas.DatetimeIndex()`

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt #visualisation
import seaborn as sns           #visualisation

# %% [markdown]
# ## 1. Importar, leer e inspeccionar los datos

# %%
import pandas as pd
df=pd.read_csv('kc_house_data.csv',sep=',')

# %%
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0    5650.0     1.0           0     0  ...      7        1180              0
# 1    7242.0     2.0           0     0  ...      7        2170            400
# 2   10000.0     1.0           0     0  ...      6         770              0
# 3    5000.0     1.0           0     0  ...      7        1050            910
# 4    8080.0     1.0           0     0  ...      8        1680              0
# 5  101930.0     1.0           0     0  ...     11        3890           1530
# 6    6819.0     2.0           0     0  ...      7        1715              0
# 7    9711.0     1.0           0     0  ...      7        1060              0
# 8    7470.0     1.0           0     0  ...      7        1050            730
# 9    6560.0     2.0           0     0  ...      7        1890              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
# 5      2001             0    98053  47.6561 -122.005           4760
# 6      1995             0    98003  47.3097 -122.327           2238
# 7      1963             0    98198  47.4095 -122.315           1650
# 8      1960             0    98146  47.5123 -122.337           1780
# 9      2003             0    98038  47.3684 -122.031           2390
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
# 5      101930
# 6        6819
# 7        9711
# 8        8113
# 9        7570
#
# [10 rows x 21 columns]

# %%
# !ls
# Out:
# HousePrices.h5	 homework_07-Copy1.ipynb  kc_house_data.csv
# HousePrices2.h5  homework_07.ipynb

# %%
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21610   263000018  20140521T000000  360000.0         3       2.50
# 21611  6600060120  20150223T000000  400000.0         4       2.50
# 21612  1523300141  20140623T000000  402101.0         2       0.75
# 21613   291310100  20150116T000000  400000.0         3       2.50
# 21614  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21610         1530    1131.0     3.0           0     0  ...      8
# 21611         2310    5813.0     2.0           0     0  ...      8
# 21612         1020    1350.0     2.0           0     0  ...      7
# 21613         1600    2388.0     2.0           0     0  ...      8
# 21614         1020    1076.0     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21610        1530              0      2009             0    98103  47.6993
# 21611        2310              0      2014             0    98146  47.5107
# 21612        1020              0      2009             0    98144  47.5944
# 21613        1600              0      2004             0    98027  47.5345
# 21614        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 21610 -122.346           1530        1509
# 21611 -122.362           1830        7200
# 21612 -122.299           1020        2007
# 21613 -122.069           1410        1287
# 21614 -122.299           1020        1357
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (21615, 21)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161500e+04  2.161500e+04  21615.000000  21615.000000  21615.000000
# mean   4.579945e+09  5.400672e+05      3.370807      2.114724   2079.874763
# std    2.876672e+09  3.671167e+05      0.930026      0.770136    918.402073
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.215000e+05      3.000000      1.750000   1428.500000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161400e+04  21615.000000  21615.000000  21615.000000  21615.000000
# mean   1.511002e+04      1.494263      0.007541      0.234282      3.409577
# std    4.142026e+04      0.539985      0.086513      0.766285      0.650893
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.620000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.069350e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21615.000000  21615.000000   21615.000000  21615.000000  21615.000000
# mean       7.656812   1788.337173     291.537590   1971.005968     84.394448
# std        1.175421    828.071354     442.564514     29.372179    401.661476
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21615.000000  21615.000000  21615.000000   21615.000000   21615.000000
# mean   98077.936109     47.560039   -122.213873    1986.521351   12779.768864
# std       53.503930      0.138565      0.140843     685.367239   27328.234764
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.470850   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10085.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21615 entries, 0 to 21614
# Data columns (total 21 columns):
# id               21615 non-null int64
# date             21615 non-null object
# price            21615 non-null float64
# bedrooms         21615 non-null int64
# bathrooms        21615 non-null float64
# sqft_living      21615 non-null int64
# sqft_lot         21614 non-null float64
# floors           21615 non-null float64
# waterfront       21615 non-null int64
# view             21615 non-null int64
# condition        21615 non-null int64
# grade            21615 non-null int64
# sqft_above       21615 non-null int64
# sqft_basement    21615 non-null int64
# yr_built         21615 non-null int64
# yr_renovated     21615 non-null int64
# zipcode          21615 non-null int64
# lat              21615 non-null float64
# long             21615 non-null float64
# sqft_living15    21615 non-null int64
# sqft_lot15       21615 non-null int64
# dtypes: float64(6), int64(14), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# ## 2. Completar los datos y organizar las columnas

# %%
df[df.duplicated()]
# Out:
#             id             date     price  bedrooms  bathrooms  sqft_living  \
# 99   722079104  20140711T000000  314000.0         3       1.75         1810
# 100  722079104  20140711T000000  314000.0         3       1.75         1810
#
#      sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 99    41800.0     1.0           0     0  ...      7        1210
# 100   41800.0     1.0           0     0  ...      7        1210
#
#      sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 99             600      1980             0    98038  47.4109 -121.958
# 100            600      1980             0    98038  47.4109 -121.958
#
#      sqft_living15  sqft_lot15
# 99            1650      135036
# 100           1650      135036
#
# [2 rows x 21 columns]

# %%
df.iloc[99]
# Out:
# id                     722079104
# date             20140711T000000
# price                     314000
# bedrooms                       3
# bathrooms                   1.75
# sqft_living                 1810
# sqft_lot                   41800
# floors                         1
# waterfront                     0
# view                           0
# condition                      5
# grade                          7
# sqft_above                  1210
# sqft_basement                600
# yr_built                    1980
# yr_renovated                   0
# zipcode                    98038
# lat                      47.4109
# long                    -121.958
# sqft_living15               1650
# sqft_lot15                135036
# Name: 99, dtype: object

# %%
df = df.drop_duplicates()

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ## 3. Comprobar de los tipos de datos y eliminar de los valores repetidos, y Nan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21613 entries, 0 to 21614
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21612 non-null float64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# dtypes: float64(6), int64(14), object(1)
# memory usage: 3.6+ MB

# %% [markdown]
# ### Drop null values

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         1
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df[df['sqft_lot'].isnull()==True]
# Out:
#              id             date     price  bedrooms  bathrooms  sqft_living  \
# 109  3530510041  20140723T000000  188500.0         2       1.75         1240
#
#      sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 109       NaN     1.0           0     0  ...      8        1240
#
#      sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 109              0      1985             0    98198  47.3813 -122.322
#
#      sqft_living15  sqft_lot15
# 109           1270        4966
#
# [1 rows x 21 columns]

# %%
df = df.drop(df[df['sqft_lot'].isnull()==True].index,axis=0)

# %%
df[df['sqft_lot'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.shape
# Out:
# (21612, 21)

# %% [markdown]
# ### Drop NaN values

# %%
df.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.dropna(axis=0)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21610   263000018  20140521T000000  360000.0         3       2.50
# 21611  6600060120  20150223T000000  400000.0         4       2.50
# 21612  1523300141  20140623T000000  402101.0         2       0.75
# 21613   291310100  20150116T000000  400000.0         3       2.50
# 21614  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180    5650.0     1.0           0     0  ...      7
# 1             2570    7242.0     2.0           0     0  ...      7
# 2              770   10000.0     1.0           0     0  ...      6
# 3             1960    5000.0     1.0           0     0  ...      7
# 4             1680    8080.0     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21610         1530    1131.0     3.0           0     0  ...      8
# 21611         2310    5813.0     2.0           0     0  ...      8
# 21612         1020    1350.0     2.0           0     0  ...      7
# 21613         1600    2388.0     2.0           0     0  ...      8
# 21614         1020    1076.0     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21610        1530              0      2009             0    98103  47.6993
# 21611        2310              0      2014             0    98146  47.5107
# 21612        1020              0      2009             0    98144  47.5944
# 21613        1600              0      2004             0    98027  47.5345
# 21614        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21610 -122.346           1530        1509
# 21611 -122.362           1830        7200
# 21612 -122.299           1020        2007
# 21613 -122.069           1410        1287
# 21614 -122.299           1020        1357
#
# [21612 rows x 21 columns]

# %% [markdown]
# ## 4. Revisar y comprender los datos

# %%
df['floors'].value_counts()
# Out:
# 1.0    10679
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
df['price'].nlargest(10)
# Out:
# 7254    7700000.0
# 3916    7062500.0
# 9256    6885000.0
# 4413    5570000.0
# 1450    5350000.0
# 1317    5300000.0
# 1166    5110800.0
# 8094    4668000.0
# 2628    4500000.0
# 8640    4489000.0
# Name: price, dtype: float64

# %%
df.groupby(['bedrooms']).mean()['price']
# Out:
# bedrooms
# 0     4.095038e+05
# 1     3.176429e+05
# 2     4.014498e+05
# 3     4.662321e+05
# 4     6.354195e+05
# 5     7.865998e+05
# 6     8.255206e+05
# 7     9.511847e+05
# 8     1.105077e+06
# 9     8.939998e+05
# 10    8.193333e+05
# 11    5.200000e+05
# 33    6.400000e+05
# Name: price, dtype: float64

# %%
fig = plt.figure(figsize=(12,8))
fig.add_subplot(2,1,1)
sns.distplot(df['price'])
fig.add_subplot(2,1,2)
sns.boxplot(x=df['price'])
plt.tight_layout()
# Out:
# /home/michal/.local/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fig = plt.figure(figsize=(16,5))
fig.add_subplot(2,2,1)
sns.scatterplot(x=df['sqft_above'], y=df['price'])
fig.add_subplot(2,2,2)
sns.scatterplot(x=df['sqft_lot'],y=df['price'])
fig.add_subplot(2,2,3)
sns.scatterplot(x=df['sqft_living'],y=df['price'])
fig.add_subplot(2,2,4)
sns.scatterplot(x=df['sqft_basement'],y=df['price'])

plt.tight_layout()

# %%
fig = plt.figure(figsize=(15,7))
fig.add_subplot(2,2,1)
sns.countplot(x=df['bedrooms'])
fig.add_subplot(2,2,2)
sns.countplot(x=df['floors'])
fig.add_subplot(2,2,3)
sns.countplot(x=df['bathrooms'])
fig.add_subplot(2,2,4)
sns.countplot(x=df['grade'])
plt.tight_layout()

# %% [markdown]
# ## 5. Compruebar la correlación entre variables y eliminar las que tengan una correlación superior a 0,8

# %% [markdown]
# ## Correlation

# %%
plt.figure(figsize=(20,10))
correlation_values= df.corr()
sns.heatmap(correlation_values,cmap='BrBG',annot=True)
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (21612, 21)

# %%
df = df.drop(['sqft_above'],axis=1)

# %%
df.shape
# Out:
# (21612, 20)

# %% [markdown]
# ## 6. Buscar y eliminar valores atípicos

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161200e+04  2.161200e+04  21612.000000  21612.000000  21612.000000
# mean   4.580350e+09  5.401044e+05      3.370905      2.114774   2079.938599
# std    2.876623e+09  3.671279e+05      0.930037      0.770177    918.444375
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219875e+05      3.000000      1.750000   1429.250000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161200e+04  21612.000000  21612.000000  21612.000000  21612.000000
# mean   1.510755e+04      1.494332      0.007542      0.234314      3.409402
# std    4.142138e+04      0.539991      0.086519      0.766334      0.650746
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.619000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068825e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade  sqft_basement      yr_built  yr_renovated       zipcode  \
# count  21612.000000   21612.000000  21612.000000  21612.000000  21612.000000
# mean       7.656857     291.522534   1971.004488     84.406163  98077.934249
# std        1.175484     442.580840     29.373936    401.688123     53.500031
# min        1.000000       0.000000   1900.000000      0.000000  98001.000000
# 25%        7.000000       0.000000   1951.000000      0.000000  98033.000000
# 50%        7.000000       0.000000   1975.000000      0.000000  98065.000000
# 75%        8.000000     560.000000   1997.000000      0.000000  98118.000000
# max       13.000000    4820.000000   2015.000000   2015.000000  98199.000000
#
#                 lat          long  sqft_living15     sqft_lot15
# count  21612.000000  21612.000000   21612.000000   21612.000000
# mean      47.560061   -122.213891    1986.585647   12768.816676
# std        0.138562      0.140830     685.389829   27304.759757
# min       47.155900   -122.519000     399.000000     651.000000
# 25%       47.471075   -122.328000    1490.000000    5100.000000
# 50%       47.571800   -122.230000    1840.000000    7620.000000
# 75%       47.678000   -122.125000    2360.000000   10083.250000
# max       47.777600   -121.315000    6210.000000  871200.000000

# %%
q1 = df.quantile(0.25)
q3 = df.quantile(0.75)

IQR = q3 - q1

qu = q3 + IQR*1.5
ql = q1 - IQR*1.5

df_out =df[~((df>qu) | (df<ql)).any(axis=1)]
df_out
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# 6      1321400060  20140627T000000  257500.0         3       2.25
# ...           ...              ...       ...       ...        ...
# 21610   263000018  20140521T000000  360000.0         3       2.50
# 21611  6600060120  20150223T000000  400000.0         4       2.50
# 21612  1523300141  20140623T000000  402101.0         2       0.75
# 21613   291310100  20150116T000000  400000.0         3       2.50
# 21614  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 0             1180    5650.0     1.0           0     0          3      7
# 2              770   10000.0     1.0           0     0          3      6
# 3             1960    5000.0     1.0           0     0          5      7
# 4             1680    8080.0     1.0           0     0          3      8
# 6             1715    6819.0     2.0           0     0          3      7
# ...            ...       ...     ...         ...   ...        ...    ...
# 21610         1530    1131.0     3.0           0     0          3      8
# 21611         2310    5813.0     2.0           0     0          3      8
# 21612         1020    1350.0     2.0           0     0          3      7
# 21613         1600    2388.0     2.0           0     0          3      8
# 21614         1020    1076.0     2.0           0     0          3      7
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0                  0      1955             0    98178  47.5112 -122.257
# 2                  0      1933             0    98028  47.7379 -122.233
# 3                910      1965             0    98136  47.5208 -122.393
# 4                  0      1987             0    98074  47.6168 -122.045
# 6                  0      1995             0    98003  47.3097 -122.327
# ...              ...       ...           ...      ...      ...      ...
# 21610              0      2009             0    98103  47.6993 -122.346
# 21611              0      2014             0    98146  47.5107 -122.362
# 21612              0      2009             0    98144  47.5944 -122.299
# 21613              0      2004             0    98027  47.5345 -122.069
# 21614              0      2008             0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 0               1340        5650
# 2               2720        8062
# 3               1360        5000
# 4               1800        7503
# 6               2238        6819
# ...              ...         ...
# 21610           1530        1509
# 21611           1830        7200
# 21612           1020        2007
# 21613           1410        1287
# 21614           1020        1357
#
# [14958 rows x 20 columns]

# %%
sns.boxplot(x=df['price'])
# Out:
# <AxesSubplot:xlabel='price'>

# %%
df=df[df['price']<6000000]
df.shape
# Out:
# (21609, 20)

# %%
fig = plt.figure(figsize=(10,5))
fig.add_subplot(2,1,1)
sns.boxplot(x=df['bedrooms'])
fig.add_subplot(2,1,2)
sns.scatterplot(x=df['bedrooms'],y=df['price'])
plt.tight_layout()

# %%
df=df[df['bedrooms']<15]
df.shape
# Out:
# (21608, 20)

# %%
fig = plt.figure(figsize=(10,5))
fig.add_subplot(2,1,1)
sns.boxplot(x=df['bathrooms'])
fig.add_subplot(2,1,2)
sns.scatterplot(x=df['bathrooms'],y=df['price'])
plt.tight_layout()

# %%
df=df[df['bathrooms']<8]
df.shape
# Out:
# (21607, 20)

# %%
fig = plt.figure(figsize=(10,5))
fig.add_subplot(2,1,1)
sns.boxplot(x=df['sqft_living'])
fig.add_subplot(2,1,2)
sns.scatterplot(x=df['sqft_living'],y=df['price'])
plt.tight_layout()

# %%
df=df[df['sqft_living']<12000]
df.shape
# Out:
# (21607, 20)

# %%
fig = plt.figure(figsize=(10,5))
fig.add_subplot(2,1,1)
sns.boxplot(x=df['sqft_lot'])
fig.add_subplot(2,1,2)
sns.scatterplot(x=df['sqft_lot'],y=df['price'])
plt.tight_layout()

# %%
df=df[df['sqft_lot']<1.25e+6]
df.shape
# Out:
# (21606, 20)

# %%
fig = plt.figure(figsize=(10,5))
fig.add_subplot(2,1,1)
sns.boxplot(x=df['yr_built'])
fig.add_subplot(2,1,2)
sns.scatterplot(x=df['yr_built'],y=df['price'])
plt.tight_layout()

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.160600e+04  2.160600e+04  21606.000000  21606.000000  21606.000000
# mean   4.580214e+09  5.390849e+05      3.369018      2.113927   2078.274229
# std    2.876361e+09  3.584304e+05      0.907293      0.767029    909.559150
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.216125e+05      3.000000      1.750000   1427.750000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  5.570000e+06     11.000000      7.500000   9640.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.160600e+04  21606.000000  21606.000000  21606.000000  21606.000000
# mean   1.501634e+04      1.494215      0.007498      0.233639      3.409331
# std    3.985308e+04      0.539883      0.086267      0.765024      0.650703
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.617000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068350e+04      2.000000      0.000000      0.000000      4.000000
# max    1.164794e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade  sqft_basement      yr_built  yr_renovated       zipcode  \
# count  21606.000000   21606.000000  21606.000000  21606.000000  21606.000000
# mean       7.656114     291.067528   1971.009534     84.245025  98077.940942
# std        1.173867     441.076412     29.370495    401.321870     53.502294
# min        1.000000       0.000000   1900.000000      0.000000  98001.000000
# 25%        7.000000       0.000000   1951.000000      0.000000  98033.000000
# 50%        7.000000       0.000000   1975.000000      0.000000  98065.000000
# 75%        8.000000     560.000000   1997.000000      0.000000  98118.000000
# max       13.000000    4820.000000   2015.000000   2015.000000  98199.000000
#
#                 lat          long  sqft_living15     sqft_lot15
# count  21606.000000  21606.000000   21606.000000   21606.000000
# mean      47.560054   -122.213899    1986.158428   12738.804314
# std        0.138555      0.140830     684.705490   27126.921499
# min       47.155900   -122.519000     399.000000     651.000000
# 25%       47.471025   -122.328000    1490.000000    5100.000000
# 50%       47.571800   -122.230000    1840.000000    7620.000000
# 75%       47.678000   -122.125000    2360.000000   10082.250000
# max       47.777600   -121.315000    6210.000000  871200.000000

# %% [markdown]
# ## 7. Comprobar la normalidad de la distribución de continua variable

# %%
sns.distplot(np.log(df.price))
# Out:
# /home/michal/.local/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# ## 8. Búscar de linealidad y relación general entre variables

# %%
sns.jointplot(x='sqft_living', y='price',data=df, kind='reg')

# %%
sns.jointplot(x='sqft_lot', y='price',data=df, kind='reg')

# %%
sns.jointplot(x='sqft_basement', y='price',data=df, kind='reg')

# %%
sns.jointplot(x='sqft_living15', y='price',data=df, kind='reg')

# %%
sns.jointplot(x='sqft_lot15', y='price',data=df, kind='reg')

# %%
#sns.pairplot(df)

# %% [markdown]
# ## 9. Identificar de variables categóricas

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(df['bedrooms'], df['price'])
ax.set_xlabel('bedrooms')
ax.set_ylabel('price')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(df['bathrooms'], df['price'])
ax.set_xlabel('bathrooms')
ax.set_ylabel('price')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(df['floors'], df['price'])
ax.set_xlabel('floors')
ax.set_ylabel('price')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(df['condition'], df['price'])
ax.set_xlabel('condition')
ax.set_ylabel('price')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(df['grade'], df['price'])
ax.set_xlabel('grade')
ax.set_ylabel('price')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(df['view'], df['price'])
ax.set_xlabel('view')
ax.set_ylabel('price')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(df['waterfront'], df['price'])
ax.set_xlabel('waterfront')
ax.set_ylabel('price')
plt.show()

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_basement  \
# 0    5650.0     1.0           0     0          3      7              0
# 1    7242.0     2.0           0     0          3      7            400
# 2   10000.0     1.0           0     0          3      6              0
# 3    5000.0     1.0           0     0          5      7            910
# 4    8080.0     1.0           0     0          3      8              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503

# %% [markdown]
# ## 10. Extraer otras informaciónes válida, por ejemplo usando time series

# %%
df['date'] = pd.to_datetime(df['date'])
df['year'] = pd.DatetimeIndex(df['date']).year
df['month'] = pd.DatetimeIndex(df['date']).month
df['day'] = pd.DatetimeIndex(df['date']).day
df
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180
# 1      6414100192 2014-12-09  538000.0         3       2.25         2570
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# ...           ...        ...       ...       ...        ...          ...
# 21610   263000018 2014-05-21  360000.0         3       2.50         1530
# 21611  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21612  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21613   291310100 2015-01-16  400000.0         3       2.50         1600
# 21614  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  yr_built  yr_renovated  \
# 0        5650.0     1.0           0     0  ...      1955             0
# 1        7242.0     2.0           0     0  ...      1951          1991
# 2       10000.0     1.0           0     0  ...      1933             0
# 3        5000.0     1.0           0     0  ...      1965             0
# 4        8080.0     1.0           0     0  ...      1987             0
# ...         ...     ...         ...   ...  ...       ...           ...
# 21610    1131.0     3.0           0     0  ...      2009             0
# 21611    5813.0     2.0           0     0  ...      2014             0
# 21612    1350.0     2.0           0     0  ...      2009             0
# 21613    2388.0     2.0           0     0  ...      2004             0
# 21614    1076.0     2.0           0     0  ...      2008             0
#
#        zipcode      lat     long  sqft_living15  sqft_lot15  year  month  day
# 0        98178  47.5112 -122.257           1340        5650  2014     10   13
# 1        98125  47.7210 -122.319           1690        7639  2014     12    9
# 2        98028  47.7379 -122.233           2720        8062  2015      2   25
# 3        98136  47.5208 -122.393           1360        5000  2014     12    9
# 4        98074  47.6168 -122.045           1800        7503  2015      2   18
# ...        ...      ...      ...            ...         ...   ...    ...  ...
# 21610    98103  47.6993 -122.346           1530        1509  2014      5   21
# 21611    98146  47.5107 -122.362           1830        7200  2015      2   23
# 21612    98144  47.5944 -122.299           1020        2007  2014      6   23
# 21613    98027  47.5345 -122.069           1410        1287  2015      1   16
# 21614    98144  47.5941 -122.299           1020        1357  2014     10   15
#
# [21606 rows x 23 columns]

# %%
df_out['date'] = pd.to_datetime(df_out['date'])
df_out['year'] = pd.DatetimeIndex(df_out['date']).year
df_out['month'] = pd.DatetimeIndex(df_out['date']).month
df_out['day'] = pd.DatetimeIndex(df_out['date']).day
df_out
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# 6      1321400060 2014-06-27  257500.0         3       2.25         1715
# ...           ...        ...       ...       ...        ...          ...
# 21610   263000018 2014-05-21  360000.0         3       2.50         1530
# 21611  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21612  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21613   291310100 2015-01-16  400000.0         3       2.50         1600
# 21614  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  yr_built  yr_renovated  \
# 0        5650.0     1.0           0     0  ...      1955             0
# 2       10000.0     1.0           0     0  ...      1933             0
# 3        5000.0     1.0           0     0  ...      1965             0
# 4        8080.0     1.0           0     0  ...      1987             0
# 6        6819.0     2.0           0     0  ...      1995             0
# ...         ...     ...         ...   ...  ...       ...           ...
# 21610    1131.0     3.0           0     0  ...      2009             0
# 21611    5813.0     2.0           0     0  ...      2014             0
# 21612    1350.0     2.0           0     0  ...      2009             0
# 21613    2388.0     2.0           0     0  ...      2004             0
# 21614    1076.0     2.0           0     0  ...      2008             0
#
#        zipcode      lat     long  sqft_living15  sqft_lot15  year  month  day
# 0        98178  47.5112 -122.257           1340        5650  2014     10   13
# 2        98028  47.7379 -122.233           2720        8062  2015      2   25
# 3        98136  47.5208 -122.393           1360        5000  2014     12    9
# 4        98074  47.6168 -122.045           1800        7503  2015      2   18
# 6        98003  47.3097 -122.327           2238        6819  2014      6   27
# ...        ...      ...      ...            ...         ...   ...    ...  ...
# 21610    98103  47.6993 -122.346           1530        1509  2014      5   21
# 21611    98146  47.5107 -122.362           1830        7200  2015      2   23
# 21612    98144  47.5944 -122.299           1020        2007  2014      6   23
# 21613    98027  47.5345 -122.069           1410        1287  2015      1   16
# 21614    98144  47.5941 -122.299           1020        1357  2014     10   15
#
# [14958 rows x 23 columns]

# %%
df.groupby(['year']).mean()['price']
# Out:
# year
# 2014    537710.114309
# 2015    541966.351340
# Name: price, dtype: float64

# %%
df.groupby(['month']).mean()['price']
# Out:
# month
# 1     525870.889571
# 2     507851.371200
# 3     543893.930630
# 4     561837.774989
# 5     550052.154579
# 6     554978.096878
# 7     544949.980995
# 8     536445.276804
# 9     525669.080654
# 10    535211.855621
# 11    521961.009213
# 12    524461.866757
# Name: price, dtype: float64

# %%
fig, ax = plt.subplots(1,1,figsize=(16,5))
ax.plot(df['date'], df['price'],'.k')

fig, ax = plt.subplots(1,3,figsize=(16,5))
ax[0].plot(df.groupby(['day']).mean()['price'])
ax[1].plot(df.groupby(['month']).mean()['price'])
ax[2].plot(df.groupby(['year']).mean()['price'])
# Out:
# /usr/lib64/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
df = df.drop(['date','id', 'zipcode','day'], axis=1)

# %%
df_out = df_out.drop(['date','id', 'zipcode','day'], axis=1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180    5650.0     1.0           0
# 1  538000.0         3       2.25         2570    7242.0     2.0           0
# 2  180000.0         2       1.00          770   10000.0     1.0           0
# 3  604000.0         4       3.00         1960    5000.0     1.0           0
# 4  510000.0         3       2.00         1680    8080.0     1.0           0
#
#    view  condition  grade  sqft_basement  yr_built  yr_renovated      lat  \
# 0     0          3      7              0      1955             0  47.5112
# 1     0          3      7            400      1951          1991  47.7210
# 2     0          3      6              0      1933             0  47.7379
# 3     0          5      7            910      1965             0  47.5208
# 4     0          3      8              0      1987             0  47.6168
#
#       long  sqft_living15  sqft_lot15  year  month
# 0 -122.257           1340        5650  2014     10
# 1 -122.319           1690        7639  2014     12
# 2 -122.233           2720        8062  2015      2
# 3 -122.393           1360        5000  2014     12
# 4 -122.045           1800        7503  2015      2

# %% [markdown]
# ## Neural Network

# %%
def data_processing(df):
    
    ## Divide my data into X data and y data
    X_data = df.drop('price',axis=1)
    y_data = df['price'].values
    
    ## Split my data into test and train samples
    from sklearn.model_selection import train_test_split
    
    (X_train, X_test, y_train, y_test) = train_test_split(X_data, y_data, test_size=0.2, random_state=11)
    print("train data shape: ", X_train.shape)
    print("test data shape:  ", X_test.shape)
    
    ### Scale the data with the sklearn.preprocessing.StandardScaler
    from sklearn.preprocessing import StandardScaler

    s_scaler = StandardScaler()
    X_train = s_scaler.fit_transform(X_train.astype(float))
    X_test = s_scaler.transform(X_test.astype(float))
    
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = data_processing(df)
# Out:
# train data shape:  (17284, 18)
# test data shape:   (4322, 18)

# %%
# input_shape 
print("Shape of a single sample: ", X_train[0].shape)
# Out:
# Shape of a single sample:  (18,)

# %%
# Import a sequential model
from tensorflow.keras.models import Sequential
# Import the models to solve the problems
from tensorflow.keras.layers import InputLayer, Dense, Flatten, Dropout
# Import regularizers
from tensorflow.keras import regularizers
# Import EarlyStopping
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# Create a function with the Sequential model
def get_model(units=19, activation_hidden_layer = 'relu', drate=0.3, wd=0.01):
    model = Sequential([
                        InputLayer(input_shape = X_train[0].shape),
        
                        Dense(units=units, activation = activation_hidden_layer, name='layer_1'),
                        Dropout(drate),
        
                        Dense(units=units, activation = activation_hidden_layer, name='layer_2'),
    
                        Dense(units=units, activation = activation_hidden_layer, name='layer_3'),
        
                        Dropout(drate),
                        Dense(units=units, activation = activation_hidden_layer, name='layer_4'),
                        
                        Dense(units=1, name='output_layer') # The units in the output layer must be the number of posibilities they_data can take into account
                        ])
    return model

# %%
# Intance a Sequential model
units = 500
model = get_model(units)

# %%
def compile_model(model, optimizer, loss, metrics):   
    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
    # Summary
    model.summary()

# %%
compile_model(model, 'adam', 'mape', ['mape'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_1 (Dense)              (None, 500)               9500
# _________________________________________________________________
# dropout (Dropout)            (None, 500)               0
# _________________________________________________________________
# layer_2 (Dense)              (None, 500)               250500
# _________________________________________________________________
# layer_3 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 500)               0
# _________________________________________________________________
# layer_4 (Dense)              (None, 500)               250500
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 501
# =================================================================
# Total params: 761,501
# Trainable params: 761,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint=ModelCheckpoint('HousePrices.h5',
                           save_weights_only=False,
                           frequency='epoch',
                           verbose=1,
                           monitor='mape')

# %%
epochs = 200
myhistory = model.fit(X_train, y_train, epochs=epochs, batch_size = 128, validation_split=0.15, verbose=2, callbacks=[EarlyStopping(monitor='val_loss',patience=10), checkpoint])
# Out:
# Epoch 1/200
# 115/115 - 2s - loss: 68.5410 - mape: 68.5410 - val_loss: 27.2227 - val_mape: 27.2227
#
# Epoch 00001: saving model to HousePrices.h5
# Epoch 2/200
# 115/115 - 1s - loss: 23.1250 - mape: 23.1250 - val_loss: 21.0553 - val_mape: 21.0553
#
# Epoch 00002: saving model to HousePrices.h5
# Epoch 3/200
# 115/115 - 1s - loss: 20.8301 - mape: 20.8301 - val_loss: 19.9989 - val_mape: 19.9989
#
# Epoch 00003: saving model to HousePrices.h5
# Epoch 4/200
# 115/115 - 1s - loss: 20.1536 - mape: 20.1536 - val_loss: 19.5402 - val_mape: 19.5402
#
# Epoch 00004: saving model to HousePrices.h5
# Epoch 5/200
# 115/115 - 1s - loss: 19.6894 - mape: 19.6894 - val_loss: 19.6179 - val_mape: 19.6179
#
# Epoch 00005: saving model to HousePrices.h5
# Epoch 6/200
# 115/115 - 1s - loss: 19.6047 - mape: 19.6047 - val_loss: 19.0337 - val_mape: 19.0337
#
# Epoch 00006: saving model to HousePrices.h5
# Epoch 7/200
# 115/115 - 1s - loss: 19.2658 - mape: 19.2658 - val_loss: 18.8186 - val_mape: 18.8186
#
# Epoch 00007: saving model to HousePrices.h5
# Epoch 8/200
# 115/115 - 1s - loss: 19.0993 - mape: 19.0993 - val_loss: 18.7637 - val_mape: 18.7637
#
# Epoch 00008: saving model to HousePrices.h5
# Epoch 9/200
# 115/115 - 1s - loss: 18.9548 - mape: 18.9548 - val_loss: 18.4910 - val_mape: 18.4910
#
# Epoch 00009: saving model to HousePrices.h5
# Epoch 10/200
# 115/115 - 1s - loss: 18.9000 - mape: 18.9000 - val_loss: 18.3714 - val_mape: 18.3714
#
# Epoch 00010: saving model to HousePrices.h5
# Epoch 11/200
# 115/115 - 1s - loss: 18.8312 - mape: 18.8312 - val_loss: 18.2257 - val_mape: 18.2257
#
# Epoch 00011: saving model to HousePrices.h5
# Epoch 12/200
# 115/115 - 1s - loss: 18.7503 - mape: 18.7503 - val_loss: 18.1829 - val_mape: 18.1829
#
# Epoch 00012: saving model to HousePrices.h5
# Epoch 13/200
# 115/115 - 1s - loss: 18.5663 - mape: 18.5663 - val_loss: 18.0385 - val_mape: 18.0385
#
# Epoch 00013: saving model to HousePrices.h5
# Epoch 14/200
# 115/115 - 1s - loss: 18.3553 - mape: 18.3553 - val_loss: 18.0276 - val_mape: 18.0276
#
# Epoch 00014: saving model to HousePrices.h5
# Epoch 15/200
# 115/115 - 1s - loss: 18.3235 - mape: 18.3235 - val_loss: 17.7506 - val_mape: 17.7506
#
# Epoch 00015: saving model to HousePrices.h5
# Epoch 16/200
# 115/115 - 1s - loss: 18.0933 - mape: 18.0933 - val_loss: 17.5196 - val_mape: 17.5196
#
# Epoch 00016: saving model to HousePrices.h5
# Epoch 17/200
# 115/115 - 1s - loss: 17.9638 - mape: 17.9638 - val_loss: 17.2412 - val_mape: 17.2412
#
# Epoch 00017: saving model to HousePrices.h5
# Epoch 18/200
# 115/115 - 1s - loss: 17.8836 - mape: 17.8836 - val_loss: 17.0439 - val_mape: 17.0439
#
# Epoch 00018: saving model to HousePrices.h5
# Epoch 19/200
# 115/115 - 2s - loss: 17.6657 - mape: 17.6657 - val_loss: 16.9367 - val_mape: 16.9367
#
# Epoch 00019: saving model to HousePrices.h5
# Epoch 20/200
# 115/115 - 1s - loss: 17.5291 - mape: 17.5291 - val_loss: 16.5687 - val_mape: 16.5687
#
# Epoch 00020: saving model to HousePrices.h5
# Epoch 21/200
# 115/115 - 1s - loss: 17.3074 - mape: 17.3074 - val_loss: 16.3194 - val_mape: 16.3194
#
# Epoch 00021: saving model to HousePrices.h5
# Epoch 22/200
# 115/115 - 1s - loss: 17.1820 - mape: 17.1820 - val_loss: 16.1620 - val_mape: 16.1620
#
# Epoch 00022: saving model to HousePrices.h5
# Epoch 23/200
# 115/115 - 1s - loss: 17.0790 - mape: 17.0790 - val_loss: 16.4854 - val_mape: 16.4854
#
# Epoch 00023: saving model to HousePrices.h5
# Epoch 24/200
# 115/115 - 1s - loss: 16.8624 - mape: 16.8624 - val_loss: 15.8328 - val_mape: 15.8328
#
# Epoch 00024: saving model to HousePrices.h5
# Epoch 25/200
# 115/115 - 1s - loss: 16.5790 - mape: 16.5790 - val_loss: 15.6538 - val_mape: 15.6538
#
# Epoch 00025: saving model to HousePrices.h5
# Epoch 26/200
# 115/115 - 1s - loss: 16.5733 - mape: 16.5733 - val_loss: 15.4016 - val_mape: 15.4016
#
# Epoch 00026: saving model to HousePrices.h5
# Epoch 27/200
# 115/115 - 1s - loss: 16.2262 - mape: 16.2262 - val_loss: 15.1991 - val_mape: 15.1991
#
# Epoch 00027: saving model to HousePrices.h5
# Epoch 28/200
# 115/115 - 1s - loss: 16.0996 - mape: 16.0996 - val_loss: 15.4221 - val_mape: 15.4221
#
# Epoch 00028: saving model to HousePrices.h5
# Epoch 29/200
# 115/115 - 1s - loss: 16.0724 - mape: 16.0724 - val_loss: 14.9765 - val_mape: 14.9765
#
# Epoch 00029: saving model to HousePrices.h5
# Epoch 30/200
# 115/115 - 1s - loss: 15.6898 - mape: 15.6898 - val_loss: 14.6315 - val_mape: 14.6315
#
# Epoch 00030: saving model to HousePrices.h5
# Epoch 31/200
# 115/115 - 1s - loss: 15.6697 - mape: 15.6697 - val_loss: 14.4580 - val_mape: 14.4580
#
# Epoch 00031: saving model to HousePrices.h5
# Epoch 32/200
# 115/115 - 1s - loss: 15.4944 - mape: 15.4944 - val_loss: 14.4871 - val_mape: 14.4871
#
# Epoch 00032: saving model to HousePrices.h5
# Epoch 33/200
# 115/115 - 1s - loss: 15.4371 - mape: 15.4371 - val_loss: 14.5411 - val_mape: 14.5411
#
# Epoch 00033: saving model to HousePrices.h5
# Epoch 34/200
# 115/115 - 1s - loss: 15.3013 - mape: 15.3013 - val_loss: 14.1797 - val_mape: 14.1797
#
# Epoch 00034: saving model to HousePrices.h5
# Epoch 35/200
# 115/115 - 1s - loss: 15.2819 - mape: 15.2819 - val_loss: 14.3503 - val_mape: 14.3503
#
# Epoch 00035: saving model to HousePrices.h5
# Epoch 36/200
# 115/115 - 1s - loss: 15.0192 - mape: 15.0192 - val_loss: 13.9663 - val_mape: 13.9663
#
# Epoch 00036: saving model to HousePrices.h5
# Epoch 37/200
# 115/115 - 1s - loss: 14.9856 - mape: 14.9856 - val_loss: 14.2612 - val_mape: 14.2612
#
# Epoch 00037: saving model to HousePrices.h5
# Epoch 38/200
# 115/115 - 1s - loss: 14.8993 - mape: 14.8993 - val_loss: 14.0355 - val_mape: 14.0355
#
# Epoch 00038: saving model to HousePrices.h5
# Epoch 39/200
# 115/115 - 1s - loss: 14.9062 - mape: 14.9062 - val_loss: 14.0621 - val_mape: 14.0621
#
# Epoch 00039: saving model to HousePrices.h5
# Epoch 40/200
# 115/115 - 1s - loss: 14.8799 - mape: 14.8799 - val_loss: 13.8210 - val_mape: 13.8210
#
# Epoch 00040: saving model to HousePrices.h5
# Epoch 41/200
# 115/115 - 1s - loss: 14.8710 - mape: 14.8710 - val_loss: 13.8488 - val_mape: 13.8488
#
# Epoch 00041: saving model to HousePrices.h5
# Epoch 42/200
# 115/115 - 1s - loss: 14.6909 - mape: 14.6909 - val_loss: 13.6101 - val_mape: 13.6101
#
# Epoch 00042: saving model to HousePrices.h5
# Epoch 43/200
# 115/115 - 2s - loss: 14.6048 - mape: 14.6048 - val_loss: 13.6346 - val_mape: 13.6346
#
# Epoch 00043: saving model to HousePrices.h5
# Epoch 44/200
# 115/115 - 1s - loss: 14.6300 - mape: 14.6300 - val_loss: 13.5774 - val_mape: 13.5774
#
# Epoch 00044: saving model to HousePrices.h5
# Epoch 45/200
# 115/115 - 1s - loss: 14.6105 - mape: 14.6105 - val_loss: 13.7359 - val_mape: 13.7359
#
# Epoch 00045: saving model to HousePrices.h5
# Epoch 46/200
# 115/115 - 1s - loss: 14.5506 - mape: 14.5506 - val_loss: 14.0125 - val_mape: 14.0125
#
# Epoch 00046: saving model to HousePrices.h5
# Epoch 47/200
# 115/115 - 1s - loss: 14.4314 - mape: 14.4314 - val_loss: 13.3323 - val_mape: 13.3323
#
# Epoch 00047: saving model to HousePrices.h5
# Epoch 48/200
# 115/115 - 1s - loss: 14.4163 - mape: 14.4163 - val_loss: 13.5388 - val_mape: 13.5388
#
# Epoch 00048: saving model to HousePrices.h5
# Epoch 49/200
# 115/115 - 1s - loss: 14.5129 - mape: 14.5129 - val_loss: 13.4539 - val_mape: 13.4539
#
# Epoch 00049: saving model to HousePrices.h5
# Epoch 50/200
# 115/115 - 1s - loss: 14.1738 - mape: 14.1738 - val_loss: 13.6869 - val_mape: 13.6869
#
# Epoch 00050: saving model to HousePrices.h5
# Epoch 51/200
# 115/115 - 1s - loss: 14.3182 - mape: 14.3182 - val_loss: 13.3686 - val_mape: 13.3686
#
# Epoch 00051: saving model to HousePrices.h5
# Epoch 52/200
# 115/115 - 1s - loss: 14.1428 - mape: 14.1428 - val_loss: 13.2000 - val_mape: 13.2000
#
# Epoch 00052: saving model to HousePrices.h5
# Epoch 53/200
# 115/115 - 1s - loss: 14.2901 - mape: 14.2901 - val_loss: 13.3769 - val_mape: 13.3769
#
# Epoch 00053: saving model to HousePrices.h5
# Epoch 54/200
# 115/115 - 1s - loss: 14.1030 - mape: 14.1030 - val_loss: 13.2914 - val_mape: 13.2914
#
# Epoch 00054: saving model to HousePrices.h5
# Epoch 55/200
# 115/115 - 1s - loss: 14.1423 - mape: 14.1423 - val_loss: 13.2244 - val_mape: 13.2244
#
# Epoch 00055: saving model to HousePrices.h5
# Epoch 56/200
# 115/115 - 1s - loss: 14.0552 - mape: 14.0552 - val_loss: 13.2104 - val_mape: 13.2104
#
# Epoch 00056: saving model to HousePrices.h5
# Epoch 57/200
# 115/115 - 1s - loss: 14.2019 - mape: 14.2019 - val_loss: 13.5855 - val_mape: 13.5855
#
# Epoch 00057: saving model to HousePrices.h5
# Epoch 58/200
# 115/115 - 1s - loss: 14.0864 - mape: 14.0864 - val_loss: 13.0835 - val_mape: 13.0835
# Epoch 00058: saving model to HousePrices.h5
# Epoch 59/200
# 115/115 - 1s - loss: 14.0101 - mape: 14.0101 - val_loss: 13.0644 - val_mape: 13.0644
#
# Epoch 00059: saving model to HousePrices.h5
# Epoch 60/200
# 115/115 - 1s - loss: 13.9985 - mape: 13.9985 - val_loss: 12.9902 - val_mape: 12.9902
#
# Epoch 00060: saving model to HousePrices.h5
# Epoch 61/200
# 115/115 - 1s - loss: 14.0612 - mape: 14.0612 - val_loss: 13.1834 - val_mape: 13.1834
#
# Epoch 00061: saving model to HousePrices.h5
# Epoch 62/200
# 115/115 - 1s - loss: 13.9919 - mape: 13.9919 - val_loss: 13.5340 - val_mape: 13.5340
#
# Epoch 00062: saving model to HousePrices.h5
# Epoch 63/200
# 115/115 - 1s - loss: 13.9509 - mape: 13.9509 - val_loss: 13.0619 - val_mape: 13.0619
#
# Epoch 00063: saving model to HousePrices.h5
# Epoch 64/200
# 115/115 - 1s - loss: 14.0292 - mape: 14.0292 - val_loss: 13.1903 - val_mape: 13.1903
#
# Epoch 00064: saving model to HousePrices.h5
# Epoch 65/200
# 115/115 - 1s - loss: 13.7972 - mape: 13.7972 - val_loss: 13.1906 - val_mape: 13.1906
#
# Epoch 00065: saving model to HousePrices.h5
# Epoch 66/200
# 115/115 - 1s - loss: 13.7558 - mape: 13.7558 - val_loss: 12.8738 - val_mape: 12.8738
#
# Epoch 00066: saving model to HousePrices.h5
# Epoch 67/200
# 115/115 - 1s - loss: 13.8932 - mape: 13.8932 - val_loss: 13.3267 - val_mape: 13.3267
#
# Epoch 00067: saving model to HousePrices.h5
# Epoch 68/200
# 115/115 - 1s - loss: 13.8608 - mape: 13.8608 - val_loss: 12.7914 - val_mape: 12.7914
#
# Epoch 00068: saving model to HousePrices.h5
# Epoch 69/200
# 115/115 - 1s - loss: 13.6990 - mape: 13.6990 - val_loss: 12.9411 - val_mape: 12.9411
#
# Epoch 00069: saving model to HousePrices.h5
# Epoch 70/200
# 115/115 - 1s - loss: 13.7962 - mape: 13.7962 - val_loss: 12.9312 - val_mape: 12.9312
#
# Epoch 00070: saving model to HousePrices.h5
# Epoch 71/200
# 115/115 - 1s - loss: 13.7187 - mape: 13.7187 - val_loss: 12.7934 - val_mape: 12.7934
#
# Epoch 00071: saving model to HousePrices.h5
# Epoch 72/200
# 115/115 - 1s - loss: 13.6678 - mape: 13.6678 - val_loss: 12.9916 - val_mape: 12.9916
#
# Epoch 00072: saving model to HousePrices.h5
# Epoch 73/200
# 115/115 - 1s - loss: 13.6617 - mape: 13.6617 - val_loss: 12.7662 - val_mape: 12.7662
#
# Epoch 00073: saving model to HousePrices.h5
# Epoch 74/200
# 115/115 - 1s - loss: 13.5807 - mape: 13.5807 - val_loss: 13.0134 - val_mape: 13.0134
#
# Epoch 00074: saving model to HousePrices.h5
# Epoch 75/200
# 115/115 - 1s - loss: 13.5283 - mape: 13.5283 - val_loss: 12.7433 - val_mape: 12.7433
#
# Epoch 00075: saving model to HousePrices.h5
# Epoch 76/200
# 115/115 - 1s - loss: 13.5592 - mape: 13.5592 - val_loss: 12.6658 - val_mape: 12.6658
#
# Epoch 00076: saving model to HousePrices.h5
# Epoch 77/200
# 115/115 - 1s - loss: 13.4636 - mape: 13.4636 - val_loss: 12.7137 - val_mape: 12.7137
#
# Epoch 00077: saving model to HousePrices.h5
# Epoch 78/200
# 115/115 - 1s - loss: 13.4991 - mape: 13.4991 - val_loss: 12.6486 - val_mape: 12.6486
#
# Epoch 00078: saving model to HousePrices.h5
# Epoch 79/200
# 115/115 - 1s - loss: 13.5199 - mape: 13.5199 - val_loss: 12.7480 - val_mape: 12.7480
#
# Epoch 00079: saving model to HousePrices.h5
# Epoch 80/200
# 115/115 - 1s - loss: 13.5482 - mape: 13.5482 - val_loss: 12.6620 - val_mape: 12.6620
#
# Epoch 00080: saving model to HousePrices.h5
# Epoch 81/200
# 115/115 - 1s - loss: 13.4463 - mape: 13.4463 - val_loss: 12.7251 - val_mape: 12.7251
#
# Epoch 00081: saving model to HousePrices.h5
# Epoch 82/200
# 115/115 - 1s - loss: 13.3976 - mape: 13.3976 - val_loss: 12.9580 - val_mape: 12.9580
#
# Epoch 00082: saving model to HousePrices.h5
# Epoch 83/200
# 115/115 - 1s - loss: 13.3843 - mape: 13.3843 - val_loss: 12.8866 - val_mape: 12.8866
#
# Epoch 00083: saving model to HousePrices.h5
# Epoch 84/200
# 115/115 - 1s - loss: 13.4860 - mape: 13.4860 - val_loss: 12.6521 - val_mape: 12.6521
#
# Epoch 00084: saving model to HousePrices.h5
# Epoch 85/200
# 115/115 - 1s - loss: 13.4182 - mape: 13.4182 - val_loss: 13.0577 - val_mape: 13.0577
#
# Epoch 00085: saving model to HousePrices.h5
# Epoch 86/200
# 115/115 - 1s - loss: 13.2636 - mape: 13.2636 - val_loss: 12.6961 - val_mape: 12.6961
#
# Epoch 00086: saving model to HousePrices.h5
# Epoch 87/200
# 115/115 - 1s - loss: 13.4238 - mape: 13.4238 - val_loss: 12.6794 - val_mape: 12.6794
#
# Epoch 00087: saving model to HousePrices.h5
# Epoch 88/200
# 115/115 - 1s - loss: 13.3153 - mape: 13.3153 - val_loss: 12.6227 - val_mape: 12.6227
#
# Epoch 00088: saving model to HousePrices.h5
# Epoch 89/200
# 115/115 - 1s - loss: 13.3863 - mape: 13.3863 - val_loss: 12.8307 - val_mape: 12.8307
#
# Epoch 00089: saving model to HousePrices.h5
# Epoch 90/200
# 115/115 - 1s - loss: 13.2453 - mape: 13.2453 - val_loss: 12.7131 - val_mape: 12.7131
#
# Epoch 00090: saving model to HousePrices.h5
# Epoch 91/200
# 115/115 - 1s - loss: 13.2187 - mape: 13.2187 - val_loss: 12.5527 - val_mape: 12.5527
#
# Epoch 00091: saving model to HousePrices.h5
# Epoch 92/200
# 115/115 - 1s - loss: 13.2934 - mape: 13.2934 - val_loss: 12.6584 - val_mape: 12.6584
#
# Epoch 00092: saving model to HousePrices.h5
# Epoch 93/200
# 115/115 - 1s - loss: 13.2446 - mape: 13.2446 - val_loss: 12.4235 - val_mape: 12.4235
#
# Epoch 00093: saving model to HousePrices.h5
# Epoch 94/200
# 115/115 - 1s - loss: 13.1916 - mape: 13.1916 - val_loss: 12.4954 - val_mape: 12.4954
#
# Epoch 00094: saving model to HousePrices.h5
# Epoch 95/200
# 115/115 - 1s - loss: 13.1474 - mape: 13.1474 - val_loss: 13.3074 - val_mape: 13.3074
#
# Epoch 00095: saving model to HousePrices.h5
# Epoch 96/200
# 115/115 - 1s - loss: 13.2274 - mape: 13.2274 - val_loss: 12.4563 - val_mape: 12.4563
#
# Epoch 00096: saving model to HousePrices.h5
# Epoch 97/200
# 115/115 - 1s - loss: 13.1544 - mape: 13.1544 - val_loss: 12.5732 - val_mape: 12.5732
#
# Epoch 00097: saving model to HousePrices.h5
# Epoch 98/200
# 115/115 - 1s - loss: 12.9959 - mape: 12.9959 - val_loss: 12.4110 - val_mape: 12.4110
#
# Epoch 00098: saving model to HousePrices.h5
# Epoch 99/200
# 115/115 - 1s - loss: 13.2001 - mape: 13.2001 - val_loss: 12.6240 - val_mape: 12.6240
#
# Epoch 00099: saving model to HousePrices.h5
# Epoch 100/200
# 115/115 - 1s - loss: 13.0417 - mape: 13.0417 - val_loss: 12.6947 - val_mape: 12.6947
#
# Epoch 00100: saving model to HousePrices.h5
# Epoch 101/200
# 115/115 - 1s - loss: 12.9523 - mape: 12.9523 - val_loss: 12.2631 - val_mape: 12.2631
#
# Epoch 00101: saving model to HousePrices.h5
# Epoch 102/200
# 115/115 - 1s - loss: 13.0785 - mape: 13.0785 - val_loss: 12.8491 - val_mape: 12.8491
#
# Epoch 00102: saving model to HousePrices.h5
# Epoch 103/200
# 115/115 - 1s - loss: 13.0278 - mape: 13.0278 - val_loss: 12.3409 - val_mape: 12.3409
#
# Epoch 00103: saving model to HousePrices.h5
# Epoch 104/200
# 115/115 - 1s - loss: 13.0082 - mape: 13.0082 - val_loss: 12.8339 - val_mape: 12.8339
#
# Epoch 00104: saving model to HousePrices.h5
# Epoch 105/200
# 115/115 - 2s - loss: 13.0325 - mape: 13.0325 - val_loss: 12.5276 - val_mape: 12.5276
#
# Epoch 00105: saving model to HousePrices.h5
# Epoch 106/200
# 115/115 - 2s - loss: 13.0068 - mape: 13.0068 - val_loss: 12.4500 - val_mape: 12.4500
#
# Epoch 00106: saving model to HousePrices.h5
# Epoch 107/200
# 115/115 - 1s - loss: 13.2178 - mape: 13.2178 - val_loss: 12.4418 - val_mape: 12.4418
#
# Epoch 00107: saving model to HousePrices.h5
# Epoch 108/200
# 115/115 - 1s - loss: 12.9225 - mape: 12.9225 - val_loss: 12.3614 - val_mape: 12.3614
#
# Epoch 00108: saving model to HousePrices.h5
# Epoch 109/200
# 115/115 - 1s - loss: 13.0221 - mape: 13.0221 - val_loss: 12.3736 - val_mape: 12.3736
#
# Epoch 00109: saving model to HousePrices.h5
# Epoch 110/200
# 115/115 - 1s - loss: 13.0147 - mape: 13.0147 - val_loss: 12.5838 - val_mape: 12.5838
#
# Epoch 00110: saving model to HousePrices.h5
# Epoch 111/200
# 115/115 - 1s - loss: 12.9367 - mape: 12.9367 - val_loss: 12.4681 - val_mape: 12.4681
#
# Epoch 00111: saving model to HousePrices.h5

# %%
myhistory.history.keys()
# Out:
# dict_keys(['loss', 'mape', 'val_loss', 'val_mape'])

# %%
xvals = range(len(myhistory.history['loss']))

fig, ax = plt.subplots(1,1,figsize=(10,8))
ax.plot(xvals, myhistory.history['val_mape'], '-', label='test set accuracy')
ax.plot(xvals, myhistory.history['mape'], '-', label='train set accuracy')
ax.legend()
plt.show()

# %%
y_pred = model.predict(X_test)

from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, y_pred))  
print('MSE:', metrics.mean_squared_error(y_test, y_pred))  
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('MAPE:', np.sqrt(metrics.mean_absolute_percentage_error(y_test, y_pred)))
print('VarScore:',metrics.explained_variance_score(y_test,y_pred))
# Out:
# MAE: 66789.5452192272
# MSE: 12775773923.704224
# RMSE: 113029.96913962343
# MAPE: 0.35110236537922185
# VarScore: 0.8950433728166958

# %%
# Visualizing Our predictions
fig = plt.figure(figsize=(10,5))
plt.scatter(y_test,y_pred)
# Perfect predictions
plt.plot(y_test,y_test,'r')

# %%
print("Real Value: ", y_test[0])
print("Predicted Value: ", y_pred[0][0])
# Out:
# Real Value:  308000.0
# Predicted Value:  369379.88

# %% [markdown]
# ## Neural Network with the data in the Interquartile Range Outliers

# %%
# Create a function with the Sequential model
def get_model(units=19, activation_hidden_layer = 'relu', drate=0.3, wd=0.01):
    model = Sequential([
                        InputLayer(input_shape = X_train[0].shape),
        
                        Dense(units=units, activation = activation_hidden_layer, kernel_regularizer = regularizers.l2(wd), name='layer_1'),
                        Dropout(drate),
        
                        Dense(units=units, activation = activation_hidden_layer, kernel_regularizer = regularizers.l2(wd), name='layer_2'),
                        Dropout(drate),
        
                        Dense(units=units, activation = activation_hidden_layer, kernel_regularizer = regularizers.l2(wd), name='layer_3'),
                        Dropout(drate),
        
                        Dense(units=units, activation = activation_hidden_layer, kernel_regularizer = regularizers.l2(wd), name='layer_4'),
                        
                        Dense(units=1, name='output_layer') # The units in the output layer must be the number of posibilities they_data can take into account
                        ])
    return model

# %%
# Intance a Sequential model
units = 500
model = get_model(units)

# %%
compile_model(model, 'adam', 'mape', ['mape'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_1 (Dense)              (None, 500)               9500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# layer_2 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 500)               0
# _________________________________________________________________
# layer_3 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 500)               0
# _________________________________________________________________
# layer_4 (Dense)              (None, 500)               250500
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 501
# =================================================================
# Total params: 761,501
# Trainable params: 761,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train_out, X_test_out, y_train_out, y_test_out = data_processing(df_out)
# Out:
# train data shape:  (11966, 18)
# test data shape:   (2992, 18)

# %%
checkpoint=ModelCheckpoint('HousePrices2.h5',
                           save_weights_only=False,
                           frequency='epoch',
                           verbose=1,
                           monitor='mape')

# %%
epochs = 200
myhistory2 = model.fit(X_train_out, y_train_out, epochs=epochs, batch_size = 128, validation_split=0.15, verbose=2, callbacks=[EarlyStopping(monitor='val_loss', patience=10), checkpoint])
# Out:
# Epoch 1/200
# 80/80 - 2s - loss: 104.2209 - mape: 99.9996 - val_loss: 100.1970 - val_mape: 99.9990
#
# Epoch 00001: saving model to HousePrices2.h5
# Epoch 2/200
# 80/80 - 1s - loss: 100.0330 - mape: 99.9976 - val_loss: 99.9961 - val_mape: 99.9955
#
# Epoch 00002: saving model to HousePrices2.h5
# Epoch 3/200
# 80/80 - 1s - loss: 99.9925 - mape: 99.9919 - val_loss: 99.9880 - val_mape: 99.9868
#
# Epoch 00003: saving model to HousePrices2.h5
# Epoch 4/200
# 80/80 - 1s - loss: 99.9803 - mape: 99.9763 - val_loss: 99.9690 - val_mape: 99.9589
#
# Epoch 00004: saving model to HousePrices2.h5
# Epoch 5/200
# 80/80 - 1s - loss: 93.7286 - mape: 92.3056 - val_loss: 52.7245 - val_mape: 45.5071
#
# Epoch 00005: saving model to HousePrices2.h5
# Epoch 6/200
# 80/80 - 1s - loss: 31.0132 - mape: 22.6658 - val_loss: 26.4356 - val_mape: 18.3838
#
# Epoch 00006: saving model to HousePrices2.h5
# Epoch 7/200
# 80/80 - 1s - loss: 26.6248 - mape: 19.0899 - val_loss: 25.2935 - val_mape: 18.0837
#
# Epoch 00007: saving model to HousePrices2.h5
# Epoch 8/200
# 80/80 - 1s - loss: 25.7410 - mape: 18.7158 - val_loss: 24.6165 - val_mape: 17.7098
#
# Epoch 00008: saving model to HousePrices2.h5
# Epoch 9/200
# 80/80 - 1s - loss: 25.4164 - mape: 18.7433 - val_loss: 23.9514 - val_mape: 17.4274
#
# Epoch 00009: saving model to HousePrices2.h5
# Epoch 10/200
# 80/80 - 1s - loss: 24.7357 - mape: 18.3393 - val_loss: 23.8862 - val_mape: 17.7622
#
# Epoch 00010: saving model to HousePrices2.h5
# Epoch 11/200
# 80/80 - 1s - loss: 24.4249 - mape: 18.2815 - val_loss: 23.2134 - val_mape: 17.2182
#
# Epoch 00011: saving model to HousePrices2.h5
# Epoch 12/200
# 80/80 - 1s - loss: 24.0550 - mape: 18.1197 - val_loss: 22.9484 - val_mape: 17.1514
#
# Epoch 00012: saving model to HousePrices2.h5
# Epoch 13/200
# 80/80 - 1s - loss: 23.7502 - mape: 17.9906 - val_loss: 22.6713 - val_mape: 17.0348
#
# Epoch 00013: saving model to HousePrices2.h5
# Epoch 14/200
# 80/80 - 1s - loss: 23.6198 - mape: 18.0390 - val_loss: 22.5072 - val_mape: 16.8911
#
# Epoch 00014: saving model to HousePrices2.h5
# Epoch 15/200
# 80/80 - 1s - loss: 23.4806 - mape: 18.0228 - val_loss: 22.5682 - val_mape: 17.3014
#
# Epoch 00015: saving model to HousePrices2.h5
# Epoch 16/200
# 80/80 - 1s - loss: 23.2729 - mape: 17.9607 - val_loss: 22.1133 - val_mape: 16.8620
#
# Epoch 00016: saving model to HousePrices2.h5
# Epoch 17/200
# 80/80 - 1s - loss: 23.1300 - mape: 17.9409 - val_loss: 22.0241 - val_mape: 16.8722
#
# Epoch 00017: saving model to HousePrices2.h5
# Epoch 18/200
# 80/80 - 1s - loss: 22.9440 - mape: 17.8464 - val_loss: 21.8221 - val_mape: 16.7837
#
# Epoch 00018: saving model to HousePrices2.h5
# Epoch 19/200
# 80/80 - 1s - loss: 22.9791 - mape: 17.9949 - val_loss: 21.7600 - val_mape: 16.7444
#
# Epoch 00019: saving model to HousePrices2.h5
# Epoch 20/200
# 80/80 - 1s - loss: 22.6090 - mape: 17.7189 - val_loss: 21.6052 - val_mape: 16.7307
#
# Epoch 00020: saving model to HousePrices2.h5
# Epoch 21/200
# 80/80 - 1s - loss: 22.5447 - mape: 17.7292 - val_loss: 21.4781 - val_mape: 16.6323
#
# Epoch 00021: saving model to HousePrices2.h5
# Epoch 22/200
# 80/80 - 1s - loss: 22.6842 - mape: 17.9377 - val_loss: 21.5692 - val_mape: 16.7412
#
# Epoch 00022: saving model to HousePrices2.h5
# Epoch 23/200
# 80/80 - 1s - loss: 22.4677 - mape: 17.8005 - val_loss: 21.4782 - val_mape: 16.9234
#
# Epoch 00023: saving model to HousePrices2.h5
# Epoch 24/200
# 80/80 - 1s - loss: 22.4855 - mape: 17.8862 - val_loss: 21.6685 - val_mape: 16.9815
#
# Epoch 00024: saving model to HousePrices2.h5
# Epoch 25/200
# 80/80 - 1s - loss: 22.3580 - mape: 17.8269 - val_loss: 21.1367 - val_mape: 16.6549
#
# Epoch 00025: saving model to HousePrices2.h5
# Epoch 26/200
# 80/80 - 1s - loss: 22.3282 - mape: 17.8483 - val_loss: 21.0801 - val_mape: 16.6294
#
# Epoch 00026: saving model to HousePrices2.h5
# Epoch 27/200
# 80/80 - 1s - loss: 22.1111 - mape: 17.6736 - val_loss: 21.0165 - val_mape: 16.5657
#
# Epoch 00027: saving model to HousePrices2.h5
# Epoch 28/200
# 80/80 - 1s - loss: 22.0843 - mape: 17.6977 - val_loss: 21.1200 - val_mape: 16.8567
#
# Epoch 00028: saving model to HousePrices2.h5
# Epoch 29/200
# 80/80 - 1s - loss: 22.2280 - mape: 17.8963 - val_loss: 20.8222 - val_mape: 16.4629
#
# Epoch 00029: saving model to HousePrices2.h5
# Epoch 30/200
# 80/80 - 1s - loss: 21.8688 - mape: 17.5738 - val_loss: 20.8110 - val_mape: 16.5545
#
# Epoch 00030: saving model to HousePrices2.h5
# Epoch 31/200
# 80/80 - 1s - loss: 21.9066 - mape: 17.6547 - val_loss: 20.8446 - val_mape: 16.6531
#
# Epoch 00031: saving model to HousePrices2.h5
# Epoch 32/200
# 80/80 - 1s - loss: 21.7912 - mape: 17.5876 - val_loss: 21.0625 - val_mape: 16.7757
#
# Epoch 00032: saving model to HousePrices2.h5
# Epoch 33/200
# 80/80 - 1s - loss: 21.8064 - mape: 17.6495 - val_loss: 20.6601 - val_mape: 16.5397
#
# Epoch 00033: saving model to HousePrices2.h5
# Epoch 34/200
# 80/80 - 1s - loss: 21.6969 - mape: 17.5764 - val_loss: 20.6297 - val_mape: 16.4677
#
# Epoch 00034: saving model to HousePrices2.h5
# Epoch 35/200
# 80/80 - 1s - loss: 21.6942 - mape: 17.6018 - val_loss: 20.4993 - val_mape: 16.4198
#
# Epoch 00035: saving model to HousePrices2.h5
# Epoch 36/200
# 80/80 - 1s - loss: 21.4140 - mape: 17.3527 - val_loss: 20.4575 - val_mape: 16.3776
#
# Epoch 00036: saving model to HousePrices2.h5
# Epoch 37/200
# 80/80 - 1s - loss: 21.5288 - mape: 17.4987 - val_loss: 20.5351 - val_mape: 16.5785
#
# Epoch 00037: saving model to HousePrices2.h5
# Epoch 38/200
# 80/80 - 1s - loss: 21.5497 - mape: 17.5661 - val_loss: 20.4072 - val_mape: 16.3956
#
# Epoch 00038: saving model to HousePrices2.h5
# Epoch 39/200
# 80/80 - 1s - loss: 21.4471 - mape: 17.4901 - val_loss: 20.3762 - val_mape: 16.4175
#
# Epoch 00039: saving model to HousePrices2.h5
# Epoch 40/200
# 80/80 - 1s - loss: 21.4181 - mape: 17.4920 - val_loss: 20.2848 - val_mape: 16.3483
#
# Epoch 00040: saving model to HousePrices2.h5
# Epoch 41/200
# 80/80 - 1s - loss: 21.3842 - mape: 17.4868 - val_loss: 20.2712 - val_mape: 16.3779
#
# Epoch 00041: saving model to HousePrices2.h5
# Epoch 42/200
# 80/80 - 1s - loss: 21.4843 - mape: 17.6069 - val_loss: 20.2405 - val_mape: 16.3629
#
# Epoch 00042: saving model to HousePrices2.h5
# Epoch 43/200
# 80/80 - 1s - loss: 21.4447 - mape: 17.6052 - val_loss: 20.2236 - val_mape: 16.4046
#
# Epoch 00043: saving model to HousePrices2.h5
# Epoch 44/200
# 80/80 - 1s - loss: 21.4630 - mape: 17.6486 - val_loss: 20.1689 - val_mape: 16.3342
#
# Epoch 00044: saving model to HousePrices2.h5
# Epoch 45/200
# 80/80 - 1s - loss: 21.3737 - mape: 17.6028 - val_loss: 20.1408 - val_mape: 16.3180
#
# Epoch 00045: saving model to HousePrices2.h5
# Epoch 46/200
# 80/80 - 1s - loss: 21.3174 - mape: 17.5584 - val_loss: 20.2438 - val_mape: 16.5403
#
# Epoch 00046: saving model to HousePrices2.h5
# Epoch 47/200
# 80/80 - 1s - loss: 21.1783 - mape: 17.4291 - val_loss: 20.2659 - val_mape: 16.5952
#
# Epoch 00047: saving model to HousePrices2.h5
# Epoch 48/200
# 80/80 - 1s - loss: 21.3698 - mape: 17.6572 - val_loss: 20.4575 - val_mape: 16.8429
#
# Epoch 00048: saving model to HousePrices2.h5
# Epoch 49/200
# 80/80 - 1s - loss: 21.2926 - mape: 17.6069 - val_loss: 20.0537 - val_mape: 16.3368
#
# Epoch 00049: saving model to HousePrices2.h5
# Epoch 50/200
# 80/80 - 1s - loss: 21.1383 - mape: 17.4748 - val_loss: 20.0364 - val_mape: 16.3185
#
# Epoch 00050: saving model to HousePrices2.h5
# Epoch 51/200
# 80/80 - 1s - loss: 21.2226 - mape: 17.5772 - val_loss: 20.8912 - val_mape: 17.3454
#
# Epoch 00051: saving model to HousePrices2.h5
# Epoch 52/200
# 80/80 - 1s - loss: 21.0441 - mape: 17.4081 - val_loss: 20.0014 - val_mape: 16.4207
#
# Epoch 00052: saving model to HousePrices2.h5
# Epoch 53/200
# 80/80 - 1s - loss: 21.0154 - mape: 17.4053 - val_loss: 19.9874 - val_mape: 16.3642
#
# Epoch 00053: saving model to HousePrices2.h5
# Epoch 54/200
# 80/80 - 1s - loss: 21.2656 - mape: 17.6811 - val_loss: 19.9942 - val_mape: 16.3517
#
# Epoch 00054: saving model to HousePrices2.h5
# Epoch 55/200
# 80/80 - 1s - loss: 21.0511 - mape: 17.4755 - val_loss: 19.9023 - val_mape: 16.3210
#
# Epoch 00055: saving model to HousePrices2.h5
# Epoch 56/200
# 80/80 - 1s - loss: 21.0954 - mape: 17.5441 - val_loss: 19.8765 - val_mape: 16.3650
#
# Epoch 00056: saving model to HousePrices2.h5
# Epoch 57/200
# 80/80 - 1s - loss: 21.0222 - mape: 17.4942 - val_loss: 19.9328 - val_mape: 16.4367
#
# Epoch 00057: saving model to HousePrices2.h5
# Epoch 58/200
# 80/80 - 1s - loss: 21.0152 - mape: 17.4894 - val_loss: 19.8098 - val_mape: 16.2984
#
# Epoch 00058: saving model to HousePrices2.h5
# Epoch 59/200
# 80/80 - 1s - loss: 21.0469 - mape: 17.5270 - val_loss: 19.8668 - val_mape: 16.3400
#
# Epoch 00059: saving model to HousePrices2.h5
# Epoch 60/200
# 80/80 - 1s - loss: 21.0753 - mape: 17.5859 - val_loss: 19.7704 - val_mape: 16.2658
#
# Epoch 00060: saving model to HousePrices2.h5
# Epoch 61/200
# 80/80 - 1s - loss: 20.9158 - mape: 17.4541 - val_loss: 19.8491 - val_mape: 16.4295
#
# Epoch 00061: saving model to HousePrices2.h5
# Epoch 62/200
# 80/80 - 1s - loss: 20.8228 - mape: 17.3806 - val_loss: 20.2822 - val_mape: 16.9278
#
# Epoch 00062: saving model to HousePrices2.h5
# Epoch 63/200
# 80/80 - 1s - loss: 20.8301 - mape: 17.3958 - val_loss: 19.7377 - val_mape: 16.2965
#
# Epoch 00063: saving model to HousePrices2.h5
# Epoch 64/200
# 80/80 - 1s - loss: 20.8478 - mape: 17.4317 - val_loss: 19.7703 - val_mape: 16.3037
#
# Epoch 00064: saving model to HousePrices2.h5
# Epoch 65/200
# 80/80 - 1s - loss: 20.7262 - mape: 17.3295 - val_loss: 19.8372 - val_mape: 16.4917
#
# Epoch 00065: saving model to HousePrices2.h5
# Epoch 66/200
# 80/80 - 1s - loss: 20.8775 - mape: 17.5047 - val_loss: 20.0961 - val_mape: 16.7929
#
# Epoch 00066: saving model to HousePrices2.h5
# Epoch 67/200
# 80/80 - 1s - loss: 20.8892 - mape: 17.5198 - val_loss: 19.7765 - val_mape: 16.3791
#
# Epoch 00067: saving model to HousePrices2.h5
# Epoch 68/200
# 80/80 - 1s - loss: 20.7299 - mape: 17.3694 - val_loss: 19.7980 - val_mape: 16.4531
#
# Epoch 00068: saving model to HousePrices2.h5
# Epoch 69/200
# 80/80 - 1s - loss: 20.8465 - mape: 17.4914 - val_loss: 19.6958 - val_mape: 16.3041
#
# Epoch 00069: saving model to HousePrices2.h5
# Epoch 70/200
# 80/80 - 1s - loss: 20.7461 - mape: 17.4219 - val_loss: 19.8075 - val_mape: 16.5120
#
# Epoch 00070: saving model to HousePrices2.h5
# Epoch 71/200
# 80/80 - 1s - loss: 20.8121 - mape: 17.4805 - val_loss: 19.6436 - val_mape: 16.3445
#
# Epoch 00071: saving model to HousePrices2.h5
# Epoch 72/200
# 80/80 - 1s - loss: 20.9810 - mape: 17.6797 - val_loss: 20.3210 - val_mape: 16.9104
#
# Epoch 00072: saving model to HousePrices2.h5
# Epoch 73/200
# 80/80 - 1s - loss: 20.9035 - mape: 17.6063 - val_loss: 19.6318 - val_mape: 16.3578
#
# Epoch 00073: saving model to HousePrices2.h5
# Epoch 74/200
# 80/80 - 1s - loss: 20.5564 - mape: 17.2776 - val_loss: 19.5739 - val_mape: 16.2629
#
# Epoch 00074: saving model to HousePrices2.h5
# Epoch 75/200
# 80/80 - 1s - loss: 20.8175 - mape: 17.5427 - val_loss: 19.5000 - val_mape: 16.2291
#
# Epoch 00075: saving model to HousePrices2.h5
# Epoch 76/200
# 80/80 - 1s - loss: 20.6139 - mape: 17.3544 - val_loss: 19.5376 - val_mape: 16.2687
#
# Epoch 00076: saving model to HousePrices2.h5
# Epoch 77/200
# 80/80 - 1s - loss: 20.5899 - mape: 17.3446 - val_loss: 19.7468 - val_mape: 16.5605
#
# Epoch 00077: saving model to HousePrices2.h5
# Epoch 78/200
# 80/80 - 2s - loss: 20.6767 - mape: 17.4517 - val_loss: 19.7525 - val_mape: 16.5819
#
# Epoch 00078: saving model to HousePrices2.h5
# Epoch 79/200
# 80/80 - 1s - loss: 20.6028 - mape: 17.3795 - val_loss: 19.8431 - val_mape: 16.5496
#
# Epoch 00079: saving model to HousePrices2.h5
# Epoch 80/200
# 80/80 - 1s - loss: 20.6220 - mape: 17.3990 - val_loss: 19.7700 - val_mape: 16.5912
#
# Epoch 00080: saving model to HousePrices2.h5
# Epoch 81/200
# 80/80 - 1s - loss: 20.7461 - mape: 17.5253 - val_loss: 19.5272 - val_mape: 16.3494
#
# Epoch 00081: saving model to HousePrices2.h5
# Epoch 82/200
# 80/80 - 1s - loss: 20.6683 - mape: 17.4637 - val_loss: 19.4546 - val_mape: 16.2195
#
# Epoch 00082: saving model to HousePrices2.h5
# Epoch 83/200
# 80/80 - 1s - loss: 20.5926 - mape: 17.4030 - val_loss: 19.4367 - val_mape: 16.2469
#
# Epoch 00083: saving model to HousePrices2.h5
# Epoch 84/200
# 80/80 - 1s - loss: 20.6016 - mape: 17.4367 - val_loss: 19.3839 - val_mape: 16.1942
#
# Epoch 00084: saving model to HousePrices2.h5
# Epoch 85/200
# 80/80 - 1s - loss: 20.5814 - mape: 17.4262 - val_loss: 19.4745 - val_mape: 16.3173
#
# Epoch 00085: saving model to HousePrices2.h5
# Epoch 86/200
# 80/80 - 1s - loss: 20.5248 - mape: 17.3553 - val_loss: 20.0834 - val_mape: 17.0106
#
# Epoch 00086: saving model to HousePrices2.h5
# Epoch 87/200
# 80/80 - 1s - loss: 20.6094 - mape: 17.4701 - val_loss: 19.3942 - val_mape: 16.2024
#
# Epoch 00087: saving model to HousePrices2.h5
# Epoch 88/200
# 80/80 - 1s - loss: 20.5714 - mape: 17.4355 - val_loss: 19.4555 - val_mape: 16.2899
#
# Epoch 00088: saving model to HousePrices2.h5
# Epoch 89/200
# 80/80 - 1s - loss: 20.6630 - mape: 17.5446 - val_loss: 19.3729 - val_mape: 16.2767
#
# Epoch 00089: saving model to HousePrices2.h5
# Epoch 90/200
# 80/80 - 1s - loss: 20.6006 - mape: 17.4868 - val_loss: 20.0456 - val_mape: 17.0172
#
# Epoch 00090: saving model to HousePrices2.h5
# Epoch 91/200
# 80/80 - 1s - loss: 20.4563 - mape: 17.3538 - val_loss: 19.4210 - val_mape: 16.3248
#
# Epoch 00091: saving model to HousePrices2.h5
# Epoch 92/200
# 80/80 - 1s - loss: 20.3927 - mape: 17.2904 - val_loss: 19.3243 - val_mape: 16.2135
#
# Epoch 00092: saving model to HousePrices2.h5
# Epoch 93/200
# 80/80 - 1s - loss: 20.4661 - mape: 17.3671 - val_loss: 19.7479 - val_mape: 16.7318
#
# Epoch 00093: saving model to HousePrices2.h5
# Epoch 94/200
# 80/80 - 1s - loss: 20.6244 - mape: 17.5512 - val_loss: 20.0396 - val_mape: 17.0486
#
# Epoch 00094: saving model to HousePrices2.h5
# Epoch 95/200
# 80/80 - 1s - loss: 20.5325 - mape: 17.4526 - val_loss: 19.3019 - val_mape: 16.2279
#
# Epoch 00095: saving model to HousePrices2.h5
# Epoch 96/200
# 80/80 - 1s - loss: 20.4604 - mape: 17.3988 - val_loss: 19.3834 - val_mape: 16.3402
#
# Epoch 00096: saving model to HousePrices2.h5
# Epoch 97/200
# 80/80 - 1s - loss: 20.5334 - mape: 17.4723 - val_loss: 19.6549 - val_mape: 16.6596
#
# Epoch 00097: saving model to HousePrices2.h5
# Epoch 98/200
# 80/80 - 1s - loss: 20.5076 - mape: 17.4632 - val_loss: 19.3407 - val_mape: 16.3071
#
# Epoch 00098: saving model to HousePrices2.h5
# Epoch 99/200
# 80/80 - 1s - loss: 20.3675 - mape: 17.3265 - val_loss: 19.3204 - val_mape: 16.3284
#
# Epoch 00099: saving model to HousePrices2.h5
# Epoch 100/200
# 80/80 - 1s - loss: 20.5055 - mape: 17.4758 - val_loss: 19.4220 - val_mape: 16.3380
#
# Epoch 00100: saving model to HousePrices2.h5
# Epoch 101/200
# 80/80 - 1s - loss: 20.3376 - mape: 17.3117 - val_loss: 19.2692 - val_mape: 16.2268
#
# Epoch 00101: saving model to HousePrices2.h5
# Epoch 102/200
# 80/80 - 1s - loss: 20.3841 - mape: 17.3584 - val_loss: 19.2128 - val_mape: 16.1701
#
# Epoch 00102: saving model to HousePrices2.h5
# Epoch 103/200
# 80/80 - 1s - loss: 20.3645 - mape: 17.3593 - val_loss: 19.3649 - val_mape: 16.3044
#
# Epoch 00103: saving model to HousePrices2.h5
# Epoch 104/200
# 80/80 - 1s - loss: 20.4399 - mape: 17.4210 - val_loss: 19.6259 - val_mape: 16.6753
#
# Epoch 00104: saving model to HousePrices2.h5
# Epoch 105/200
# 80/80 - 1s - loss: 20.3823 - mape: 17.3880 - val_loss: 19.1801 - val_mape: 16.1815
#
# Epoch 00105: saving model to HousePrices2.h5
# Epoch 106/200
# 80/80 - 1s - loss: 20.2687 - mape: 17.2626 - val_loss: 19.2758 - val_mape: 16.3015
#
# Epoch 00106: saving model to HousePrices2.h5
# Epoch 107/200
# 80/80 - 1s - loss: 20.3096 - mape: 17.3132 - val_loss: 19.2186 - val_mape: 16.2137
#
# Epoch 00107: saving model to HousePrices2.h5
# Epoch 108/200
# 80/80 - 1s - loss: 20.4465 - mape: 17.4488 - val_loss: 19.3248 - val_mape: 16.3695
#
# Epoch 00108: saving model to HousePrices2.h5
# Epoch 109/200
# 80/80 - 1s - loss: 20.3065 - mape: 17.3235 - val_loss: 19.1794 - val_mape: 16.2191
#
# Epoch 00109: saving model to HousePrices2.h5
# Epoch 110/200
# 80/80 - 1s - loss: 20.2855 - mape: 17.3169 - val_loss: 19.1788 - val_mape: 16.2093
#
# Epoch 00110: saving model to HousePrices2.h5
# Epoch 111/200
# 80/80 - 1s - loss: 20.2239 - mape: 17.2609 - val_loss: 19.1997 - val_mape: 16.2544
#
# Epoch 00111: saving model to HousePrices2.h5
# Epoch 112/200
# 80/80 - 1s - loss: 20.3442 - mape: 17.3932 - val_loss: 19.1712 - val_mape: 16.2076
#
# Epoch 00112: saving model to HousePrices2.h5
# Epoch 113/200
# 80/80 - 1s - loss: 20.2577 - mape: 17.2945 - val_loss: 19.1289 - val_mape: 16.1723
#
# Epoch 00113: saving model to HousePrices2.h5
# Epoch 114/200
# 80/80 - 1s - loss: 20.2161 - mape: 17.2582 - val_loss: 19.3852 - val_mape: 16.4829
#
# Epoch 00114: saving model to HousePrices2.h5
# Epoch 115/200
# 80/80 - 1s - loss: 20.1027 - mape: 17.1571 - val_loss: 19.1689 - val_mape: 16.2327
#
# Epoch 00115: saving model to HousePrices2.h5
# Epoch 116/200
# 80/80 - 1s - loss: 20.1716 - mape: 17.2287 - val_loss: 19.3081 - val_mape: 16.3964
# Epoch 00116: saving model to HousePrices2.h5
# Epoch 117/200
# 80/80 - 1s - loss: 20.2342 - mape: 17.2925 - val_loss: 19.4945 - val_mape: 16.6109
#
# Epoch 00117: saving model to HousePrices2.h5
# Epoch 118/200
# 80/80 - 1s - loss: 20.1896 - mape: 17.2673 - val_loss: 19.1218 - val_mape: 16.1839
#
# Epoch 00118: saving model to HousePrices2.h5
# Epoch 119/200
# 80/80 - 1s - loss: 20.2030 - mape: 17.2887 - val_loss: 19.1209 - val_mape: 16.2035
#
# Epoch 00119: saving model to HousePrices2.h5
# Epoch 120/200
# 80/80 - 1s - loss: 20.2805 - mape: 17.3848 - val_loss: 19.0671 - val_mape: 16.1597
#
# Epoch 00120: saving model to HousePrices2.h5
# Epoch 121/200
# 80/80 - 1s - loss: 20.2496 - mape: 17.3573 - val_loss: 19.2435 - val_mape: 16.3353
#
# Epoch 00121: saving model to HousePrices2.h5
# Epoch 122/200
# 80/80 - 1s - loss: 20.2147 - mape: 17.3381 - val_loss: 19.2421 - val_mape: 16.3486
#
# Epoch 00122: saving model to HousePrices2.h5
# Epoch 123/200
# 80/80 - 1s - loss: 20.2181 - mape: 17.3125 - val_loss: 19.1211 - val_mape: 16.2466
#
# Epoch 00123: saving model to HousePrices2.h5
# Epoch 124/200
# 80/80 - 1s - loss: 20.1728 - mape: 17.2953 - val_loss: 19.0431 - val_mape: 16.1608
#
# Epoch 00124: saving model to HousePrices2.h5
# Epoch 125/200
# 80/80 - 1s - loss: 20.2410 - mape: 17.3730 - val_loss: 19.1356 - val_mape: 16.2634
#
# Epoch 00125: saving model to HousePrices2.h5
# Epoch 126/200
# 80/80 - 1s - loss: 20.2073 - mape: 17.3421 - val_loss: 19.1734 - val_mape: 16.3197
#
# Epoch 00126: saving model to HousePrices2.h5
# Epoch 127/200
# 80/80 - 1s - loss: 20.1683 - mape: 17.3142 - val_loss: 19.4462 - val_mape: 16.6264
#
# Epoch 00127: saving model to HousePrices2.h5
# Epoch 128/200
# 80/80 - 1s - loss: 20.2805 - mape: 17.4317 - val_loss: 19.0541 - val_mape: 16.2071
#
# Epoch 00128: saving model to HousePrices2.h5
# Epoch 129/200
# 80/80 - 1s - loss: 20.3074 - mape: 17.4638 - val_loss: 19.0152 - val_mape: 16.1415
#
# Epoch 00129: saving model to HousePrices2.h5
# Epoch 130/200
# 80/80 - 1s - loss: 20.1292 - mape: 17.2665 - val_loss: 19.5868 - val_mape: 16.8344
#
# Epoch 00130: saving model to HousePrices2.h5
# Epoch 131/200
# 80/80 - 1s - loss: 20.2814 - mape: 17.4609 - val_loss: 19.0133 - val_mape: 16.1379
#
# Epoch 00131: saving model to HousePrices2.h5
# Epoch 132/200
# 80/80 - 1s - loss: 20.1910 - mape: 17.3575 - val_loss: 19.1135 - val_mape: 16.3242
#
# Epoch 00132: saving model to HousePrices2.h5
# Epoch 133/200
# 80/80 - 1s - loss: 20.2264 - mape: 17.4181 - val_loss: 19.1727 - val_mape: 16.3936
#
# Epoch 00133: saving model to HousePrices2.h5
# Epoch 134/200
# 80/80 - 1s - loss: 20.2229 - mape: 17.3975 - val_loss: 19.0721 - val_mape: 16.2562
#
# Epoch 00134: saving model to HousePrices2.h5
# Epoch 135/200
# 80/80 - 1s - loss: 20.1771 - mape: 17.3675 - val_loss: 18.9753 - val_mape: 16.1657
#
# Epoch 00135: saving model to HousePrices2.h5
# Epoch 136/200
# 80/80 - 1s - loss: 20.0176 - mape: 17.2018 - val_loss: 18.9972 - val_mape: 16.1727
#
# Epoch 00136: saving model to HousePrices2.h5
# Epoch 137/200
# 80/80 - 1s - loss: 20.0846 - mape: 17.2641 - val_loss: 19.3376 - val_mape: 16.5546
#
# Epoch 00137: saving model to HousePrices2.h5
# Epoch 138/200
# 80/80 - 1s - loss: 20.1145 - mape: 17.3079 - val_loss: 19.0103 - val_mape: 16.2039
#
# Epoch 00138: saving model to HousePrices2.h5
# Epoch 139/200
# 80/80 - 1s - loss: 20.1049 - mape: 17.2988 - val_loss: 19.1715 - val_mape: 16.3578
#
# Epoch 00139: saving model to HousePrices2.h5
# Epoch 140/200
# 80/80 - 1s - loss: 20.2135 - mape: 17.4248 - val_loss: 18.9757 - val_mape: 16.2022
#
# Epoch 00140: saving model to HousePrices2.h5
# Epoch 141/200
# 80/80 - 1s - loss: 20.0307 - mape: 17.2367 - val_loss: 19.5568 - val_mape: 16.8375
#
# Epoch 00141: saving model to HousePrices2.h5
# Epoch 142/200
# 80/80 - 1s - loss: 20.2141 - mape: 17.4259 - val_loss: 18.9934 - val_mape: 16.1831
#
# Epoch 00142: saving model to HousePrices2.h5
# Epoch 143/200
# 80/80 - 1s - loss: 20.0009 - mape: 17.2165 - val_loss: 19.1889 - val_mape: 16.4280
#
# Epoch 00143: saving model to HousePrices2.h5
# Epoch 144/200
# 80/80 - 1s - loss: 20.0473 - mape: 17.2506 - val_loss: 18.9161 - val_mape: 16.1522
#
# Epoch 00144: saving model to HousePrices2.h5
# Epoch 145/200
# 80/80 - 1s - loss: 20.0551 - mape: 17.2955 - val_loss: 19.1029 - val_mape: 16.2813
#
# Epoch 00145: saving model to HousePrices2.h5
# Epoch 146/200
# 80/80 - 1s - loss: 20.0538 - mape: 17.2790 - val_loss: 18.9759 - val_mape: 16.1826
#
# Epoch 00146: saving model to HousePrices2.h5
# Epoch 147/200
# 80/80 - 1s - loss: 20.1401 - mape: 17.3755 - val_loss: 18.9216 - val_mape: 16.1592
#
# Epoch 00147: saving model to HousePrices2.h5
# Epoch 148/200
# 80/80 - 1s - loss: 20.1070 - mape: 17.3447 - val_loss: 18.9365 - val_mape: 16.1959
#
# Epoch 00148: saving model to HousePrices2.h5
# Epoch 149/200
# 80/80 - 1s - loss: 20.1845 - mape: 17.4373 - val_loss: 18.9012 - val_mape: 16.1761
#
# Epoch 00149: saving model to HousePrices2.h5
# Epoch 150/200
# 80/80 - 1s - loss: 20.0592 - mape: 17.3263 - val_loss: 18.8940 - val_mape: 16.1524
#
# Epoch 00150: saving model to HousePrices2.h5
# Epoch 151/200
# 80/80 - 1s - loss: 19.9910 - mape: 17.2576 - val_loss: 18.8971 - val_mape: 16.1277
#
# Epoch 00151: saving model to HousePrices2.h5
# Epoch 152/200
# 80/80 - 1s - loss: 20.0962 - mape: 17.3556 - val_loss: 18.9774 - val_mape: 16.2073
#
# Epoch 00152: saving model to HousePrices2.h5
# Epoch 153/200
# 80/80 - 1s - loss: 19.9780 - mape: 17.2554 - val_loss: 18.8854 - val_mape: 16.1501
#
# Epoch 00153: saving model to HousePrices2.h5
# Epoch 154/200
# 80/80 - 1s - loss: 19.9509 - mape: 17.2133 - val_loss: 19.4888 - val_mape: 16.6938
#
# Epoch 00154: saving model to HousePrices2.h5
# Epoch 155/200
# 80/80 - 1s - loss: 20.0510 - mape: 17.3133 - val_loss: 18.8706 - val_mape: 16.1295
#
# Epoch 00155: saving model to HousePrices2.h5
# Epoch 156/200
# 80/80 - 1s - loss: 20.0600 - mape: 17.3202 - val_loss: 18.9482 - val_mape: 16.2621
#
# Epoch 00156: saving model to HousePrices2.h5
# Epoch 157/200
# 80/80 - 1s - loss: 19.9816 - mape: 17.2718 - val_loss: 19.5099 - val_mape: 16.8507
#
# Epoch 00157: saving model to HousePrices2.h5
# Epoch 158/200
# 80/80 - 1s - loss: 20.0256 - mape: 17.2938 - val_loss: 18.9025 - val_mape: 16.1873
#
# Epoch 00158: saving model to HousePrices2.h5
# Epoch 159/200
# 80/80 - 1s - loss: 19.9827 - mape: 17.2672 - val_loss: 19.0159 - val_mape: 16.2468
#
# Epoch 00159: saving model to HousePrices2.h5
# Epoch 160/200
# 80/80 - 1s - loss: 19.8931 - mape: 17.1676 - val_loss: 18.8989 - val_mape: 16.1944
#
# Epoch 00160: saving model to HousePrices2.h5
# Epoch 161/200
# 80/80 - 1s - loss: 19.9168 - mape: 17.2067 - val_loss: 18.8864 - val_mape: 16.1869
#
# Epoch 00161: saving model to HousePrices2.h5
# Epoch 162/200
# 80/80 - 1s - loss: 19.9734 - mape: 17.2713 - val_loss: 19.0176 - val_mape: 16.3574
#
# Epoch 00162: saving model to HousePrices2.h5
# Epoch 163/200
# 80/80 - 1s - loss: 19.9765 - mape: 17.2930 - val_loss: 19.1327 - val_mape: 16.4964
#
# Epoch 00163: saving model to HousePrices2.h5
# Epoch 164/200
# 80/80 - 1s - loss: 19.9513 - mape: 17.2689 - val_loss: 18.8779 - val_mape: 16.1593
#
# Epoch 00164: saving model to HousePrices2.h5
# Epoch 165/200
# 80/80 - 1s - loss: 20.0647 - mape: 17.3724 - val_loss: 18.8726 - val_mape: 16.1921
#
# Epoch 00165: saving model to HousePrices2.h5

# %%
xvals = range(len(myhistory2.history['loss']))

fig, ax = plt.subplots(1,1,figsize=(10,8))
ax.plot(xvals, myhistory2.history['val_mape'], '-', label='test set accuracy')
ax.plot(xvals, myhistory2.history['mape'], '-', label='train set accuracy')
ax.legend()
plt.show()

# %%
y_pred_out = model.predict(X_test_out)

from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test_out, y_pred_out))  
print('MSE:', metrics.mean_squared_error(y_test_out, y_pred_out))  
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test_out, y_pred_out)))
print('MAPE:', np.sqrt(metrics.mean_absolute_percentage_error(y_test_out, y_pred_out)))
print('VarScore:',metrics.explained_variance_score(y_test_out,y_pred_out))
print('R2:', metrics.r2_score(y_test_out, y_pred_out))
# Out:
# MAE: 75555.40700722761
# MSE: 11950596890.686405
# RMSE: 109318.78562573958
# MAPE: 0.40175601978193476
# VarScore: 0.6670534527664318
# R2: 0.6266055896383502

# %%
# Visualizing Our predictions
fig = plt.figure(figsize=(10,5))
plt.scatter(y_test_out,y_pred_out)
# Perfect predictions
plt.plot(y_test_out,y_test_out,'r')

# %%
# !ls
# Out:
# HousePrices.h5	 homework_07-Copy1.ipynb  kc_house_data.csv
# HousePrices2.h5  homework_07.ipynb

# %%
print("Real Value: ", y_test_out[0])
print("Predicted Value: ", y_pred_out[0][0])
# Out:
# Real Value:  465000.0
# Predicted Value:  495784.66

# %%
import sklearn

# %% [markdown]
# # To do the following exercises you need to know how to use:
# * pandas dataframes
# * dictionaries
# * plotting array of images
# * convert data to .to_numpy()
# * assign inputs (features) to **X_data**
# * assign outputs (labels/targets) to **y_data**
# * understand the output of attribute .shape (dimensions of the data)
# * generate random integers np.random.randint()
# * convert color image to grayscale

# %% [markdown]
# # Exercise 1
# * the file 'mnist_test.csv' contains 10000 images of digits in grayscale saved as a rows in the csv file
# * first column contains value of the digits then 784 columns correspond to pixels
# * make an array of plots of 25 randomly chosen images (5x5)
# * each plot has to have a title corresponding to a digit

# %%
# !ls
# Out:
# FuelConsumption.csv	Homework3  data.csv	     how_to_submit.txt
# Homework1_Matrix.ipynb	aprobados  homework_2.ipynb  mnist_test.csv

# %%
# %pylab inline
import pandas as pd

#loading the data.
images=pd.read_csv("mnist_test.csv")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#converting to numpy array.
images_np=images.to_numpy()

# %%
#X data contains the pixels of the image.
X_data=images.loc[:,"1x1":"28x28"].to_numpy()

#y data contains the label of the image.
y_data=images["label"].to_numpy()

# %%
#selection of a random sample of 25 elements.
n_samples=np.random.randint(0,X_data.shape[0],25)
n_samples
# Out:
# array([1733,  647, 9733, 6720, 8002, 8846, 1687, 2920, 4264, 6567, 4506,
#        9301, 1136, 1897, 1078, 1006,  385, 4385, 9976, 7238, 3545, 1169,
#        7224, 6631, 9843])

# %%
#converting the 1D array of samples into a 2D array of 5x5.
ran_indx_matrix=n_samples.reshape(5,5)


fig,ax=plt.subplots(5,5,figsize=(10,10))
for i in range(0,ran_indx_matrix.shape[0]):
    for j in range(0,ran_indx_matrix.shape[1]):
        #the ij entry of this matrix is the random index of the image.
        k=ran_indx_matrix[i,j]
        
        #converting the 1D array of pixels into a 2D array of 28x28 image.
        b=X_data[k].reshape(28,28)
        
        #ploting the image.
        ax[i,j].imshow(b)
        ax[i,j].set_title(y_data[k])
        ax[i,j].set_axis_off()
        
#setting the separation between subplots.        
fig.tight_layout(pad=1.0)

# %% [markdown]
# # Exercise 2
#
# * Sklearn digits dataset (https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_digits.html) contains 1797 images of digits in grayscale
# * download the dataset (command is below) and:
# * make an array of plots of 25 randomly chosen images (5 images x 5 images)
# * each plot has to have a title corresponding to a digit

# %%
from sklearn import datasets
digits = datasets.load_digits() # digits is a dictionary

# %%
#Xdata contains images of digits.
X_data2=digits["images"]

#y data contains label of each image.
y_data2=digits["target"]

# %%
#selection of a random sample of 25 elements.
n_samples2=np.random.randint(0,X_data2.shape[0],25)

#converting the 1D array of samples into a 2D array of 5x5.
ran_indx_matrix2=n_samples2.reshape(5,5)

# %%
fig2,ax2=plt.subplots(5,5,figsize=(10,10))
for i in range(0,ran_indx_matrix2.shape[0]):
    for j in range(0,ran_indx_matrix2.shape[1]):
        #the ij entry of this matrix is the random index of the image.
        k=ran_indx_matrix2[i,j]
        
        #ploting the image.
        ax2[i,j].imshow(X_data2[k])
        ax2[i,j].set_title(y_data2[k])
        ax2[i,j].set_axis_off()
        
#setting the separation between subplots.        
fig2.tight_layout(pad=1.0)

# %% [markdown]
# # Exercise 3
# The CIFAR-10 dataset consists of, in total, 60000 **color** (three channels) images, each with one of 10 labels: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck. For an introduction and a download.
#
# http://www.cs.toronto.edu/~kriz/cifar.html
#
# * make an array of plots of 25 randomly chosen images (5 images x 5 images)
# * each plot has to have a title with a corresponding label
#
#
#
# * convert the color images to grayscale by averaging one of the dimensions and again display the images
#
#
# * make an array of plots of 25 randomly chosen images (5 images x 5 images)
# * each plot has to have a title with a corresponding label

# %%
import tensorflow as tf
(X_data3, y_data3), (_, _) = tf.keras.datasets.cifar10.load_data()

# %% [markdown]
# ## **I have an issue with tensorflow, I can not install it and that is the reason why the following cells were not run, although I worked on Colaboratory and the algorithm were right.**

# %%
#Equivalence between y_data and the labels for each image.
labels={0:"airplane",1:"automobile",2:"bird",3:"cat",4:"deer",5:"dog",6:"frog",7:"horse",8:"ship",9:"truck"}

# %%
#selection of a random sample of 25 elements.
n_samples3=np.random.randint(0,X_data3.shape[0],25)

#converting the 1D array of samples into a 2D array of 5x5.
ran_indx_matrix3=n_samples3.reshape(5,5)

# %%
fig3,ax3=plt.subplots(5,5,figsize=(6,6))
for i in range(0,ran_indx_matrix3.shape[0]):
    for j in range(0,ran_indx_matrix3.shape[1]):
        #the ij entry of this matrix is the random index of the image.
        k=ran_indx_matrix3[i,j]
        labl=labels[y_data3[k][0]]
        #ploting the image.
        ax3[i,j].imshow(X_data3[k])
        ax3[i,j].set_title(labl)
        ax3[i,j].set_axis_off()
        
#setting the separation between subplots.        
fig3.tight_layout(pad=1.0)

# %%
def c2gray1(M):
    """
    This function converts a (32,32,3) colored image into a (32x32) gray image.
    
    Parameters
    ----
    
    M : Array-like
        32x32x3-shape array to convert.
        
    Return
    ----
    
    c : Array-like
        The new array of shape 32x32 gray-scale.
    """
    b=M.copy().transpose(2,0,1)
    gray=(1/(3*255))*(b[0]+b[1]+b[2])
    return gray

# %%
#Constructing a new set of images converting the colored images into gray images.
nX_data3=[]
for i in range(0,X_data3.shape[0]):
    nX_data3.append(c2gray1(X_data3[i]))

# %%
fig3_gray,ax3_gray=plt.subplots(5,5,figsize=(6,6))
for i in range(0,ran_indx_matrix3.shape[0]):
    for j in range(0,ran_indx_matrix3.shape[1]):
        #the ij entry of this matrix is the random index of the image.
        k=ran_indx_matrix3[i,j]
        labl=labels[y_data3[k][0]]
        #ploting the image.
        ax3_gray[i,j].imshow(nX_data3[k],cmap="gray")
        ax3_gray[i,j].set_title(labl)
        ax3_gray[i,j].set_axis_off()
        
#setting the separation between subplots.        
fig3_gray.tight_layout(pad=1.0)

# %%
#selection of a random sample of 25 elements from gray images.
n_samples3_gray=np.random.randint(0,len(nX_data3),25)

#converting the 1D array of samples into a 2D array of 5x5.
ran_indx_matrix3_gray=n_samples3_gray.reshape(5,5)

# %%
fig3b_gray,ax3b_gray=plt.subplots(5,5,figsize=(6,6))
for i in range(0,ran_indx_matrix3_gray.shape[0]):
    for j in range(0,ran_indx_matrix3_gray.shape[1]):
        #the ij entry of this matrix is the random index of the image.
        k=ran_indx_matrix3_gray[i,j]
        labl=labels[y_data3[k][0]]
        #ploting the image.
        ax3b_gray[i,j].imshow(nX_data3[k],cmap="gray")
        ax3b_gray[i,j].set_title(labl)
        ax3b_gray[i,j].set_axis_off()
        
#setting the separation between subplots.        
fig3b_gray.tight_layout(pad=1.0)
